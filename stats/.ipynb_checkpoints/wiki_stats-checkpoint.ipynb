# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy

# Apply the default theme at seaborn
sns.set_theme()

# %%
# Opening JSON file
file_name = './../output/output_wiki.json'

df = pd.read_json(file_name)

# %%
df
# Out:
#                            name                       type  \
# 0                       Binance                         []
# 1        Gourmet Master Co. Ltd                         []
# 2     Tata Consultancy Services                   [Public]
# 3                   APMEX, Inc.                  [Private]
# 4     Bitmain Technologies Ltd.                  [Private]
# ...                         ...                        ...
# 997                 Blockstream              [Corporation]
# 998                        Nuri                         []
# 999                    Bitstamp  [Cryptocurrency exchange]
# 1000                     BitPay                         []
# 1001                     BitMEX                         []
#
#                                                industry      founded  \
# 0                            [cryptocurrency industry ]  [July 2017]
# 1                                   [Food and Beverage]       [2004]
# 2     [Information technology, Consulting, Outsourcing]       [1968]
# 3                                     [precious metals]       [2000]
# 4                                      [Cryptocurrency]       [2013]
# ...                                                 ...          ...
# 997                          [Cryptocurrency, software]       [2014]
# 998                                [Financial Services]       [2015]
# 999                                                  []           []
# 1000                                [Payment Processor]           []
# 1001                                                 []       [2014]
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                    []
# 2                                       [J. R. D. Tata]
# 3                                                    []
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                           []         []       []
# 1                             [Taipei, Taiwan]         []       []
# 2                        [Mumbai, Maharashtra]         []       []
# 3     [Oklahoma City, Oklahoma, United States]         []       []
# 4                             [Beijing, China]         []       []
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]         []       []
# 998                          [Berlin, Germany]         []       []
# 999                                         []         []       []
# 1000                   [Atlanta, Georgia, USA]         []       []
# 1001                              [Seychelles]         []       []
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                                 []
# 4                                 []
# ...                              ...
# 997                               []
# 998                               []
# 999                               []
# 1000                              []
# 1001                              []
#
#                                        operating_income  \
# 0                                                    []
# 1                                                    []
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                                 []
#
#                                            total_assets  \
# 0                                                    []
# 1                                                    []
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                                 []
#
#                            number_of_employees  \
# 0                                           []
# 1                                           []
# 2              [616,171, [3],  (October 2022)]
# 3                                           []
# 4                                           []
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                         []
# 999                                         []
# 1000                                        []
# 1001                                        []
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                             []
# 999                         [www, .bitstamp, .net]
# 1000                                            []
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]
#                            name                       type  \
# 0                       Binance                         []
# 1        Gourmet Master Co. Ltd                         []
# 2     Tata Consultancy Services                   [Public]
# 3                   APMEX, Inc.                  [Private]
# 4     Bitmain Technologies Ltd.                  [Private]
# ...                         ...                        ...
# 997                 Blockstream              [Corporation]
# 998                        Nuri                         []
# 999                    Bitstamp  [Cryptocurrency exchange]
# 1000                     BitPay                         []
# 1001                     BitMEX                         []
#
#                                                industry      founded  \
# 0                            [cryptocurrency industry ]  [July 2017]
# 1                                   [Food and Beverage]       [2004]
# 2     [Information technology, Consulting, Outsourcing]       [1968]
# 3                                     [precious metals]       [2000]
# 4                                      [Cryptocurrency]       [2013]
# ...                                                 ...          ...
# 997                          [Cryptocurrency, software]       [2014]
# 998                                [Financial Services]       [2015]
# 999                                                  []           []
# 1000                                [Payment Processor]           []
# 1001                                                 []       [2014]
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                    []
# 2                                       [J. R. D. Tata]
# 3                                                    []
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                           []         []       []
# 1                             [Taipei, Taiwan]         []       []
# 2                        [Mumbai, Maharashtra]         []       []
# 3     [Oklahoma City, Oklahoma, United States]         []       []
# 4                             [Beijing, China]         []       []
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]         []       []
# 998                          [Berlin, Germany]         []       []
# 999                                         []         []       []
# 1000                   [Atlanta, Georgia, USA]         []       []
# 1001                              [Seychelles]         []       []
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                                 []
# 4                                 []
# ...                              ...
# 997                               []
# 998                               []
# 999                               []
# 1000                              []
# 1001                              []
#
#                                        operating_income  \
# 0                                                    []
# 1                                                    []
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                                 []
#
#                                            total_assets  \
# 0                                                    []
# 1                                                    []
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                                 []
#
#                            number_of_employees  \
# 0                                           []
# 1                                           []
# 2              [616,171, [3],  (October 2022)]
# 3                                           []
# 4                                           []
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                         []
# 999                                         []
# 1000                                        []
# 1001                                        []
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                             []
# 999                         [www, .bitstamp, .net]
# 1000                                            []
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]

# %%
df = df.applymap(lambda x: None if len(x)==0 else x)

# %%
df
# Out:
#                            name                       type  \
# 0                       Binance                       None
# 1        Gourmet Master Co. Ltd                       None
# 2     Tata Consultancy Services                   [Public]
# 3                   APMEX, Inc.                  [Private]
# 4     Bitmain Technologies Ltd.                  [Private]
# ...                         ...                        ...
# 997                 Blockstream              [Corporation]
# 998                        Nuri                       None
# 999                    Bitstamp  [Cryptocurrency exchange]
# 1000                     BitPay                       None
# 1001                     BitMEX                       None
#
#                                                industry      founded  \
# 0                            [cryptocurrency industry ]  [July 2017]
# 1                                   [Food and Beverage]       [2004]
# 2     [Information technology, Consulting, Outsourcing]       [1968]
# 3                                     [precious metals]       [2000]
# 4                                      [Cryptocurrency]       [2013]
# ...                                                 ...          ...
# 997                          [Cryptocurrency, software]       [2014]
# 998                                [Financial Services]       [2015]
# 999                                                None         None
# 1000                                [Payment Processor]         None
# 1001                                               None       [2014]
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                  None
# 2                                       [J. R. D. Tata]
# 3                                                  None
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                         None       None     None
# 1                             [Taipei, Taiwan]       None     None
# 2                        [Mumbai, Maharashtra]       None     None
# 3     [Oklahoma City, Oklahoma, United States]       None     None
# 4                             [Beijing, China]       None     None
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]       None     None
# 998                          [Berlin, Germany]       None     None
# 999                                       None       None     None
# 1000                   [Atlanta, Georgia, USA]       None     None
# 1001                              [Seychelles]       None     None
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                               None
# 4                               None
# ...                              ...
# 997                             None
# 998                             None
# 999                             None
# 1000                            None
# 1001                            None
#
#                                        operating_income  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                                            total_assets  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                            number_of_employees  \
# 0                                         None
# 1                                         None
# 2              [616,171, [3],  (October 2022)]
# 3                                         None
# 4                                         None
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                       None
# 999                                       None
# 1000                                      None
# 1001                                      None
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                           None
# 999                         [www, .bitstamp, .net]
# 1000                                          None
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]
#                            name                       type  \
# 0                       Binance                       None
# 1        Gourmet Master Co. Ltd                       None
# 2     Tata Consultancy Services                   [Public]
# 3                   APMEX, Inc.                  [Private]
# 4     Bitmain Technologies Ltd.                  [Private]
# ...                         ...                        ...
# 997                 Blockstream              [Corporation]
# 998                        Nuri                       None
# 999                    Bitstamp  [Cryptocurrency exchange]
# 1000                     BitPay                       None
# 1001                     BitMEX                       None
#
#                                                industry      founded  \
# 0                            [cryptocurrency industry ]  [July 2017]
# 1                                   [Food and Beverage]       [2004]
# 2     [Information technology, Consulting, Outsourcing]       [1968]
# 3                                     [precious metals]       [2000]
# 4                                      [Cryptocurrency]       [2013]
# ...                                                 ...          ...
# 997                          [Cryptocurrency, software]       [2014]
# 998                                [Financial Services]       [2015]
# 999                                                None         None
# 1000                                [Payment Processor]         None
# 1001                                               None       [2014]
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                  None
# 2                                       [J. R. D. Tata]
# 3                                                  None
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                         None       None     None
# 1                             [Taipei, Taiwan]       None     None
# 2                        [Mumbai, Maharashtra]       None     None
# 3     [Oklahoma City, Oklahoma, United States]       None     None
# 4                             [Beijing, China]       None     None
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]       None     None
# 998                          [Berlin, Germany]       None     None
# 999                                       None       None     None
# 1000                   [Atlanta, Georgia, USA]       None     None
# 1001                              [Seychelles]       None     None
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                               None
# 4                               None
# ...                              ...
# 997                             None
# 998                             None
# 999                             None
# 1000                            None
# 1001                            None
#
#                                        operating_income  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                                            total_assets  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                            number_of_employees  \
# 0                                         None
# 1                                         None
# 2              [616,171, [3],  (October 2022)]
# 3                                         None
# 4                                         None
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                       None
# 999                                       None
# 1000                                      None
# 1001                                      None
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                           None
# 999                         [www, .bitstamp, .net]
# 1000                                          None
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# name                      0
# type                    142
# industry                 78
# founded                  46
# founders                498
# headquarters             37
# key_people             1001
# services                837
# revenue                 475
# operating_income        687
# total_assets            638
# number_of_employees     462
# website                 163
# dtype: int64
# name                      0
# type                    142
# industry                 78
# founded                  46
# founders                498
# headquarters             37
# key_people             1001
# services                837
# revenue                 475
# operating_income        687
# total_assets            638
# number_of_employees     462
# website                 163
# dtype: int64

# %%
print("Number of cells:", df.size)
print("Number of value None:", df.isnull().sum().sum())
print("Number of row:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of cells: 13026
# Number of value None: 5064
# Number of row: 1002
# Number of columns: 13
# Number of cells: 13026
# Number of value None: 5064
# Number of row: 1002
# Number of columns: 13

# %%
# to extract the first elements from list
df.type = df.type.apply(lambda x: x[0] if x is not None else x)

# %%
#type
print(df['type'].value_counts())
type_companies = df['type'].value_counts()
type(type_companies)
#the top 10 types of companies are taken here because there are many types
type_companies_top10 = type_companies.head(10)
keys = type_companies_top10.index
values = type_companies_top10.values

print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("top 10 type of companies")
plt.xlabel("number of companies")
plt.show()
# Out:
# Public                     250
# Private                    132
# Public company              78
# Subsidiary                  78
# State-owned enterprise      21
#                           ...
# Sun Network                  1
# ASA                          1
# Private Limited company      1
# JSC                          1
# State owned company          1
# Name: type, Length: 135, dtype: int64
# Index(['Public', 'Private', 'Public company', 'Subsidiary',
#        'State-owned enterprise', 'Division', 'Public limited company',
#        'Production company', 'Corporation', 'Privately held company'],
#       dtype='object')
# [250 132  78  78  21  21  19  12  11  11]
# Public                     250
# Private                    132
# Public company              78
# Subsidiary                  78
# State-owned enterprise      21
#                           ...
# Sun Network                  1
# ASA                          1
# Private Limited company      1
# JSC                          1
# State owned company          1
# Name: type, Length: 135, dtype: int64
# Index(['Public', 'Private', 'Public company', 'Subsidiary',
#        'State-owned enterprise', 'Division', 'Public limited company',
#        'Production company', 'Corporation', 'Privately held company'],
#       dtype='object')
# [250 132  78  78  21  21  19  12  11  11]

# %%
# to extract the first elements from list
df.industry = df.industry.apply(lambda x: x[0] if x is not None else x)

# %%
#industry
plt.rcParams.update({'font.size': 22})
print(df['industry'].value_counts())
industry_companies = df['industry'].value_counts()
type(industry_companies)
#the top 10 industry
industry_companies_top10 = industry_companies.head(10)
keys = industry_companies_top10.index
values = industry_companies_top10.values

print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")
plt.tick_params(axis='both', which='major', labelsize=20)

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("top 10 industry of companies")
plt.xlabel("number of companies")
plt.show()
# Out:
# Film                       71
# Entertainment              64
# Retail                     58
# Oil and gas                56
# Motion pictures            47
#                            ..
# Motion Picture              1
# oil and gas exploration     1
# Supermarket                 1
# Gas utility                 1
# Payment Processor           1
# Name: industry, Length: 235, dtype: int64
# Index(['Film', 'Entertainment', 'Retail', 'Oil and gas', 'Motion pictures',
#        'Petroleum industry', 'Information technology', 'Petroleum',
#        'Financial services', 'Energy'],
#       dtype='object')
# [71 64 58 56 47 31 26 25 24 18]
# Film                       71
# Entertainment              64
# Retail                     58
# Oil and gas                56
# Motion pictures            47
#                            ..
# Motion Picture              1
# oil and gas exploration     1
# Supermarket                 1
# Gas utility                 1
# Payment Processor           1
# Name: industry, Length: 235, dtype: int64
# Index(['Film', 'Entertainment', 'Retail', 'Oil and gas', 'Motion pictures',
#        'Petroleum industry', 'Information technology', 'Petroleum',
#        'Financial services', 'Energy'],
#       dtype='object')
# [71 64 58 56 47 31 26 25 24 18]

# %%
# to extract the first elements from list
df.founded = df.founded.apply(lambda x: x[0] if x is not None else x)

# df.founded.apply(lambda txt: int(s) for s in txt for w in s.split() if w.isdigit() and len(s)==4)

# %%
companies_to_date = {'<1950': 0, '1950-2000': 0, '>2000': 0}
#generate dictionary with key an interval time and with value number of companies in that time interval
for s in df.founded.values:
    if s is not None:
        for w in s.split():
            if s.isdigit() and len(s)==4:
                s = int(s)
                type(s)
                if s<1950:
                    companies_to_date['<1950'] += 1
                elif 1950 < s < 2000:
                    companies_to_date['1950-2000'] += 1
                else:
                    companies_to_date['>2000'] += 1

print(companies_to_date)
companies_to_date = pd.Series(companies_to_date)
keys = companies_to_date.index
values = companies_to_date.values
print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.05, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("fondation date")
plt.xlabel("number of companies")
plt.show()
# Out:
# {'<1950': 105, '1950-2000': 237, '>2000': 125}
# Index(['<1950', '1950-2000', '>2000'], dtype='object')
# [105 237 125]
# {'<1950': 105, '1950-2000': 237, '>2000': 125}
# Index(['<1950', '1950-2000', '>2000'], dtype='object')
# [105 237 125]

# %%
df
# Out:
#                            name                     type  \
# 0                       Binance                     None
# 1        Gourmet Master Co. Ltd                     None
# 2     Tata Consultancy Services                   Public
# 3                   APMEX, Inc.                  Private
# 4     Bitmain Technologies Ltd.                  Private
# ...                         ...                      ...
# 997                 Blockstream              Corporation
# 998                        Nuri                     None
# 999                    Bitstamp  Cryptocurrency exchange
# 1000                     BitPay                     None
# 1001                     BitMEX                     None
#
#                       industry    founded  \
# 0     cryptocurrency industry   July 2017
# 1            Food and Beverage       2004
# 2       Information technology       1968
# 3              precious metals       2000
# 4               Cryptocurrency       2013
# ...                        ...        ...
# 997             Cryptocurrency       2014
# 998         Financial Services       2015
# 999                       None       None
# 1000         Payment Processor       None
# 1001                      None       2014
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                  None
# 2                                       [J. R. D. Tata]
# 3                                                  None
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                         None       None     None
# 1                             [Taipei, Taiwan]       None     None
# 2                        [Mumbai, Maharashtra]       None     None
# 3     [Oklahoma City, Oklahoma, United States]       None     None
# 4                             [Beijing, China]       None     None
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]       None     None
# 998                          [Berlin, Germany]       None     None
# 999                                       None       None     None
# 1000                   [Atlanta, Georgia, USA]       None     None
# 1001                              [Seychelles]       None     None
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                               None
# 4                               None
# ...                              ...
# 997                             None
# 998                             None
# 999                             None
# 1000                            None
# 1001                            None
#
#                                        operating_income  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                                            total_assets  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                            number_of_employees  \
# 0                                         None
# 1                                         None
# 2              [616,171, [3],  (October 2022)]
# 3                                         None
# 4                                         None
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                       None
# 999                                       None
# 1000                                      None
# 1001                                      None
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                           None
# 999                         [www, .bitstamp, .net]
# 1000                                          None
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]
#                            name                     type  \
# 0                       Binance                     None
# 1        Gourmet Master Co. Ltd                     None
# 2     Tata Consultancy Services                   Public
# 3                   APMEX, Inc.                  Private
# 4     Bitmain Technologies Ltd.                  Private
# ...                         ...                      ...
# 997                 Blockstream              Corporation
# 998                        Nuri                     None
# 999                    Bitstamp  Cryptocurrency exchange
# 1000                     BitPay                     None
# 1001                     BitMEX                     None
#
#                       industry    founded  \
# 0     cryptocurrency industry   July 2017
# 1            Food and Beverage       2004
# 2       Information technology       1968
# 3              precious metals       2000
# 4               Cryptocurrency       2013
# ...                        ...        ...
# 997             Cryptocurrency       2014
# 998         Financial Services       2015
# 999                       None       None
# 1000         Payment Processor       None
# 1001                      None       2014
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                  None
# 2                                       [J. R. D. Tata]
# 3                                                  None
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                         None       None     None
# 1                             [Taipei, Taiwan]       None     None
# 2                        [Mumbai, Maharashtra]       None     None
# 3     [Oklahoma City, Oklahoma, United States]       None     None
# 4                             [Beijing, China]       None     None
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]       None     None
# 998                          [Berlin, Germany]       None     None
# 999                                       None       None     None
# 1000                   [Atlanta, Georgia, USA]       None     None
# 1001                              [Seychelles]       None     None
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                               None
# 4                               None
# ...                              ...
# 997                             None
# 998                             None
# 999                             None
# 1000                            None
# 1001                            None
#
#                                        operating_income  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                                            total_assets  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                            number_of_employees  \
# 0                                         None
# 1                                         None
# 2              [616,171, [3],  (October 2022)]
# 3                                         None
# 4                                         None
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                       None
# 999                                       None
# 1000                                      None
# 1001                                      None
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                           None
# 999                         [www, .bitstamp, .net]
# 1000                                          None
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]

# %% [markdown]
# # Valori Distinti

# %%
df.type.value_counts()
# Out:
# Public                     250
# Private                    132
# Public company              78
# Subsidiary                  78
# State-owned enterprise      21
#                           ...
# Sun Network                  1
# ASA                          1
# Private Limited company      1
# JSC                          1
# State owned company          1
# Name: type, Length: 135, dtype: int64
# Public                     250
# Private                    132
# Public company              78
# Subsidiary                  78
# State-owned enterprise      21
#                           ...
# Sun Network                  1
# ASA                          1
# Private Limited company      1
# JSC                          1
# State owned company          1
# Name: type, Length: 135, dtype: int64

# %%
df.industry.value_counts()
# Out:
# Film                       71
# Entertainment              64
# Retail                     58
# Oil and gas                56
# Motion pictures            47
#                            ..
# Motion Picture              1
# oil and gas exploration     1
# Supermarket                 1
# Gas utility                 1
# Payment Processor           1
# Name: industry, Length: 235, dtype: int64
# Film                       71
# Entertainment              64
# Retail                     58
# Oil and gas                56
# Motion pictures            47
#                            ..
# Motion Picture              1
# oil and gas exploration     1
# Supermarket                 1
# Gas utility                 1
# Payment Processor           1
# Name: industry, Length: 235, dtype: int64

# %%
df.founded.value_counts()
# Out:
# 2005               13
# 2000               13
# 1993               13
# 1994               12
# 1989               12
#                    ..
# Quezon City         1
# May 8, 1993         1
# January 1, 1980     1
# 1997-2018           1
#                     1
# Name: founded, Length: 584, dtype: int64
# 2005               13
# 2000               13
# 1993               13
# 1994               12
# 1989               12
#                    ..
# Quezon City         1
# May 8, 1993         1
# January 1, 1980     1
# 1997-2018           1
#                     1
# Name: founded, Length: 584, dtype: int64

# %%
df.founders.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Marcus, Samuel Samuel, Jean B.A. Kessler, Henri Deterding]    3
# [Charles Heung]                                                2
# [Vladimir Nikolaev, Yuri Moskvin]                              2
# [Samuel Goldwyn Jr.]                                           2
# [Laszlo Barna, Laura Alper]                                    2
#                                                               ..
# [Juan Francisco Velasco Alvarado]                              1
# [CJ Group]                                                     1
# [Kang Woo-suk]                                                 1
# [Tyler Kwon (CEO)]                                             1
# [Ben Delo]                                                     1
# Name: founders, Length: 494, dtype: int64
# [Marcus, Samuel Samuel, Jean B.A. Kessler, Henri Deterding]    3
# [Charles Heung]                                                2
# [Vladimir Nikolaev, Yuri Moskvin]                              2
# [Samuel Goldwyn Jr.]                                           2
# [Laszlo Barna, Laura Alper]                                    2
#                                                               ..
# [Juan Francisco Velasco Alvarado]                              1
# [CJ Group]                                                     1
# [Kang Woo-suk]                                                 1
# [Tyler Kwon (CEO)]                                             1
# [Ben Delo]                                                     1
# Name: founders, Length: 494, dtype: int64

# %%
df.headquarters.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [London]                                                                  13
# [Mumbai, India]                                                           11
# [Mumbai, Maharashtra, India]                                               9
# [Beijing, China]                                                           9
# [Los Angeles, California]                                                  9
#                                                                           ..
# [St. John's, Newfoundland and Labrador, Canada]                            1
# [Calgary, Alberta, Canada]                                                 1
# [Saint John, New Brunswick]                                                1
# [Headquarters in Calgary; oil and gas wells throughout western Canada]     1
# [Atlanta, Georgia, USA]                                                    1
# Name: headquarters, Length: 712, dtype: int64
# [London]                                                                  13
# [Mumbai, India]                                                           11
# [Mumbai, Maharashtra, India]                                               9
# [Beijing, China]                                                           9
# [Los Angeles, California]                                                  9
#                                                                           ..
# [St. John's, Newfoundland and Labrador, Canada]                            1
# [Calgary, Alberta, Canada]                                                 1
# [Saint John, New Brunswick]                                                1
# [Headquarters in Calgary; oil and gas wells throughout western Canada]     1
# [Atlanta, Georgia, USA]                                                    1
# Name: headquarters, Length: 712, dtype: int64

# %%
df.key_people.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ (, ), Edward 'Ted' Philip (non-executive chairman),  (chairwoman), Brett Hart (president), Gerry Laderman (, ),  (, )]    1
# Name: key_people, dtype: int64
# [ (, ), Edward 'Ted' Philip (non-executive chairman),  (chairwoman), Brett Hart (president), Gerry Laderman (, ),  (, )]    1
# Name: key_people, dtype: int64

# %%
df.services.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Film production]                                                 5
# [Fuel stations]                                                   5
# [Film production, Film distribution]                              4
# [Coffee]                                                          3
# [Service stations]                                                3
#                                                                  ..
# [Bicycle sharing, Carsharing, Fuel stations, Fleet management]    1
# [Post-production services]                                        1
# [Gas Pipeline Transport]                                          1
# [Film production, Film distribution, Advertisement production]    1
# [Outsourcing, Professional services, Managed services]            1
# Name: services, Length: 140, dtype: int64
# [Film production]                                                 5
# [Fuel stations]                                                   5
# [Film production, Film distribution]                              4
# [Coffee]                                                          3
# [Service stations]                                                3
#                                                                  ..
# [Bicycle sharing, Carsharing, Fuel stations, Fleet management]    1
# [Post-production services]                                        1
# [Gas Pipeline Transport]                                          1
# [Film production, Film distribution, Advertisement production]    1
# [Outsourcing, Professional services, Managed services]            1
# Name: services, Length: 140, dtype: int64

# %%
df.revenue.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ ,  (2021)]                                       51
# [US$]                                              45
# [€]                                                41
# [ ,  (2022)]                                        9
# [ ,  (2021)]                                        8
#                                                    ..
# [ 23.366 billion HRK |,  $3,672 billion (2021)]     1
# [ US$ 250 million (2006)]                           1
# [kr.]                                               1
# [ €15.148 billion ]                                 1
# [US$ 35 billion (2021)]                             1
# Name: revenue, Length: 322, dtype: int64
# [ ,  (2021)]                                       51
# [US$]                                              45
# [€]                                                41
# [ ,  (2022)]                                        9
# [ ,  (2021)]                                        8
#                                                    ..
# [ 23.366 billion HRK |,  $3,672 billion (2021)]     1
# [ US$ 250 million (2006)]                           1
# [kr.]                                               1
# [ €15.148 billion ]                                 1
# [US$ 35 billion (2021)]                             1
# Name: revenue, Length: 322, dtype: int64

# %%
df.operating_income.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ US$33.4 billion, [1],  (2021)]     3
# [ $7.7,  , billion, [2],  (2022)]    2
# [ €16.0 billion (2021), [1]]         2
# [ US$1.965 billion (2019), [1]]      2
# [ US$23.04 billion (2021)]           2
#                                     ..
# [ ¥236 billion (FY2018), [1]]        1
# [US$1.8 billion (2019), [5]]         1
# [NIS –60.7 million , (2010)]         1
# [ US$4.62 billion (2022)]            1
# [ US$6.86 billion (2021), [5]]       1
# Name: operating_income, Length: 306, dtype: int64
# [ US$33.4 billion, [1],  (2021)]     3
# [ $7.7,  , billion, [2],  (2022)]    2
# [ €16.0 billion (2021), [1]]         2
# [ US$1.965 billion (2019), [1]]      2
# [ US$23.04 billion (2021)]           2
#                                     ..
# [ ¥236 billion (FY2018), [1]]        1
# [US$1.8 billion (2019), [5]]         1
# [NIS –60.7 million , (2010)]         1
# [ US$4.62 billion (2022)]            1
# [ US$6.86 billion (2021), [5]]       1
# Name: operating_income, Length: 306, dtype: int64

# %%
df.total_assets.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ US$404.4 billion, [1],  (2021)]                                     3
# [ €258.8 billion (2021), [1]]                                         2
# [ , ¥27.70 , trillion,  , RMB,   US$4027.44 billion , (2018), [7]]    2
# [ , US$320.5 billion,  (2021)]                                        2
# [ €159.8 billion (2019), [1]]                                         2
#                                                                      ..
# [US$ 22.5 billion (2012)]                                             1
# [ THB2,232,331 million , (2016)]                                      1
# [ , CA$, 13,423.9 million,  (2020), [2]]                              1
# [1,129,199,000 Czech koruna (2019) ]                                  1
# [ ,  US$132.00 billion (2021), [5],  ]                                1
# Name: total_assets, Length: 355, dtype: int64
# [ US$404.4 billion, [1],  (2021)]                                     3
# [ €258.8 billion (2021), [1]]                                         2
# [ , ¥27.70 , trillion,  , RMB,   US$4027.44 billion , (2018), [7]]    2
# [ , US$320.5 billion,  (2021)]                                        2
# [ €159.8 billion (2019), [1]]                                         2
#                                                                      ..
# [US$ 22.5 billion (2012)]                                             1
# [ THB2,232,331 million , (2016)]                                      1
# [ , CA$, 13,423.9 million,  (2020), [2]]                              1
# [1,129,199,000 Czech koruna (2019) ]                                  1
# [ ,  US$132.00 billion (2021), [5],  ]                                1
# Name: total_assets, Length: 355, dtype: int64

# %%
df.number_of_employees.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [86,000, [2],  (2022)]                                                  3
# [100+]                                                                  3
# [ 304,000, [1],  (2022)]                                                2
# [ 172,425 (2021), [1]]                                                  2
# [124,818 (2018)]                                                        2
#                                                                        ..
# [83,633 (2021)]                                                         1
# [INA Group: 9,751 (31 Dec 2021), INA d.d.: 3,222 (31 Dec 2021), [2]]    1
# [746 (2020)]                                                            1
# [ 6,836 (end 2021), [2]]                                                1
# [50–100, [, citation needed, ],  (2014)]                                1
# Name: number_of_employees, Length: 526, dtype: int64
# [86,000, [2],  (2022)]                                                  3
# [100+]                                                                  3
# [ 304,000, [1],  (2022)]                                                2
# [ 172,425 (2021), [1]]                                                  2
# [124,818 (2018)]                                                        2
#                                                                        ..
# [83,633 (2021)]                                                         1
# [INA Group: 9,751 (31 Dec 2021), INA d.d.: 3,222 (31 Dec 2021), [2]]    1
# [746 (2020)]                                                            1
# [ 6,836 (end 2021), [2]]                                                1
# [50–100, [, citation needed, ],  (2014)]                                1
# Name: number_of_employees, Length: 526, dtype: int64

# %%
df.website.value_counts()
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# File pandas\_libs\hashtable_class_helper.pxi:5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ ]                             30
# [Official website]              16
# [ ]                              4
# [www, .shell, .com]              3
# [engie, .com, /en]               2
#                                 ..
# [www, .lycaproductions, .in]     1
# [www.premier-oil.com]            1
# [dana-petroleum, .com]           1
# [www, .centrica, .com]           1
# [www, .bitmex, .com]             1
# Name: website, Length: 775, dtype: int64
# [ ]                             30
# [Official website]              16
# [ ]                              4
# [www, .shell, .com]              3
# [engie, .com, /en]               2
#                                 ..
# [www, .lycaproductions, .in]     1
# [www.premier-oil.com]            1
# [dana-petroleum, .com]           1
# [www, .centrica, .com]           1
# [www, .bitmex, .com]             1
# Name: website, Length: 775, dtype: int64

# %% [markdown]
# # Generazione Mappe

# %%
df.headquarters = df.headquarters.apply(lambda x: x[0] if x is not None else x)

# %%
list_without_none = list()
for i in df.headquarters:
    if i is not None:
        list_without_none.append(i)

print(list_without_none)
# Out:
# ['Taipei', 'Mumbai', 'Oklahoma City, Oklahoma', 'Beijing, China', 'Palo Alto, CA', 'New Brunswick, New Jersey', 'One Microsoft Way', 'Bentonville, Arkansas', 'Saint Kitts and Nevis', 'Northern Cross, Malahide Road, Dublin, Ireland', 'Ottawa', 'Oakland', 'Neckarsulm', 'Beijing', 'Essen', 'Deerfield, Illinois', 'Atlanta, Georgia', 'Brampton', '1000 ', 'Paris', 'Bella Vista, New South Wales', 'Goodlettsville, Tennessee', 'Issaquah, Washington', 'Delft', 'Saint-Étienne', 'Croix', 'Nanjing', 'Bangkok', 'Düsseldorf', 'Arteixo', 'Bologna', 'San Francisco, California', 'Hamburg', 'Beaverton, Oregon', 'New York City', 'Memphis, Tennessee', 'Monterrey', 'Karlsruhe', 'Solna', 'Madrid', 'Brackenfell', '40 rue de Sèvres, Paris 7e, France', 'West Des Moines, Iowa', 'Jamsil-dong', "Villeneuve d'Ascq", 'Kochi', 'Mumbai', 'Malad', 'Mumbai', 'Mumbai', 'Reykjavík', 'Hyderabad, Telangana', 'Chennai', 'Mumbai, Maharashtra', 'Mumbai', 'Chennai', 'Mumbai', 'Mumbai', 'Chennai', 'Mumbai, Maharashtra', 'India', 'Chembur', 'Oslo', 'Koganei, Tokyo', 'Pasig', 'Victoria Island', 'Ekaterinburg', 'Saint Petersburg', 'Manila', 'St. Petersburg, Russia', 'Moscow', 'Moscow', 'Saint-Petersburg', 'Cape Town', 'Akademika Korolyova str.', 'Nonhyeon-dong', 'Belgrade', 'Moscow', 'Saint Petersburg', 'Nambusunhwan', 'Istanbul', 'London, England', 'Broadcasting House', 'London, United Kingdom', 'Shepperton', 'Brooklyn, New York', 'Bridgend', 'Bangkok', 'London', 'Sheffield', 'London', 'New York City', 'Greenwich, Connecticut', 'St Margarets, London', 'United States', 'United States', 'Hollywood, California', 'Hollywood, California', 'Century City, California', '4000 Warner Blvd', 'Toronto', 'Glendale, California', '723 Seventh Avenue, New York, NY', 'Fort Lee, New Jersey', 'United States', 'The Bronx', 'Hollywood, California', 'Century City, Los Angeles, California', 'United States', 'New York City', 'Santa Monica, California', 'Santa Monica', 'Philadelphia, Pennsylvania', 'Studio City', '500 South Buena Vista Street', 'Letterman Digital Arts Center', 'Medford, Oregon', 'Beverly Hills, California', 'Melbourne', 'Los Angeles, California', 'Los Angeles, California', '4000 Warner Blvd', 'Los Angeles, California', 'Bayonne, New Jersey', 'London', 'Edendale, California', 'Culver City, California', 'Los Angeles, California', 'Albany, Georgia', '10202 West Washington Boulevard', 'Chicago', 'Century City', '10202 West Washington Boulevard', 'New York City', 'Los Angeles', 'Santa Monica, California', 'New York, New York', '10202 West Washington Boulevard', 'Santa Monica', 'Los Angeles, California', 'Universal City, California', 'Beverly Hills, California', 'Pico Boulevard', 'Minneapolis', 'Atlanta, Georgia', 'Hudson Street', 'Los Angeles', 'Century City', '1384 Broadway', 'Burbank, California', '500 South Buena Vista Street', 'United States', 'Los Angeles', '4000 Warner Blvd.', '500 South Buena Vista Street', 'Walt Disney Studios', 'Culver City, California', 'New York City', '10 Universal City Plaza', 'Santa Monica, California', 'Utah', 'New York City', 'Universal City, California', 'Studio City, Los Angeles', 'Hollywood, California', 'Avenue of the Americas', 'Austin Studios', 'Poverty Row', 'Scottsdale, Arizona', 'Los Angeles, California', 'Los Angeles', 'New York City, New York', 'Los Angeles', 'New York City', 'California', 'Beverly Hills, California', 'Edendale, Los Angeles', 'Albany, Georgia', 'Irving, Texas', 'Santa Monica Boulevard', 'Burbank', 'United States', 'New York', '500 South Buena Vista Street', 'Charlottesville', ', ', 'Springdale, Arkansas', 'Chatsworth, Los Angeles', 'Sonoma County, California', 'Universal City, California', 'Miami', 'Beverly Hills, California', 'United States', 'Los Angeles, California', 'Beverly Hills, California', 'Nashville, Tennessee', 'United States', 'New York City', 'Universal City, California', '10202 West Washington Boulevard', 'Santa Monica, California', 'Los Angeles', 'Brentwood, Los Angeles', 'Beverly Hills, California', 'Los Ange ...
# ['Taipei', 'Mumbai', 'Oklahoma City, Oklahoma', 'Beijing, China', 'Palo Alto, CA', 'New Brunswick, New Jersey', 'One Microsoft Way', 'Bentonville, Arkansas', 'Saint Kitts and Nevis', 'Northern Cross, Malahide Road, Dublin, Ireland', 'Ottawa', 'Oakland', 'Neckarsulm', 'Beijing', 'Essen', 'Deerfield, Illinois', 'Atlanta, Georgia', 'Brampton', '1000 ', 'Paris', 'Bella Vista, New South Wales', 'Goodlettsville, Tennessee', 'Issaquah, Washington', 'Delft', 'Saint-Étienne', 'Croix', 'Nanjing', 'Bangkok', 'Düsseldorf', 'Arteixo', 'Bologna', 'San Francisco, California', 'Hamburg', 'Beaverton, Oregon', 'New York City', 'Memphis, Tennessee', 'Monterrey', 'Karlsruhe', 'Solna', 'Madrid', 'Brackenfell', '40 rue de Sèvres, Paris 7e, France', 'West Des Moines, Iowa', 'Jamsil-dong', "Villeneuve d'Ascq", 'Kochi', 'Mumbai', 'Malad', 'Mumbai', 'Mumbai', 'Reykjavík', 'Hyderabad, Telangana', 'Chennai', 'Mumbai, Maharashtra', 'Mumbai', 'Chennai', 'Mumbai', 'Mumbai', 'Chennai', 'Mumbai, Maharashtra', 'India', 'Chembur', 'Oslo', 'Koganei, Tokyo', 'Pasig', 'Victoria Island', 'Ekaterinburg', 'Saint Petersburg', 'Manila', 'St. Petersburg, Russia', 'Moscow', 'Moscow', 'Saint-Petersburg', 'Cape Town', 'Akademika Korolyova str.', 'Nonhyeon-dong', 'Belgrade', 'Moscow', 'Saint Petersburg', 'Nambusunhwan', 'Istanbul', 'London, England', 'Broadcasting House', 'London, United Kingdom', 'Shepperton', 'Brooklyn, New York', 'Bridgend', 'Bangkok', 'London', 'Sheffield', 'London', 'New York City', 'Greenwich, Connecticut', 'St Margarets, London', 'United States', 'United States', 'Hollywood, California', 'Hollywood, California', 'Century City, California', '4000 Warner Blvd', 'Toronto', 'Glendale, California', '723 Seventh Avenue, New York, NY', 'Fort Lee, New Jersey', 'United States', 'The Bronx', 'Hollywood, California', 'Century City, Los Angeles, California', 'United States', 'New York City', 'Santa Monica, California', 'Santa Monica', 'Philadelphia, Pennsylvania', 'Studio City', '500 South Buena Vista Street', 'Letterman Digital Arts Center', 'Medford, Oregon', 'Beverly Hills, California', 'Melbourne', 'Los Angeles, California', 'Los Angeles, California', '4000 Warner Blvd', 'Los Angeles, California', 'Bayonne, New Jersey', 'London', 'Edendale, California', 'Culver City, California', 'Los Angeles, California', 'Albany, Georgia', '10202 West Washington Boulevard', 'Chicago', 'Century City', '10202 West Washington Boulevard', 'New York City', 'Los Angeles', 'Santa Monica, California', 'New York, New York', '10202 West Washington Boulevard', 'Santa Monica', 'Los Angeles, California', 'Universal City, California', 'Beverly Hills, California', 'Pico Boulevard', 'Minneapolis', 'Atlanta, Georgia', 'Hudson Street', 'Los Angeles', 'Century City', '1384 Broadway', 'Burbank, California', '500 South Buena Vista Street', 'United States', 'Los Angeles', '4000 Warner Blvd.', '500 South Buena Vista Street', 'Walt Disney Studios', 'Culver City, California', 'New York City', '10 Universal City Plaza', 'Santa Monica, California', 'Utah', 'New York City', 'Universal City, California', 'Studio City, Los Angeles', 'Hollywood, California', 'Avenue of the Americas', 'Austin Studios', 'Poverty Row', 'Scottsdale, Arizona', 'Los Angeles, California', 'Los Angeles', 'New York City, New York', 'Los Angeles', 'New York City', 'California', 'Beverly Hills, California', 'Edendale, Los Angeles', 'Albany, Georgia', 'Irving, Texas', 'Santa Monica Boulevard', 'Burbank', 'United States', 'New York', '500 South Buena Vista Street', 'Charlottesville', ', ', 'Springdale, Arkansas', 'Chatsworth, Los Angeles', 'Sonoma County, California', 'Universal City, California', 'Miami', 'Beverly Hills, California', 'United States', 'Los Angeles, California', 'Beverly Hills, California', 'Nashville, Tennessee', 'United States', 'New York City', 'Universal City, California', '10202 West Washington Boulevard', 'Santa Monica, California', 'Los Angeles', 'Brentwood, Los Angeles', 'Beverly Hills, California', 'Los Ange ...

# %%
#extract country
import pycountry

headquarters_list = list()
for i in df.headquarters:
    if i is not None:
        headquarters_list.append(i)

print(len(headquarters_list))


country_list = list()
for text in headquarters_list:
    for country in pycountry.countries:
        if country.name in text:
            # print(country.name)
            country_list.append(country.name)

# print(country_list)
print(len(country_list))

country_to_count = dict()
for i in country_list:
    if i not in country_to_count.keys():
        country_to_count[i] = 1
    else:
        country_to_count[i] += 1

print(country_to_count)
d = {'CountryName': country_to_count.keys(), 'User_Percent': country_to_count.values()}
df_country = pd.DataFrame(data=d)
# df_country.User_Percent = df_country.User_Percent.apply(lambda x: int(x)/len(country_list))

df_country
# Out:
# 965
# 90
# {'China': 2, 'Jersey': 8, 'Saint Kitts and Nevis': 1, 'Ireland': 1, 'Georgia': 6, 'France': 2, 'India': 8, 'United Kingdom': 3, 'United States': 9, 'South Africa': 2, 'Australia': 2, 'Norway': 1, 'Malaysia': 1, 'Japan': 3, 'Italy': 2, 'Mexico': 2, 'Canada': 1, 'Sweden': 1, 'Greece': 1, 'Germany': 4, 'Austria': 1, 'Denmark': 1, 'Hong Kong': 7, 'Singapore': 5, 'Belgium': 1, 'Luxembourg': 2, 'Gibraltar': 1, 'Switzerland': 3, 'Seychelles': 3, 'Bangladesh': 1, 'Netherlands': 1, 'Cayman Islands': 1, 'Libya': 1, 'Ghana': 1, 'Congo': 1}
# 965
# 90
# {'China': 2, 'Jersey': 8, 'Saint Kitts and Nevis': 1, 'Ireland': 1, 'Georgia': 6, 'France': 2, 'India': 8, 'United Kingdom': 3, 'United States': 9, 'South Africa': 2, 'Australia': 2, 'Norway': 1, 'Malaysia': 1, 'Japan': 3, 'Italy': 2, 'Mexico': 2, 'Canada': 1, 'Sweden': 1, 'Greece': 1, 'Germany': 4, 'Austria': 1, 'Denmark': 1, 'Hong Kong': 7, 'Singapore': 5, 'Belgium': 1, 'Luxembourg': 2, 'Gibraltar': 1, 'Switzerland': 3, 'Seychelles': 3, 'Bangladesh': 1, 'Netherlands': 1, 'Cayman Islands': 1, 'Libya': 1, 'Ghana': 1, 'Congo': 1}
#               CountryName  User_Percent
# 0                   China             2
# 1                  Jersey             8
# 2   Saint Kitts and Nevis             1
# 3                 Ireland             1
# 4                 Georgia             6
# 5                  France             2
# 6                   India             8
# 7          United Kingdom             3
# 8           United States             9
# 9            South Africa             2
# 10              Australia             2
# 11                 Norway             1
# 12               Malaysia             1
# 13                  Japan             3
# 14                  Italy             2
# 15                 Mexico             2
# 16                 Canada             1
# 17                 Sweden             1
# 18                 Greece             1
# 19                Germany             4
# 20                Austria             1
# 21                Denmark             1
# 22              Hong Kong             7
# 23              Singapore             5
# 24                Belgium             1
# 25             Luxembourg             2
# 26              Gibraltar             1
# 27            Switzerland             3
# 28             Seychelles             3
# 29             Bangladesh             1
# 30            Netherlands             1
# 31         Cayman Islands             1
# 32                  Libya             1
# 33                  Ghana             1
# 34                  Congo             1
#               CountryName  User_Percent
# 0                   China             2
# 1                  Jersey             8
# 2   Saint Kitts and Nevis             1
# 3                 Ireland             1
# 4                 Georgia             6
# 5                  France             2
# 6                   India             8
# 7          United Kingdom             3
# 8           United States             9
# 9            South Africa             2
# 10              Australia             2
# 11                 Norway             1
# 12               Malaysia             1
# 13                  Japan             3
# 14                  Italy             2
# 15                 Mexico             2
# 16                 Canada             1
# 17                 Sweden             1
# 18                 Greece             1
# 19                Germany             4
# 20                Austria             1
# 21                Denmark             1
# 22              Hong Kong             7
# 23              Singapore             5
# 24                Belgium             1
# 25             Luxembourg             2
# 26              Gibraltar             1
# 27            Switzerland             3
# 28             Seychelles             3
# 29             Bangladesh             1
# 30            Netherlands             1
# 31         Cayman Islands             1
# 32                  Libya             1
# 33                  Ghana             1
# 34                  Congo             1

# %%
#function to convert to alpah2 country codes and continents
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2

def get_continent(col):
    try:
        cn_a2_code =  country_name_to_country_alpha2(col)
    except:
        cn_a2_code = 'Unknown'
    try:
        cn_continent = country_alpha2_to_continent_code(cn_a2_code)
    except:
        cn_continent = 'Unknown'
    return (cn_a2_code, cn_continent)

list_tuple = list()
for i in df_country.CountryName:
    list_tuple.append(get_continent(i))

print(len(list_tuple))
df_country = df_country.assign(codes = list_tuple)
print(list_tuple[0][0])
df_country = df_country.assign(Country = list(zip(*list_tuple))[0])
df_country = df_country.assign(Continent = list(zip(*list_tuple))[1])
df_country
# Out:
# 35
# CN
# 35
# CN
#               CountryName  User_Percent     codes Country Continent
# 0                   China             2  (CN, AS)      CN        AS
# 1                  Jersey             8  (JE, EU)      JE        EU
# 2   Saint Kitts and Nevis             1  (KN, NA)      KN        NA
# 3                 Ireland             1  (IE, EU)      IE        EU
# 4                 Georgia             6  (GE, AS)      GE        AS
# 5                  France             2  (FR, EU)      FR        EU
# 6                   India             8  (IN, AS)      IN        AS
# 7          United Kingdom             3  (GB, EU)      GB        EU
# 8           United States             9  (US, NA)      US        NA
# 9            South Africa             2  (ZA, AF)      ZA        AF
# 10              Australia             2  (AU, OC)      AU        OC
# 11                 Norway             1  (NO, EU)      NO        EU
# 12               Malaysia             1  (MY, AS)      MY        AS
# 13                  Japan             3  (JP, AS)      JP        AS
# 14                  Italy             2  (IT, EU)      IT        EU
# 15                 Mexico             2  (MX, NA)      MX        NA
# 16                 Canada             1  (CA, NA)      CA        NA
# 17                 Sweden             1  (SE, EU)      SE        EU
# 18                 Greece             1  (GR, EU)      GR        EU
# 19                Germany             4  (DE, EU)      DE        EU
# 20                Austria             1  (AT, EU)      AT        EU
# 21                Denmark             1  (DK, EU)      DK        EU
# 22              Hong Kong             7  (HK, AS)      HK        AS
# 23              Singapore             5  (SG, AS)      SG        AS
# 24                Belgium             1  (BE, EU)      BE        EU
# 25             Luxembourg             2  (LU, EU)      LU        EU
# 26              Gibraltar             1  (GI, EU)      GI        EU
# 27            Switzerland             3  (CH, EU)      CH        EU
# 28             Seychelles             3  (SC, AF)      SC        AF
# 29             Bangladesh             1  (BD, AS)      BD        AS
# 30            Netherlands             1  (NL, EU)      NL        EU
# 31         Cayman Islands             1  (KY, NA)      KY        NA
# 32                  Libya             1  (LY, AF)      LY        AF
# 33                  Ghana             1  (GH, AF)      GH        AF
# 34                  Congo             1  (CG, AF)      CG        AF
#               CountryName  User_Percent     codes Country Continent
# 0                   China             2  (CN, AS)      CN        AS
# 1                  Jersey             8  (JE, EU)      JE        EU
# 2   Saint Kitts and Nevis             1  (KN, NA)      KN        NA
# 3                 Ireland             1  (IE, EU)      IE        EU
# 4                 Georgia             6  (GE, AS)      GE        AS
# 5                  France             2  (FR, EU)      FR        EU
# 6                   India             8  (IN, AS)      IN        AS
# 7          United Kingdom             3  (GB, EU)      GB        EU
# 8           United States             9  (US, NA)      US        NA
# 9            South Africa             2  (ZA, AF)      ZA        AF
# 10              Australia             2  (AU, OC)      AU        OC
# 11                 Norway             1  (NO, EU)      NO        EU
# 12               Malaysia             1  (MY, AS)      MY        AS
# 13                  Japan             3  (JP, AS)      JP        AS
# 14                  Italy             2  (IT, EU)      IT        EU
# 15                 Mexico             2  (MX, NA)      MX        NA
# 16                 Canada             1  (CA, NA)      CA        NA
# 17                 Sweden             1  (SE, EU)      SE        EU
# 18                 Greece             1  (GR, EU)      GR        EU
# 19                Germany             4  (DE, EU)      DE        EU
# 20                Austria             1  (AT, EU)      AT        EU
# 21                Denmark             1  (DK, EU)      DK        EU
# 22              Hong Kong             7  (HK, AS)      HK        AS
# 23              Singapore             5  (SG, AS)      SG        AS
# 24                Belgium             1  (BE, EU)      BE        EU
# 25             Luxembourg             2  (LU, EU)      LU        EU
# 26              Gibraltar             1  (GI, EU)      GI        EU
# 27            Switzerland             3  (CH, EU)      CH        EU
# 28             Seychelles             3  (SC, AF)      SC        AF
# 29             Bangladesh             1  (BD, AS)      BD        AS
# 30            Netherlands             1  (NL, EU)      NL        EU
# 31         Cayman Islands             1  (KY, NA)      KY        NA
# 32                  Libya             1  (LY, AF)      LY        AF
# 33                  Ghana             1  (GH, AF)      GH        AF
# 34                  Congo             1  (CG, AF)      CG        AF

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="http")
def geolocate(country):
    try:
        # Geolocate the center of the country
        loc = geolocator.geocode(country)
        # And return latitude and longitude
        return (loc.latitude, loc.longitude)
    except:
        # Return missing value
        return np.nan

list_tuple = list()
for i in df_country.CountryName:
    list_tuple.append(geolocate(i))

print(len(list_tuple))
df_country = df_country.assign(Geolocate = list_tuple)
print(list_tuple[0][0])
df_country = df_country.assign(Latitude = list(zip(*list_tuple))[0])
df_country = df_country.assign(Longitude = list(zip(*list_tuple))[1])
df_country
# Out:
# 35
# 35.000074
# 35
# 35.000074
#               CountryName  User_Percent     codes Country Continent  \
# 0                   China             2  (CN, AS)      CN        AS
# 1                  Jersey             8  (JE, EU)      JE        EU
# 2   Saint Kitts and Nevis             1  (KN, NA)      KN        NA
# 3                 Ireland             1  (IE, EU)      IE        EU
# 4                 Georgia             6  (GE, AS)      GE        AS
# 5                  France             2  (FR, EU)      FR        EU
# 6                   India             8  (IN, AS)      IN        AS
# 7          United Kingdom             3  (GB, EU)      GB        EU
# 8           United States             9  (US, NA)      US        NA
# 9            South Africa             2  (ZA, AF)      ZA        AF
# 10              Australia             2  (AU, OC)      AU        OC
# 11                 Norway             1  (NO, EU)      NO        EU
# 12               Malaysia             1  (MY, AS)      MY        AS
# 13                  Japan             3  (JP, AS)      JP        AS
# 14                  Italy             2  (IT, EU)      IT        EU
# 15                 Mexico             2  (MX, NA)      MX        NA
# 16                 Canada             1  (CA, NA)      CA        NA
# 17                 Sweden             1  (SE, EU)      SE        EU
# 18                 Greece             1  (GR, EU)      GR        EU
# 19                Germany             4  (DE, EU)      DE        EU
# 20                Austria             1  (AT, EU)      AT        EU
# 21                Denmark             1  (DK, EU)      DK        EU
# 22              Hong Kong             7  (HK, AS)      HK        AS
# 23              Singapore             5  (SG, AS)      SG        AS
# 24                Belgium             1  (BE, EU)      BE        EU
# 25             Luxembourg             2  (LU, EU)      LU        EU
# 26              Gibraltar             1  (GI, EU)      GI        EU
# 27            Switzerland             3  (CH, EU)      CH        EU
# 28             Seychelles             3  (SC, AF)      SC        AF
# 29             Bangladesh             1  (BD, AS)      BD        AS
# 30            Netherlands             1  (NL, EU)      NL        EU
# 31         Cayman Islands             1  (KY, NA)      KY        NA
# 32                  Libya             1  (LY, AF)      LY        AF
# 33                  Ghana             1  (GH, AF)      GH        AF
# 34                  Congo             1  (CG, AF)      CG        AF
#
#                                   Geolocate   Latitude   Longitude
# 0                   (35.000074, 104.999927)  35.000074  104.999927
# 1                  (49.2214561, -2.1358386)  49.221456   -2.135839
# 2                  (17.250512, -62.6725973)  17.250512  -62.672597
# 3                   (52.865196, -7.9794599)  52.865196   -7.979460
# 4                 (32.3293809, -83.1137366)  32.329381  -83.113737
# 5                    (46.603354, 1.8883335)  46.603354    1.888334
# 6                  (22.3511148, 78.6677428)  22.351115   78.667743
# 7                  (54.7023545, -3.2765753)  54.702354   -3.276575
# 8                 (39.7837304, -100.445882)  39.783730 -100.445882
# 9                  (-28.8166236, 24.991639) -28.816624   24.991639
# 10                   (-24.7761086, 134.755) -24.776109  134.755000
# 11                  (60.5000209, 9.0999715)  60.500021    9.099972
# 12                 (4.5693754, 102.2656823)   4.569375  102.265682
# 13                (36.5748441, 139.2394179)  36.574844  139.239418
# 14                  (42.6384261, 12.674297)  42.638426   12.674297
# 15               (23.6585116, -102.0077097)  23.658512 -102.007710
# 16                (61.0666922, -107.991707)  61.066692 -107.991707
# 17                 (59.6749712, 14.5208584)  59.674971   14.520858
# 18                 (38.9953683, 21.9877132)  38.995368   21.987713
# 19                 (51.1638175, 10.4478313)  51.163818   10.447831
# 20                     (47.59397, 14.12456)  47.593970   14.124560
# 21                  (55.670249, 10.3333283)  55.670249   10.333328
# 22                (22.2793278, 114.1628131)  22.279328  114.162813
# 23                  (1.357107, 103.8194992)   1.357107  103.819499
# 24                  (50.6402809, 4.6667145)  50.640281    4.666715
# 25                  (49.8158683, 6.1296751)  49.815868    6.129675
# 26                 (36.1285933, -5.3474761)  36.128593   -5.347476
# 27                  (46.7985624, 8.2319736)  46.798562    8.231974
# 28                 (-4.6574977, 55.4540146)  -4.657498   55.454015
# 29                 (24.4769288, 90.2934413)  24.476929   90.293441
# 30                  (52.2434979, 5.6343227)  52.243498    5.634323
# 31  (19.703182249999998, -79.9174627243246)  19.703182  -79.917463
# 32                 (26.8234472, 18.1236723)  26.823447   18.123672
# 33                  (8.0300284, -1.0800271)   8.030028   -1.080027
# 34                 (-2.9814344, 23.8222636)  -2.981434   23.822264
#               CountryName  User_Percent     codes Country Continent  \
# 0                   China             2  (CN, AS)      CN        AS
# 1                  Jersey             8  (JE, EU)      JE        EU
# 2   Saint Kitts and Nevis             1  (KN, NA)      KN        NA
# 3                 Ireland             1  (IE, EU)      IE        EU
# 4                 Georgia             6  (GE, AS)      GE        AS
# 5                  France             2  (FR, EU)      FR        EU
# 6                   India             8  (IN, AS)      IN        AS
# 7          United Kingdom             3  (GB, EU)      GB        EU
# 8           United States             9  (US, NA)      US        NA
# 9            South Africa             2  (ZA, AF)      ZA        AF
# 10              Australia             2  (AU, OC)      AU        OC
# 11                 Norway             1  (NO, EU)      NO        EU
# 12               Malaysia             1  (MY, AS)      MY        AS
# 13                  Japan             3  (JP, AS)      JP        AS
# 14                  Italy             2  (IT, EU)      IT        EU
# 15                 Mexico             2  (MX, NA)      MX        NA
# 16                 Canada             1  (CA, NA)      CA        NA
# 17                 Sweden             1  (SE, EU)      SE        EU
# 18                 Greece             1  (GR, EU)      GR        EU
# 19                Germany             4  (DE, EU)      DE        EU
# 20                Austria             1  (AT, EU)      AT        EU
# 21                Denmark             1  (DK, EU)      DK        EU
# 22              Hong Kong             7  (HK, AS)      HK        AS
# 23              Singapore             5  (SG, AS)      SG        AS
# 24                Belgium             1  (BE, EU)      BE        EU
# 25             Luxembourg             2  (LU, EU)      LU        EU
# 26              Gibraltar             1  (GI, EU)      GI        EU
# 27            Switzerland             3  (CH, EU)      CH        EU
# 28             Seychelles             3  (SC, AF)      SC        AF
# 29             Bangladesh             1  (BD, AS)      BD        AS
# 30            Netherlands             1  (NL, EU)      NL        EU
# 31         Cayman Islands             1  (KY, NA)      KY        NA
# 32                  Libya             1  (LY, AF)      LY        AF
# 33                  Ghana             1  (GH, AF)      GH        AF
# 34                  Congo             1  (CG, AF)      CG        AF
#
#                                   Geolocate   Latitude   Longitude
# 0                   (35.000074, 104.999927)  35.000074  104.999927
# 1                  (49.2214561, -2.1358386)  49.221456   -2.135839
# 2                  (17.250512, -62.6725973)  17.250512  -62.672597
# 3                   (52.865196, -7.9794599)  52.865196   -7.979460
# 4                 (32.3293809, -83.1137366)  32.329381  -83.113737
# 5                    (46.603354, 1.8883335)  46.603354    1.888334
# 6                  (22.3511148, 78.6677428)  22.351115   78.667743
# 7                  (54.7023545, -3.2765753)  54.702354   -3.276575
# 8                 (39.7837304, -100.445882)  39.783730 -100.445882
# 9                  (-28.8166236, 24.991639) -28.816624   24.991639
# 10                   (-24.7761086, 134.755) -24.776109  134.755000
# 11                  (60.5000209, 9.0999715)  60.500021    9.099972
# 12                 (4.5693754, 102.2656823)   4.569375  102.265682
# 13                (36.5748441, 139.2394179)  36.574844  139.239418
# 14                  (42.6384261, 12.674297)  42.638426   12.674297
# 15               (23.6585116, -102.0077097)  23.658512 -102.007710
# 16                (61.0666922, -107.991707)  61.066692 -107.991707
# 17                 (59.6749712, 14.5208584)  59.674971   14.520858
# 18                 (38.9953683, 21.9877132)  38.995368   21.987713
# 19                 (51.1638175, 10.4478313)  51.163818   10.447831
# 20                     (47.59397, 14.12456)  47.593970   14.124560
# 21                  (55.670249, 10.3333283)  55.670249   10.333328
# 22                (22.2793278, 114.1628131)  22.279328  114.162813
# 23                  (1.357107, 103.8194992)   1.357107  103.819499
# 24                  (50.6402809, 4.6667145)  50.640281    4.666715
# 25                  (49.8158683, 6.1296751)  49.815868    6.129675
# 26                 (36.1285933, -5.3474761)  36.128593   -5.347476
# 27                  (46.7985624, 8.2319736)  46.798562    8.231974
# 28                 (-4.6574977, 55.4540146)  -4.657498   55.454015
# 29                 (24.4769288, 90.2934413)  24.476929   90.293441
# 30                  (52.2434979, 5.6343227)  52.243498    5.634323
# 31  (19.703182249999998, -79.9174627243246)  19.703182  -79.917463
# 32                 (26.8234472, 18.1236723)  26.823447   18.123672
# 33                  (8.0300284, -1.0800271)   8.030028   -1.080027
# 34                 (-2.9814344, 23.8222636)  -2.981434   23.822264

# %%
# Create a world map to show distributions of users
import folium
from folium.plugins import MarkerCluster
#empty map
world_map= folium.Map(tiles="cartodbpositron")
marker_cluster = MarkerCluster().add_to(world_map)
#for each coordinate, create circlemarker of user percent
for i in range(len(df_country)):
        lat = df_country.iloc[i]['Latitude']
        long = df_country.iloc[i]['Longitude']
        radius=5
        popup_text = """Country : {}<br>
                    # %of #Companies : {}<br>"""
        popup_text = popup_text.format(df_country.iloc[i]['Country'],
                                   df_country.iloc[i]['User_Percent']
                                   )
        folium.CircleMarker(location = [lat, long], radius=radius, popup= popup_text, fill =True, weight = 5).add_to(marker_cluster)
#show the map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b40328b15fd0eae18d7ed87a2dbd94a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b40328b15fd0eae18d7ed87a2dbd94a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b40328b15fd0eae18d7ed87a2dbd94a8 = L.map(
#                 &quot;map_b40328b15fd0eae18d7ed87a2dbd94a8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b7800562b8940369235a9685051e7b5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b40328b15fd0eae18d7ed87a2dbd94a8);
#
#
#             var marker_cluster_6014740d5dadd63d7fbef5df5763f2dd = L.markerClusterGroup(
#                 {}
#             );
#             map_b40328b15fd0eae18d7ed87a2dbd94a8.addLayer(marker_cluster_6014740d5dadd63d7fbef5df5763f2dd);
#
#
#             var circle_marker_55a23110f76d40ffdf3fb85c8b735ca7 = L.circleMarker(
#                 [35.000074, 104.999927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_6014740d5dadd63d7fbef5df5763f2dd);
#
#
#         var popup_91481546dd3e3a1f5c2c090e8d403d8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d91a956c49977d10036b9143b19fbaf = $(`&lt;div id=&quot;html_5d91a956c49977d10036b9143b19fbaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Country : CN&lt;br&gt;                     %of #Companies : 2&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_91481546dd3e3a1f5c2c090e8d403d8a.setContent(html_5d91a956c49977d10036b9143b19fbaf);
#
#
#
#         circle_marker_55a23110f76d40ffdf3fb85c8b735ca7.bindPopup(popup_91481546dd3e3a1f5c2c090e8d403d8a)
#         ;
#
#
#
#
#             var circle_marker_e1c56951e998168f1b9ab9ba334172db = L.circleMarker(
#                 [49.2214561, -2.1358386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_6014740d5dadd63d7fbef5df5763f2dd);
#
#
#         var popup_e6b1e509fe5277a604eec22ee94fba7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9455f54759ae022bd8fd1112dcb3c83 = $(`&lt;div id=&quot;html_e9455f54759ae022bd8fd1112dcb3c83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Country : JE&lt;br&gt;                     %of #Companies : 8&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_e6b1e509fe5277a604eec22ee94fba7a.setContent(html_e9455f54759ae022bd8fd1112dcb3c83);
#
#
#
#         circle_marker_e1c56951e998168f1b9ab9ba334172db.bindPopup(popup_e6b1e509fe5277a604eec22ee94fba7a)
#         ;
#
#
#
#
#             var circle_marker_5c66355815b9d148cdb5c12102e99888 = L.circleMarker(
#                 [17.250512, -62.6725973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_6014740d5dadd63d7fbef5df5763f2dd);
#
#
#         var popup_0c507019948f
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b40328b15fd0eae18d7ed87a2dbd94a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b40328b15fd0eae18d7ed87a2dbd94a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b40328b15fd0eae18d7ed87a2dbd94a8 = L.map(
#                 &quot;map_b40328b15fd0eae18d7ed87a2dbd94a8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b7800562b8940369235a9685051e7b5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b40328b15fd0eae18d7ed87a2dbd94a8);
#
#
#             var marker_cluster_6014740d5dadd63d7fbef5df5763f2dd = L.markerClusterGroup(
#                 {}
#             );
#             map_b40328b15fd0eae18d7ed87a2dbd94a8.addLayer(marker_cluster_6014740d5dadd63d7fbef5df5763f2dd);
#
#
#             var circle_marker_55a23110f76d40ffdf3fb85c8b735ca7 = L.circleMarker(
#                 [35.000074, 104.999927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_6014740d5dadd63d7fbef5df5763f2dd);
#
#
#         var popup_91481546dd3e3a1f5c2c090e8d403d8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d91a956c49977d10036b9143b19fbaf = $(`&lt;div id=&quot;html_5d91a956c49977d10036b9143b19fbaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Country : CN&lt;br&gt;                     %of #Companies : 2&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_91481546dd3e3a1f5c2c090e8d403d8a.setContent(html_5d91a956c49977d10036b9143b19fbaf);
#
#
#
#         circle_marker_55a23110f76d40ffdf3fb85c8b735ca7.bindPopup(popup_91481546dd3e3a1f5c2c090e8d403d8a)
#         ;
#
#
#
#
#             var circle_marker_e1c56951e998168f1b9ab9ba334172db = L.circleMarker(
#                 [49.2214561, -2.1358386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_6014740d5dadd63d7fbef5df5763f2dd);
#
#
#         var popup_e6b1e509fe5277a604eec22ee94fba7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9455f54759ae022bd8fd1112dcb3c83 = $(`&lt;div id=&quot;html_e9455f54759ae022bd8fd1112dcb3c83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Country : JE&lt;br&gt;                     %of #Companies : 8&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_e6b1e509fe5277a604eec22ee94fba7a.setContent(html_e9455f54759ae022bd8fd1112dcb3c83);
#
#
#
#         circle_marker_e1c56951e998168f1b9ab9ba334172db.bindPopup(popup_e6b1e509fe5277a604eec22ee94fba7a)
#         ;
#
#
#
#
#             var circle_marker_5c66355815b9d148cdb5c12102e99888 = L.circleMarker(
#                 [17.250512, -62.6725973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_6014740d5dadd63d7fbef5df5763f2dd);
#
#
#         var popup_0c507019948f

# %%
from folium import plugins

from folium.plugins import HeatMap


heat_data = [[row['Latitude'],row['Longitude']] for index, row in df_country.iterrows()]

map = folium.Map(location=[0, 0], zoom_start = 1)


# Plot it on the map

HeatMap(heat_data).add_to(map)

# Display the map

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fba68b29719ab3f5fa522b0a6e270f13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fba68b29719ab3f5fa522b0a6e270f13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fba68b29719ab3f5fa522b0a6e270f13 = L.map(
#                 &quot;map_fba68b29719ab3f5fa522b0a6e270f13&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3a926d735b593316e29b666931b2bf4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fba68b29719ab3f5fa522b0a6e270f13);
#
#
#             var heat_map_747ae017e9e5761e2d40c5c99beb16f9 = L.heatLayer(
#                 [[35.000074, 104.999927], [49.2214561, -2.1358386], [17.250512, -62.6725973], [52.865196, -7.9794599], [32.3293809, -83.1137366], [46.603354, 1.8883335], [22.3511148, 78.6677428], [54.7023545, -3.2765753], [39.7837304, -100.445882], [-28.8166236, 24.991639], [-24.7761086, 134.755], [60.5000209, 9.0999715], [4.5693754, 102.2656823], [36.5748441, 139.2394179], [42.6384261, 12.674297], [23.6585116, -102.0077097], [61.0666922, -107.991707], [59.6749712, 14.5208584], [38.9953683, 21.9877132], [51.1638175, 10.4478313], [47.59397, 14.12456], [55.670249, 10.3333283], [22.2793278, 114.1628131], [1.357107, 103.8194992], [50.6402809, 4.6667145], [49.8158683, 6.1296751], [36.1285933, -5.3474761], [46.7985624, 8.2319736], [-4.6574977, 55.4540146], [24.4769288, 90.2934413], [52.2434979, 5.6343227], [19.703182249999998, -79.9174627243246], [26.8234472, 18.1236723], [8.0300284, -1.0800271], [-2.9814344, 23.8222636]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_fba68b29719ab3f5fa522b0a6e270f13);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fba68b29719ab3f5fa522b0a6e270f13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fba68b29719ab3f5fa522b0a6e270f13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fba68b29719ab3f5fa522b0a6e270f13 = L.map(
#                 &quot;map_fba68b29719ab3f5fa522b0a6e270f13&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3a926d735b593316e29b666931b2bf4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fba68b29719ab3f5fa522b0a6e270f13);
#
#
#             var heat_map_747ae017e9e5761e2d40c5c99beb16f9 = L.heatLayer(
#                 [[35.000074, 104.999927], [49.2214561, -2.1358386], [17.250512, -62.6725973], [52.865196, -7.9794599], [32.3293809, -83.1137366], [46.603354, 1.8883335], [22.3511148, 78.6677428], [54.7023545, -3.2765753], [39.7837304, -100.445882], [-28.8166236, 24.991639], [-24.7761086, 134.755], [60.5000209, 9.0999715], [4.5693754, 102.2656823], [36.5748441, 139.2394179], [42.6384261, 12.674297], [23.6585116, -102.0077097], [61.0666922, -107.991707], [59.6749712, 14.5208584], [38.9953683, 21.9877132], [51.1638175, 10.4478313], [47.59397, 14.12456], [55.670249, 10.3333283], [22.2793278, 114.1628131], [1.357107, 103.8194992], [50.6402809, 4.6667145], [49.8158683, 6.1296751], [36.1285933, -5.3474761], [46.7985624, 8.2319736], [-4.6574977, 55.4540146], [24.4769288, 90.2934413], [52.2434979, 5.6343227], [19.703182249999998, -79.9174627243246], [26.8234472, 18.1236723], [8.0300284, -1.0800271], [-2.9814344, 23.8222636]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_fba68b29719ab3f5fa522b0a6e270f13);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # TEMPI ESTRAZIONI

# %%
# Opening JSON file
file_name_time = './../output/output_wiki_time.json'

df_time = pd.read_json(file_name_time)

# %%
df_time
# Out:
#                             name               type  \
# 0               Salesforce, Inc.   [Public company]
# 1                         SAP SE           [Public]
# 2          Microsoft Corporation           [Public]
# 3               TotalEnergies SE           [Public]
# 4          PayPal Holdings, Inc.           [Public]
# ...                          ...                ...
# 997                     Engie SA  [Société Anonyme]
# 998   Siemens Aktiengesellschaft           [Public]
# 999             BNP Paribas S.A.  [Société Anonyme]
# 1000                     Allianz           [Public]
# 1001                   Carrefour  [Société anonyme]
#
#                                                industry  \
# 0     [Cloud computing, Enterprise software, Consult...
# 1     [Enterprise software, Business software, Cloud...
# 2                              [Information technology]
# 3                                   [Petroleum, Energy]
# 4                                [Financial technology]
# ...                                                 ...
# 997                                  [Electric utility]
# 998                                      [Conglomerate]
# 999                                [Financial services]
# 1000                               [Financial services]
# 1001                              [Retail, Wholesaling]
#
#                                                 founded  \
# 0                                    [February 3, 1999]
# 1                                            [Weinheim]
# 2                                 [April 4, 1975,  in ]
# 3                                       [28 March 1924]
# 4                                    [Confinity, X.com]
# ...                                                 ...
# 997                                      [22 July 2008]
# 998                        [Berlin, Kingdom of Prussia]
# 999   [1848,  (Comptoir National d'Escompte de Paris...
# 1000                                  [5 February 1890]
# 1001                                   [1 January 1958]
#
#                                                founders  \
# 0     [Parker Harris, Dave Moellenhoff, Frank Doming...
# 1     [Dietmar Hopp, Hasso Plattner, Klaus Tschira, ...
# 2                              [Bill Gates, Paul Allen]
# 3                                                    []
# 4     [Max Levchin, Peter Thiel, Luke Nosek, Ken How...
# ...                                                 ...
# 997                                                  []
# 998                                [Werner von Siemens]
# 999                                                  []
# 1000                                  [Carl von Thieme]
# 1001                [Marcel Fournier, Jacques Defforey]
#
#                                            headquarters key_people  \
# 0     [Salesforce Tower, San Francisco, California, ...         []
# 1                         [Walldorf, Baden-Württemberg]         []
# 2              [One Microsoft Way, Redmond, Washington]         []
# 3                      [Tour Total, Courbevoie, France]         []
# 4            [San Jose, California, La Vista, Nebraska]         []
# ...                                                 ...        ...
# 997                                [La Défense, France]         []
# 998                                    [Munich, Berlin]         []
# 999             [Boulevard des Italiens, Paris, France]         []
# 1000                                           [Munich]         []
# 1001                                   [Massy, Essonne]         []
#
#                                                services  \
# 0                                     [Cloud computing]
# 1                                 [Applications, Cloud]
# 2     [Azure, Bing, LinkedIn, Yammer, Microsoft 365,...
# 3                                       [Fuel stations]
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998   [Business services, financing, project enginee...
# 999                                                  []
# 1000                                                 []
# 1001  [Cash and carry, warehouse club, discount stor...
#
#                                                 revenue  \
# 0                                          [ ,  (2022)]
# 1                                                   [€]
# 2                                          [ ,  (2022)]
# 3                                          [ ,  (2021)]
# 4                                                 [US$]
# ...                                                 ...
# 997                                                 [€]
# 998                           [ €62.265 billion (2021)]
# 999                                                 [€]
# 1000                                                [€]
# 1001  [ 35.28 billion (France)\n,  21.28 billion (Eu...
#
#                                        operating_income  \
# 0                          [ , US$548 million,  (2022)]
# 1                         [ €4.659 billion (2021), [1]]
# 2                         [ , US$83.4 billion,  (2022)]
# 3                         [ , US$30.5 billion,  (2021)]
# 4                        [ US$4.26 billion (2021), [3]]
# ...                                                 ...
# 997                         [ €5.7 billion (2019), [1]]
# 998                       [ €7.496 billion (2021), [2]]
# 999                        [ €12.2 billion (2021), [2]]
# 1000                      [ €13.40 billion (2021), [1]]
# 1001  [\n,  €2.27 billion (2021), [2], [1], \n,  768...
#
#                          total_assets  \
# 0      [ , US$95.21 billion,  (2022)]
# 1      [ €71.173 billion (2021), [1]]
# 2      [ , US$364.8 billion,  (2022)]
# 3      [ , US$320.5 billion,  (2021)]
# 4     [ US$75.80 billion (2021), [3]]
# ...                               ...
# 997     [ €159.8 billion (2019), [1]]
# 998   [ €139.608 billion (2021), [2]]
# 999      [ €2.6 trillion (2021), [2]]
# 1000    [ €1.14 trillion (2021), [1]]
# 1001    [ €47.67 billion (2021), [2]]
#
#                                     number_of_employees  \
# 0                                [73,542 (August 2022)]
# 1                                 [107,415 (2021), [1]]
# 2                                      [221,000 (2022)]
# 3                                 [105,476 (2020), [2]]
# 4                           [c.,  30,900,  (2021), [3]]
# ...                                                 ...
# 997                                    [171,100 (2019)]
# 998                               [303,000 (2021), [2]]
# 999                               [190,000 (2022), [2]]
# 1000                              [155,411 (2021), [1]]
# 1001  [\n,  319,565 , (2021), [1], \n,  115,310 (, L...
#
#                     website      time
# 0        [salesforce, .com]  0.055215
# 1         [www, .sap, .com]  0.087919
# 2           [microsoft.com]  0.161741
# 3     [totalenergies, .com]  0.120914
# 4      [www, .paypal, .com]  0.093921
# ...                     ...       ...
# 997      [engie, .com, /en]  0.080023
# 998   [www, .siemens, .com]  0.121239
# 999      [group.bnpparibas]  0.068112
# 1000        [allianz, .com]  0.089607
# 1001    [www.carrefour.com]  0.088403
#
# [1002 rows x 14 columns]
#                             name               type  \
# 0               Salesforce, Inc.   [Public company]
# 1                         SAP SE           [Public]
# 2          Microsoft Corporation           [Public]
# 3               TotalEnergies SE           [Public]
# 4          PayPal Holdings, Inc.           [Public]
# ...                          ...                ...
# 997                     Engie SA  [Société Anonyme]
# 998   Siemens Aktiengesellschaft           [Public]
# 999             BNP Paribas S.A.  [Société Anonyme]
# 1000                     Allianz           [Public]
# 1001                   Carrefour  [Société anonyme]
#
#                                                industry  \
# 0     [Cloud computing, Enterprise software, Consult...
# 1     [Enterprise software, Business software, Cloud...
# 2                              [Information technology]
# 3                                   [Petroleum, Energy]
# 4                                [Financial technology]
# ...                                                 ...
# 997                                  [Electric utility]
# 998                                      [Conglomerate]
# 999                                [Financial services]
# 1000                               [Financial services]
# 1001                              [Retail, Wholesaling]
#
#                                                 founded  \
# 0                                    [February 3, 1999]
# 1                                            [Weinheim]
# 2                                 [April 4, 1975,  in ]
# 3                                       [28 March 1924]
# 4                                    [Confinity, X.com]
# ...                                                 ...
# 997                                      [22 July 2008]
# 998                        [Berlin, Kingdom of Prussia]
# 999   [1848,  (Comptoir National d'Escompte de Paris...
# 1000                                  [5 February 1890]
# 1001                                   [1 January 1958]
#
#                                                founders  \
# 0     [Parker Harris, Dave Moellenhoff, Frank Doming...
# 1     [Dietmar Hopp, Hasso Plattner, Klaus Tschira, ...
# 2                              [Bill Gates, Paul Allen]
# 3                                                    []
# 4     [Max Levchin, Peter Thiel, Luke Nosek, Ken How...
# ...                                                 ...
# 997                                                  []
# 998                                [Werner von Siemens]
# 999                                                  []
# 1000                                  [Carl von Thieme]
# 1001                [Marcel Fournier, Jacques Defforey]
#
#                                            headquarters key_people  \
# 0     [Salesforce Tower, San Francisco, California, ...         []
# 1                         [Walldorf, Baden-Württemberg]         []
# 2              [One Microsoft Way, Redmond, Washington]         []
# 3                      [Tour Total, Courbevoie, France]         []
# 4            [San Jose, California, La Vista, Nebraska]         []
# ...                                                 ...        ...
# 997                                [La Défense, France]         []
# 998                                    [Munich, Berlin]         []
# 999             [Boulevard des Italiens, Paris, France]         []
# 1000                                           [Munich]         []
# 1001                                   [Massy, Essonne]         []
#
#                                                services  \
# 0                                     [Cloud computing]
# 1                                 [Applications, Cloud]
# 2     [Azure, Bing, LinkedIn, Yammer, Microsoft 365,...
# 3                                       [Fuel stations]
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998   [Business services, financing, project enginee...
# 999                                                  []
# 1000                                                 []
# 1001  [Cash and carry, warehouse club, discount stor...
#
#                                                 revenue  \
# 0                                          [ ,  (2022)]
# 1                                                   [€]
# 2                                          [ ,  (2022)]
# 3                                          [ ,  (2021)]
# 4                                                 [US$]
# ...                                                 ...
# 997                                                 [€]
# 998                           [ €62.265 billion (2021)]
# 999                                                 [€]
# 1000                                                [€]
# 1001  [ 35.28 billion (France)\n,  21.28 billion (Eu...
#
#                                        operating_income  \
# 0                          [ , US$548 million,  (2022)]
# 1                         [ €4.659 billion (2021), [1]]
# 2                         [ , US$83.4 billion,  (2022)]
# 3                         [ , US$30.5 billion,  (2021)]
# 4                        [ US$4.26 billion (2021), [3]]
# ...                                                 ...
# 997                         [ €5.7 billion (2019), [1]]
# 998                       [ €7.496 billion (2021), [2]]
# 999                        [ €12.2 billion (2021), [2]]
# 1000                      [ €13.40 billion (2021), [1]]
# 1001  [\n,  €2.27 billion (2021), [2], [1], \n,  768...
#
#                          total_assets  \
# 0      [ , US$95.21 billion,  (2022)]
# 1      [ €71.173 billion (2021), [1]]
# 2      [ , US$364.8 billion,  (2022)]
# 3      [ , US$320.5 billion,  (2021)]
# 4     [ US$75.80 billion (2021), [3]]
# ...                               ...
# 997     [ €159.8 billion (2019), [1]]
# 998   [ €139.608 billion (2021), [2]]
# 999      [ €2.6 trillion (2021), [2]]
# 1000    [ €1.14 trillion (2021), [1]]
# 1001    [ €47.67 billion (2021), [2]]
#
#                                     number_of_employees  \
# 0                                [73,542 (August 2022)]
# 1                                 [107,415 (2021), [1]]
# 2                                      [221,000 (2022)]
# 3                                 [105,476 (2020), [2]]
# 4                           [c.,  30,900,  (2021), [3]]
# ...                                                 ...
# 997                                    [171,100 (2019)]
# 998                               [303,000 (2021), [2]]
# 999                               [190,000 (2022), [2]]
# 1000                              [155,411 (2021), [1]]
# 1001  [\n,  319,565 , (2021), [1], \n,  115,310 (, L...
#
#                     website      time
# 0        [salesforce, .com]  0.055215
# 1         [www, .sap, .com]  0.087919
# 2           [microsoft.com]  0.161741
# 3     [totalenergies, .com]  0.120914
# 4      [www, .paypal, .com]  0.093921
# ...                     ...       ...
# 997      [engie, .com, /en]  0.080023
# 998   [www, .siemens, .com]  0.121239
# 999      [group.bnpparibas]  0.068112
# 1000        [allianz, .com]  0.089607
# 1001    [www.carrefour.com]  0.088403
#
# [1002 rows x 14 columns]

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(100).index, df_time.head(100)['time'], color='blue')

# %%
times = [[100, df_time.head(100)['time'].min(), df_time.head(100)['time'].mean(), df_time.head(500)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table
# Out:
#    Estrazioni    Minimo     Media   Mediana   Massimo
# 0         100  0.016642  0.068308  0.044878  0.465123
#    Estrazioni    Minimo     Media   Mediana   Massimo
# 0         100  0.016642  0.068308  0.044878  0.465123

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(500).index, df_time.head(500)['time'], color='blue')

# %%
times = [[500, df_time.head(500)['time'].min(), df_time.head(500)['time'].mean(), df_time.head(500)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table
# Out:
#    Estrazioni    Minimo     Media   Mediana   Massimo
# 0         500  0.011323  0.058232  0.044878  0.465123
#    Estrazioni    Minimo     Media   Mediana   Massimo
# 0         500  0.011323  0.058232  0.044878  0.465123

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(1000).index, df_time.head(1000)['time'], color='blue')

# %%
times = [[1000, df_time.head(1000)['time'].min(), df_time.head(1000)['time'].mean(), df_time.head(1000)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table
# Out:
#    Estrazioni    Minimo     Media   Mediana   Massimo
# 0        1000  0.011323  0.059584  0.046055  0.465123
#    Estrazioni    Minimo     Media   Mediana   Massimo
# 0        1000  0.011323  0.059584  0.046055  0.465123

# %%
# print(df_table.Massimo)
time = df_time.head(1)['time'].astype('float').values[0]
value = df_table.Massimo.values[0]
mask = df_time['time'].astype('float') == value
filtered_df = df_time[df_time['time']== value]
filtered_df
# Out:
#            name      type                                           industry  \
# 971  Apple Inc.  [Public]  [Consumer electronics, Software services, Onli...
#
#                      founded                                   founders  \
# 971  [Los Altos, California]  [Steve Jobs, Steve Wozniak, Ronald Wayne]
#
#            headquarters key_people  \
# 971  [1 Apple Park Way]         []
#
#                                               services       revenue  \
# 971  [App Store, Apple Card, Apple Music, Apple TV+...  [ ,  (2022)]
#
#                     operating_income                     total_assets  \
# 971  [ , US$119.44 billion,  (2022)]  [ , US$352.76 billion,  (2022)]
#
#     number_of_employees website      time
# 971    [164,000 (2022)]     [ ]  0.465123
#            name      type                                           industry  \
# 971  Apple Inc.  [Public]  [Consumer electronics, Software services, Onli...
#
#                      founded                                   founders  \
# 971  [Los Altos, California]  [Steve Jobs, Steve Wozniak, Ronald Wayne]
#
#            headquarters key_people  \
# 971  [1 Apple Park Way]         []
#
#                                               services       revenue  \
# 971  [App Store, Apple Card, Apple Music, Apple TV+...  [ ,  (2022)]
#
#                     operating_income                     total_assets  \
# 971  [ , US$119.44 billion,  (2022)]  [ , US$352.76 billion,  (2022)]
#
#     number_of_employees website      time
# 971    [164,000 (2022)]     [ ]  0.465123
