# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy

# %%
file_name = './../output/output_disfold.json'

df = pd.read_json(file_name)

# %%
df
# Out:
#                                             name market_cap stock  \
# 0                        Avis Budget Group, Inc.   $18.12 B   CAR
# 1                        Croda International plc   $19.22 B  CRDA
# 2                    Power Corporation of Canada   $21.48 B   POW
# 3                                    Twilio Inc.   $26.09 B  TWLO
# 4                           Telefônica Brasil SA   $20.19 B   VIV
# ..                                           ...        ...   ...
# 993                            HDFC Bank Limited  $115.68 B   HDB
# 994                              BlackRock, Inc.  $115.98 B   BLK
# 995                                 Unilever plc  $117.84 B  ULVR
# 996  International Business Machines Corporation  $119.20 B   IBM
# 997                                 Anthem, Inc.  $119.80 B  ANTM
#
#             country                    sector  \
# 0     United States               Industrials
# 1    United Kingdom           Basic Materials
# 2            Canada                Financials
# 3     United States    Communication Services
# 4            Brazil    Communication Services
# ..              ...                       ...
# 993           India                Financials
# 994   United States                Financials
# 995  United Kingdom          Consumer Staples
# 996   United States                Technology
# 997   United States                Healthcare
#
#                               industry                  headquarters  \
# 0            Rental & Leasing Services    Parsippany,NJ,UnitedStates
# 1                  Specialty Chemicals           Goole,UnitedKingdom
# 2                       Insurance—Life           MontrÃ©al,QC,Canada
# 3       Internet Content & Information  SanFrancisco,CA,UnitedStates
# 4                     Telecom Services           SÃ£oPaulo,SP,Brazil
# ..                                 ...                           ...
# 993                              Banks                  Mumbai,India
# 994                   Asset Management       NewYork,NY,UnitedStates
# 995      Household & Personal Products          London,UnitedKingdom
# 996    Information Technology Services        Armonk,NY,UnitedStates
# 997                   Healthcare Plans  Indianapolis,IN,UnitedStates
#
#                                                founded employees  \
# 0                                                2006     16,000
# 1                                                 1925     4,000
# 2                                                 1925    30,000
# 3                                                 2008     7,867
# 4                                                 1998    34,000
# ..                                                 ...       ...
# 993                                                      134,412
# 994                                               1988    18,400
# 995                                   2 September 1929   148,012
# 996                                      June 16, 1911   282,100
# 997   Anthem and WellPoint Health Networks merger i...    98,200
#
#                               ceo
# 0           Mr. Joseph A. Ferraro
# 1
# 2          Mr. Robert Jeffrey Orr
# 3             Mr. Jeffrey  Lawson
# 4     Mr. Christian  Mauad Gebara
# ..                            ...
# 993      Mr. Sashidhar  Jagdishan
# 994     Mr. Laurence Douglas Fink
# 995              Mr. Alan W. Jope
# 996           Mr. Arvind  Krishna
# 997    Ms. Gail Koziara Boudreaux
#
# [998 rows x 10 columns]

# %%
df = df.applymap(lambda x: None if len(x)==0 else x)

# %%
df
# Out:
#                                             name market_cap stock  \
# 0                        Avis Budget Group, Inc.   $18.12 B   CAR
# 1                        Croda International plc   $19.22 B  CRDA
# 2                    Power Corporation of Canada   $21.48 B   POW
# 3                                    Twilio Inc.   $26.09 B  TWLO
# 4                           Telefônica Brasil SA   $20.19 B   VIV
# ..                                           ...        ...   ...
# 993                            HDFC Bank Limited  $115.68 B   HDB
# 994                              BlackRock, Inc.  $115.98 B   BLK
# 995                                 Unilever plc  $117.84 B  ULVR
# 996  International Business Machines Corporation  $119.20 B   IBM
# 997                                 Anthem, Inc.  $119.80 B  ANTM
#
#             country                    sector  \
# 0     United States               Industrials
# 1    United Kingdom           Basic Materials
# 2            Canada                Financials
# 3     United States    Communication Services
# 4            Brazil    Communication Services
# ..              ...                       ...
# 993           India                Financials
# 994   United States                Financials
# 995  United Kingdom          Consumer Staples
# 996   United States                Technology
# 997   United States                Healthcare
#
#                               industry                  headquarters  \
# 0            Rental & Leasing Services    Parsippany,NJ,UnitedStates
# 1                  Specialty Chemicals           Goole,UnitedKingdom
# 2                       Insurance—Life           MontrÃ©al,QC,Canada
# 3       Internet Content & Information  SanFrancisco,CA,UnitedStates
# 4                     Telecom Services           SÃ£oPaulo,SP,Brazil
# ..                                 ...                           ...
# 993                              Banks                  Mumbai,India
# 994                   Asset Management       NewYork,NY,UnitedStates
# 995      Household & Personal Products          London,UnitedKingdom
# 996    Information Technology Services        Armonk,NY,UnitedStates
# 997                   Healthcare Plans  Indianapolis,IN,UnitedStates
#
#                                                founded employees  \
# 0                                                2006     16,000
# 1                                                 1925     4,000
# 2                                                 1925    30,000
# 3                                                 2008     7,867
# 4                                                 1998    34,000
# ..                                                 ...       ...
# 993                                               None   134,412
# 994                                               1988    18,400
# 995                                   2 September 1929   148,012
# 996                                      June 16, 1911   282,100
# 997   Anthem and WellPoint Health Networks merger i...    98,200
#
#                               ceo
# 0           Mr. Joseph A. Ferraro
# 1                            None
# 2          Mr. Robert Jeffrey Orr
# 3             Mr. Jeffrey  Lawson
# 4     Mr. Christian  Mauad Gebara
# ..                            ...
# 993      Mr. Sashidhar  Jagdishan
# 994     Mr. Laurence Douglas Fink
# 995              Mr. Alan W. Jope
# 996           Mr. Arvind  Krishna
# 997    Ms. Gail Koziara Boudreaux
#
# [998 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# name              0
# market_cap        0
# stock             0
# country           0
# sector            0
# industry          0
# headquarters      5
# founded         420
# employees        42
# ceo             165
# dtype: int64

# %%
print("Number of cells:", df.size)
print("Number of value None:", df.isnull().sum().sum())
print("Number of row:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of cells: 9980
# Number of value None: 632
# Number of row: 998
# Number of columns: 10

# %%
print(df['sector'].value_counts())
# Out:
#   Financials                183
#   Industrials               137
#   Technology                126
#   Healthcare                104
#   Consumer Discretionary     91
#   Consumer Staples           74
#   Communication Services     66
#   Basic Materials            64
#   Energy                     56
#   Utilities                  46
#   Real Estate                39
# Utilities                     2
# Consumer Discretionary        1
# Communication Services        1
# Basic Materials               1
#  Financials                   1
#  Technology                   1
# Healthcare                    1
#  Communication Services       1
#    Basic Materials            1
# Energy                        1
# Energy                        1
# Name: sector, dtype: int64

# %%
sector_company = df['sector'].value_counts()
keys = sector_company.index
values = sector_company.values


fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("sector")
plt.xlabel("number of companies")
plt.show()

# %%
employees = {'<100.000': 0, '100.000-200.000': 0, '200.000-300.000': 0, '>300.000':0 }
for s in df.employees.values:
    if s is not None:
        k = s.replace(",", "")
        k = int(k)
        if(k < 100000):
            employees['<100.000'] +=1
        elif(k >100000 and k < 200000):
            employees['100.000-200.000'] +=1
        elif(k >200000 and k < 300000):
            employees['200.000-300.000'] +=1
        else:
            employees['>300.000'] +=1


print(employees)
            
companies_employees = pd.Series(employees)
keys = companies_employees.index
values = companies_employees.values
print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.05, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("number of employees")
plt.xlabel("number of companies")
plt.show()
# Out:
# {'<100.000': 794, '100.000-200.000': 93, '200.000-300.000': 32, '>300.000': 37}
# Index(['<100.000', '100.000-200.000', '200.000-300.000', '>300.000'], dtype='object')
# [794  93  32  37]

# %%
import re
companies_to_date = {'<1950': 0, '1950-2000': 0, '>2000': 0}
for s in df.founded.values:
    if s is not None:
        date = re.findall(r'[0-9][0-9][0-9][0-9]',s)
        date = date[0]
        year = int(date)
        if year<1950:
            companies_to_date['<1950'] += 1
        elif 1950 < year < 2000:
            companies_to_date['1950-2000'] += 1
        else:
            companies_to_date['>2000'] += 1
    
print(companies_to_date)
 
companies_to_date = pd.Series(companies_to_date)
keys = companies_to_date.index
values = companies_to_date.values
print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.05, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("fondation date")
plt.xlabel("number of companies")
plt.show()
# Out:
# {'<1950': 213, '1950-2000': 258, '>2000': 108}
# Index(['<1950', '1950-2000', '>2000'], dtype='object')
# [213 258 108]

# %%
print(df['industry'].value_counts())
# Out:
#   Banks                             88
#   Telecom Services                  30
#   Specialty Industrial Machinery    30
#   Software—Application              25
#   Semiconductors                    25
#                                     ..
#   REIT—Diversified                   1
#  Semiconductors                      1
#    Utilities—Renewable               1
#   Trucking                           1
#   Financial Conglomerates            1
# Name: industry, Length: 139, dtype: int64

# %%
sector_company = df['industry'].value_counts().head(20)
keys = sector_company.index
values = sector_company.values


fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("industry")
plt.xlabel("number of companies")
plt.show()
