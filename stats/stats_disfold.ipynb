# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy

# %%
file_name = './output_disfold.json'

df = pd.read_json(file_name)

# %%
df
# Out:
#                                             name market_cap stock  \
# 0                        Avis Budget Group, Inc.   $18.12 B   CAR
# 1                           Telefônica Brasil SA   $20.19 B   VIV
# 2                     East Japan Railway Company   $22.78 B  9020
# 3                                    Twilio Inc.   $26.09 B  TWLO
# 4                        Delta Electronics, Inc.   $24.05 B  2308
# ..                                           ...        ...   ...
# 995                                 Unilever plc  $117.84 B  ULVR
# 996  International Business Machines Corporation  $119.20 B   IBM
# 997                                 Anthem, Inc.  $119.80 B  ANTM
# 998                      Applied Materials, Inc.  $121.12 B  AMAT
# 999                               Prologis, Inc.  $121.20 B   PLD
#
#             country                  sector  \
# 0     United States             Industrials
# 1            Brazil  Communication Services
# 2             Japan             Industrials
# 3     United States  Communication Services
# 4            Taiwan              Technology
# ..              ...                     ...
# 995  United Kingdom        Consumer Staples
# 996   United States              Technology
# 997   United States              Healthcare
# 998   United States              Technology
# 999   United States             Real Estate
#
#                                 industry                  headquarters  \
# 0              Rental & Leasing Services    Parsippany,NJ,UnitedStates
# 1                       Telecom Services           SÃ£oPaulo,SP,Brazil
# 2                              Railroads                   Tokyo,Japan
# 3         Internet Content & Information  SanFrancisco,CA,UnitedStates
# 4                  Electronic Components                 Taipei,Taiwan
# ..                                   ...                           ...
# 995        Household & Personal Products          London,UnitedKingdom
# 996      Information Technology Services        Armonk,NY,UnitedStates
# 997                     Healthcare Plans  Indianapolis,IN,UnitedStates
# 998  Semiconductor Equipment & Materials    SantaClara,CA,UnitedStates
# 999                      REIT—Industrial  SanFrancisco,CA,UnitedStates
#
#                                                founded employees  \
# 0                                                2006     16,000
# 1                                                 1998    34,000
# 2                                                         71,973
# 3                                                 2008     7,867
# 4
# ..                                                 ...       ...
# 995                                   2 September 1929   148,012
# 996                                      June 16, 1911   282,100
# 997   Anthem and WellPoint Health Networks merger i...    98,200
# 998                                  November 10, 1967    28,500
# 999                                               1983     2,053
#
#                               ceo
# 0           Mr. Joseph A. Ferraro
# 1     Mr. Christian  Mauad Gebara
# 2              Mr. Yuji  Fukasawa
# 3             Mr. Jeffrey  Lawson
# 4                 Mr. Ping  Cheng
# ..                            ...
# 995              Mr. Alan W. Jope
# 996           Mr. Arvind  Krishna
# 997    Ms. Gail Koziara Boudreaux
# 998         Mr. Gary E. Dickerson
# 999         Mr. Hamid R. Moghadam
#
# [1000 rows x 10 columns]

# %%
df = df.applymap(lambda x: None if len(x)==0 else x)

# %%
df
# Out:
#                                             name market_cap stock  \
# 0                        Avis Budget Group, Inc.   $18.12 B   CAR
# 1                           Telefônica Brasil SA   $20.19 B   VIV
# 2                     East Japan Railway Company   $22.78 B  9020
# 3                                    Twilio Inc.   $26.09 B  TWLO
# 4                        Delta Electronics, Inc.   $24.05 B  2308
# ..                                           ...        ...   ...
# 995                                 Unilever plc  $117.84 B  ULVR
# 996  International Business Machines Corporation  $119.20 B   IBM
# 997                                 Anthem, Inc.  $119.80 B  ANTM
# 998                      Applied Materials, Inc.  $121.12 B  AMAT
# 999                               Prologis, Inc.  $121.20 B   PLD
#
#             country                  sector  \
# 0     United States             Industrials
# 1            Brazil  Communication Services
# 2             Japan             Industrials
# 3     United States  Communication Services
# 4            Taiwan              Technology
# ..              ...                     ...
# 995  United Kingdom        Consumer Staples
# 996   United States              Technology
# 997   United States              Healthcare
# 998   United States              Technology
# 999   United States             Real Estate
#
#                                 industry                  headquarters  \
# 0              Rental & Leasing Services    Parsippany,NJ,UnitedStates
# 1                       Telecom Services           SÃ£oPaulo,SP,Brazil
# 2                              Railroads                   Tokyo,Japan
# 3         Internet Content & Information  SanFrancisco,CA,UnitedStates
# 4                  Electronic Components                 Taipei,Taiwan
# ..                                   ...                           ...
# 995        Household & Personal Products          London,UnitedKingdom
# 996      Information Technology Services        Armonk,NY,UnitedStates
# 997                     Healthcare Plans  Indianapolis,IN,UnitedStates
# 998  Semiconductor Equipment & Materials    SantaClara,CA,UnitedStates
# 999                      REIT—Industrial  SanFrancisco,CA,UnitedStates
#
#                                                founded employees  \
# 0                                                2006     16,000
# 1                                                 1998    34,000
# 2                                                 None    71,973
# 3                                                 2008     7,867
# 4                                                 None      None
# ..                                                 ...       ...
# 995                                   2 September 1929   148,012
# 996                                      June 16, 1911   282,100
# 997   Anthem and WellPoint Health Networks merger i...    98,200
# 998                                  November 10, 1967    28,500
# 999                                               1983     2,053
#
#                               ceo
# 0           Mr. Joseph A. Ferraro
# 1     Mr. Christian  Mauad Gebara
# 2              Mr. Yuji  Fukasawa
# 3             Mr. Jeffrey  Lawson
# 4                 Mr. Ping  Cheng
# ..                            ...
# 995              Mr. Alan W. Jope
# 996           Mr. Arvind  Krishna
# 997    Ms. Gail Koziara Boudreaux
# 998         Mr. Gary E. Dickerson
# 999         Mr. Hamid R. Moghadam
#
# [1000 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# name              0
# market_cap        0
# stock             0
# country           0
# sector            0
# industry          0
# headquarters      5
# founded         421
# employees        42
# ceo             165
# dtype: int64

# %%
print("Number of cells:", df.size)
print("Number of value None:", df.isnull().sum().sum())
print("Number of row:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of cells: 10000
# Number of value None: 633
# Number of row: 1000
# Number of columns: 10

# %%
print(df['sector'].value_counts())
# Out:
# Financials                                                                                            184
# Industrials                                                                                           138
# Technology                                                                                            126
# Healthcare                                                                                            104
# Consumer Discretionary                                                                                 91
# Consumer Staples                                                                                       74
# Communication Services                                                                                 66
# Basic Materials                                                                                        64
# Energy                                                                                                 55
# Utilities                                                                                              44
# Real Estate                                                                                            39
#                                         Utilities                                                       4
#                                         Energy                                                          3
#                                         Basic Materials                                                 2
#                                         Communication Services                                          2
#                                         Technology                                                      1
#                                         Financials                                                      1
#                                         Healthcare                                                      1
#                                         Consumer Discretionary                                          1
# Name: sector, dtype: int64

# %%
sector_company = df['sector'].value_counts()
keys = sector_company.index
values = sector_company.values


fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("sector")
plt.xlabel("number of companies")
plt.show()

# %%
employees = {'<100.000': 0, '100.000-200.000': 0, '200.000-300.000': 0, '>300.000':0 }
for s in df.employees.values:
    if s is not None:
        k = s.replace(",", "")
        k = int(k)
        if(k < 100000):
            employees['<100.000'] +=1
        elif(k >100000 and k < 200000):
            employees['100.000-200.000'] +=1
        elif(k >200000 and k < 300000):
            employees['200.000-300.000'] +=1
        else:
            employees['>300.000'] +=1


print(employees)
            
companies_employees = pd.Series(employees)
keys = companies_employees.index
values = companies_employees.values
print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.05, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("number of employees")
plt.xlabel("number of companies")
plt.show()
# Out:
# {'<100.000': 795, '100.000-200.000': 94, '200.000-300.000': 32, '>300.000': 37}
# Index(['<100.000', '100.000-200.000', '200.000-300.000', '>300.000'], dtype='object')
# [795  94  32  37]

# %%
employees = {'<100.000': 0, '100.000-200.000': 0, '200.000-300.000': 0, '>300.000':0 }

for s in df.employees.values:

    if s is not None:

        k = s.replace(",", "")

        k = int(k)

        if(k < 100000):

            employees['<100.000'] +=1

        elif(k >100000 and k < 200000):

            employees['100.000-200.000'] +=1

        elif(k >200000 and k < 300000):

            employees['200.000-300.000'] +=1

        else:

            employees['>300.000'] +=1

           

companies_employees = pd.Series(employees)

keys = companies_employees.index

values = companies_employees.values

plt.rcParams.update({'font.size': 22})

plt.title("Globaldata")

#graph with mathplotlib

fig, ax = plt.subplots()

width = 0.75

#fig.set_size_inches(10, 5)

#ind = np.arange(len(values))

ax.barh(keys, values, width, color = "green")



for i, v in enumerate(values):

    ax.text(v + 1, i - 0.05, str(v),

            color = 'green', fontweight = 'bold')



plt.ylabel("number of employees")

plt.xlabel("number of companies")

plt.tick_params(axis='both', which='major', labelsize=20)

plt.show()

# %%
import re
companies_to_date = {'<1950': 0, '1950-2000': 0, '>2000': 0}
for s in df.founded.values:
    if s is not None:
        date = re.findall(r'[0-9][0-9][0-9][0-9]',s)
        date = date[0]
        year = int(date)
        if year<1950:
            companies_to_date['<1950'] += 1
        elif 1950 < year < 2000:
            companies_to_date['1950-2000'] += 1
        else:
            companies_to_date['>2000'] += 1
    
print(companies_to_date)
 
companies_to_date = pd.Series(companies_to_date)
keys = companies_to_date.index
values = companies_to_date.values
print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.05, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("fondation date")
plt.xlabel("number of companies")
plt.show()
# Out:
# {'<1950': 213, '1950-2000': 258, '>2000': 108}
# Index(['<1950', '1950-2000', '>2000'], dtype='object')
# [213 258 108]

# %%
print(df['industry'].value_counts())
# Out:
# Banks                                                                                89
# Specialty Industrial Machinery                                                       30
# Telecom Services                                                                     30
# Semiconductors                                                                       25
# Software—Application                                                                 25
#                                                                                      ..
# Furnishings, Fixtures & Appliances                                                    1
# REIT—Diversified                                                                      1
# Trucking                                                                              1
#                                         Steel                                         1
# Financial Conglomerates                                                               1
# Name: industry, Length: 138, dtype: int64

# %%
sector_company = df['industry'].value_counts().head(20)
keys = sector_company.index
values = sector_company.values


fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("industry")
plt.xlabel("number of companies")
plt.show()

# %%
import numpy as np

# %%
df.country.values
# Out:
# array(['United States', 'United Kingdom', 'Brazil', 'Taiwan', 'Canada',
#        'United States', 'Japan', 'United States', 'South Korea',
#        'United States', 'United States', 'United States', 'Japan',
#        'Australia', 'United States', 'United States', 'United Kingdom',
#        'Switzerland', 'Australia', 'United States', 'United States',
#        'Canada', 'United States', 'United States', 'United States',
#        'United States', 'United States', 'United States', 'United States',
#        'China', 'France', 'China', 'Canada', 'Japan', 'United States',
#        'France', 'United States', 'Australia', 'United States', 'France',
#        'Canada', 'United States', 'Japan', 'United States',
#        'United States', 'United States', 'Switzerland', 'Canada',
#        'United States', 'Canada', 'United States', 'United States',
#        'United States', 'Australia', 'United States', 'China',
#        'United States', 'Germany', 'Germany', 'Canada', 'France',
#        'Canada', 'United States', 'China', 'United Kingdom',
#        'United States', 'United States', 'France', 'United States',
#        'United States', 'United States', 'Japan', 'Denmark',
#        'South Korea', 'Japan', 'United States', 'United States',
#        'United States', 'United States', 'United States', 'United States',
#        'India', 'Singapore', 'China', 'United States', 'Switzerland',
#        'Australia', 'United States', 'United States', 'United States',
#        'United States', 'Germany', 'Japan', 'Spain', 'United States',
#        'Russia', 'Switzerland', 'United States', 'Mexico', 'France',
#        'United States', 'Italy', 'France', 'United States',
#        'United States', 'United Kingdom', 'Germany', 'United States',
#        'Indonesia', 'Mexico', 'United States', 'United States', 'Japan',
#        'United States', 'United Kingdom', 'Germany', 'China',
#        'United States', 'United States', 'Canada', 'Saudi Arabia',
#        'China', 'United Kingdom', 'United States', 'Canada', 'Japan',
#        'China', 'United States', 'Brazil', 'United States',
#        'United States', 'United States', 'France', 'Bermuda',
#        'United Kingdom', 'United States', 'France', 'China',
#        'Saudi Arabia', 'United States', 'China', 'United Kingdom',
#        'Australia', 'United States', 'United States', 'United States',
#        'Hong Kong', 'China', 'United States', 'Germany', 'Canada',
#        'Hong Kong', 'Netherlands', 'Sweden', 'Germany', 'Spain',
#        'United States', 'Ireland', 'United States', 'United States',
#        'United States', 'Japan', 'United States', 'Singapore',
#        'United States', 'United States', 'United States', 'United States',
#        'Argentina', 'United States', 'France', 'United States', 'Russia',
#        'United States', 'China', 'Australia', 'Taiwan', 'United States',
#        'United States', 'United Kingdom', 'United States',
#        'United States', 'Japan', 'Japan', 'Canada', 'Netherlands',
#        'Italy', 'Japan', 'United States', 'Netherlands', 'Japan',
#        'United States', 'United States', 'United States', 'Germany',
#        'Canada', 'United Kingdom', 'Switzerland', 'United States',
#        'Italy', 'United States', 'United States', 'United States',
#        'United States', 'Canada', 'Brazil', 'Netherlands', 'Japan',
#        'United States', 'United States', 'Japan', 'Japan',
#        'United Kingdom', 'China', 'India', 'South Korea', 'Japan',
#        'United States', 'United States', 'United States', 'United States',
#        'United States', 'Switzerland', 'Italy', 'Russia', 'Saudi Arabia',
#        'Japan', 'United States', 'United States', 'Germany',
#        'United States', 'United States', 'United Kingdom',
#        'United States', 'United States', 'United States', 'Japan',
#        'China', 'Switzerland', 'Germany', 'Japan', 'Brazil',
#        'United States', 'United States', 'United States', 'Russia',
#        'United States', 'United States', 'South Africa', 'United States',
#        'Mexico', 'United States', 'Ireland', 'United States', 'Canada',
#        'United States', 'Russia', 'United States', 'Canada', 'Taiwan',
#        'Australia', 'Japan', 'China', 'Singapore', 'United States',
#        'United States', 'United States', 'Hong Kong', 'United States',
#        'China', 'United States', 'Singapore', 'United States',
#        'United States', 'United States', 'United States', 'United States',
#        'China', 'United States', 'Netherlands', 'Russia', 'Hong Kong',
#        'United States', 'United States', 'United States', 'United States',
#        'Switzerland', 'Germany', 'Canada', 'United States',
#        'United States', 'China', 'United States', 'Denmark', 'Japan',
#        'United States', 'United States', 'China', 'United States',
#        'China', 'Japan', 'United States', 'Australia', 'China',
#        'United States', 'United States', 'Japan', 'United States',
#        'Canada', 'United States', 'United Kingdom', 'Australia',
#        'United States', 'Ireland', 'United States', 'Finland', 'China',
#        'United States', 'China', 'United States', 'France',
#        'United States', 'United States', 'United States', 'United States',
#        'Canada', 'China', 'Canada', 'China', 'United States', 'Germany',
#        'China', 'China', 'Japan', 'United States', 'Japan', 'Ireland',
#        'United States', 'United States', 'Indonesia', 'France',
#        'United Kingdom', 'Japan', 'France', 'United States',
#        'United States', 'France', 'Sweden', 'China', 'United States',
#        'Spain', 'United States', 'Colombia', 'Switzerland',
#        'United Kingdom', 'Denmark', 'Switzerland', 'United States',
#        'Canada', 'Japan', 'United States', 'France', 'Germany', 'Canada',
#        'Ireland', 'United States', 'Canada', 'United States',
#        'United States', 'Hong Kong', 'Sweden', 'United States', 'China',
#        'Netherlands', 'Thailand', 'Japan', 'United States', 'China',
#        'Hong Kong', 'Japan', 'Switzerland', 'United States',
#        'United States', 'United States', 'United States', 'Taiwan',
#        'United States', 'China', 'United States', 'Japan',
#        'United States', 'Australia', 'Austria', 'United States',
#        'United States', 'United States', 'Luxembourg', 'Hong Kong',
#        'China', 'United States', 'United States', 'United States',
#        'Hong Kong', 'United States', 'Canada', 'United States', 'Italy',
#        'Sweden', 'Australia', 'Germany', 'United States', 'Canada',
#        'United States', 'United States', 'Finland', 'China',
#        'United States', 'France', 'Canada', 'China', 'United States',
#        'Germany', 'China', 'United States', 'China', 'Taiwan',
#        'Netherlands', 'Switzerland', 'United States', 'Japan', 'Ireland',
#        'Hong Kong', 'United States', 'China', 'Japan', 'United States',
#        'Australia', 'United States', 'United States', 'United States',
#        'Indonesia', 'Japan', 'China', 'United States', 'China', 'Brazil',
#        'United States', 'China', 'United Kingdom', 'Singapore', 'China',
#        'Spain', 'Hong Kong', 'China', 'Hong Kong', 'United States',
#        'United States', 'United States', 'China', 'United States',
#        'Switzerland', 'Canada', 'United States', 'Japan', 'Germany',
#        'Canada', 'United States', 'United States', 'France',
#        'United States', 'United States', 'United States', 'United States',
#        'Sweden', 'China', 'Germany', 'Sweden', 'Japan', 'United States',
#        'China', 'China', 'United States', 'Switzerland', 'United States',
#        'Taiwan', 'Russia', 'United States', 'China', 'China', 'Japan',
#        'United States', 'Finland', 'China', 'United States',
#        'United States', 'Germany', 'United States', 'Finland', 'Spain',
#        'United States', 'Netherlands', 'United States', 'Switzerland',
#        'Thailand', 'Canada', 'Netherlands', 'United States',
#        'Netherlands', 'Saudi Arabia', 'Denmark', 'China', 'United States',
#        'United States', 'United States', 'Japan', 'United States',
#        'United States', 'China', 'Japan', 'France', 'China',
#        'United States', 'China', 'United States', 'China', 'Switzerland',
#        'Taiwan', 'United States', 'Taiwan', 'Canada', 'United States',
#        'United States', 'South Africa', 'Japan', 'Canada', 'Indonesia',
#        'Germany', 'China', 'United States', 'China', 'Ireland', 'France',
#        'United Kingdom', 'Spain', 'China', 'United States',
#        'United States', 'Japan', 'United States', 'Ireland',
#        'United States', 'China', 'United States', 'Japan', 'Switzerland',
#        'Russia', 'China', 'Hong Kong', 'Thailand', 'United States',
#        'United Kingdom', 'Germany', 'China', 'United States',
#        'United Kingdom', 'United States', 'United States', 'Australia',
#        'Spain', 'Hong Kong', 'United States', 'United States', 'China',
#        'Germany', 'United States', 'China', 'Japan', 'France', 'Canada',
#        'Spain', 'United States', 'United States', 'Saudi Arabia',
#        'United States', 'United States', 'Luxembourg', 'United States',
#        'Taiwan', 'Belgium', 'Italy', 'United States', 'United Kingdom',
#        'Saudi Arabia', 'Denmark', 'United States', 'United States',
#        'United States', 'Sweden', 'France', 'Japan', 'United States',
#        'United States', 'United States', 'United Kingdom',
#        'United Kingdom', 'United States', 'Japan', 'Brazil',
#        'United States', 'United States', 'Japan', 'United States',
#        'United States', 'United States', 'Canada', 'United States',
#        'United States', 'United States', 'United Kingdom', 'Sweden',
#        'United States', 'United States', 'Switzerland', 'Japan', 'China',
#        'Japan', 'Brazil', 'United States', 'China', 'Mexico',
#        'United States', 'France', 'United States', 'Sweden', 'Brazil',
#        'United States', 'India', 'China', 'Japan', 'United States',
#        'Hong Kong', 'United States', 'Switzerland', 'United Kingdom',
#        'Japan', 'Mexico', 'United States', 'China', 'United States',
#        'China', 'Belgium', 'Japan', 'Luxembourg', 'Sweden', 'Chile',
#        'United States', 'United Kingdom', 'Japan', 'Germany',
#        'United States', 'United States', 'China', 'Taiwan',
#        'United States', 'Spain', 'Australia', 'United States', 'China',
#        'United States', 'United States', 'United States', 'United States',
#        'United States', 'United States', 'United States', 'Spain',
#        'United States', 'United States', 'Hong Kong', 'United States',
#        'Sweden', 'France', 'United States', 'Hong Kong', 'United States',
#        'United States', 'China', 'Hong Kong', 'Switzerland',
#        'United States', 'Taiwan', 'United States', 'India', 'Brazil',
#        'Japan', 'United States', 'United States', 'United States',
#        'Germany', 'China', 'Japan', 'Spain', 'United States',
#        'United States', 'Taiwan', 'Japan', 'United States',
#        'United States', 'United States', 'Japan', 'China', 'Saudi Arabia',
#        'Sweden', 'Japan', 'United States', 'Japan', 'United States',
#        'Ireland', 'Canada', 'Japan', 'Thailand', 'United States',
#        'United States', 'China', 'United Kingdom', 'Japan', 'Spain',
#        'United States', 'United States', 'United States', 'United States',
#        'United States', 'United States', 'Netherlands', 'United Kingdom',
#        'United States', 'Hong Kong', 'Ireland', 'China', 'United States',
#        'United States', 'Canada', 'United States', 'United Kingdom',
#        'United States', 'Japan', 'Brazil', 'Canada', 'Switzerland',
#        'Saudi Arabia', 'Japan', 'United States', 'Canada', 'China',
#        'Italy', 'South Korea', 'Sweden', 'Germany', 'Portugal', 'Spain',
#        'United States', 'United States', 'Hong Kong', 'Brazil',
#        'United States', 'Bermuda', 'United States', 'China', 'China',
#        'China', 'United States', 'United States', 'Hong Kong', 'Canada',
#        'Japan', 'Bermuda', 'Japan', 'Ireland', 'United States', 'Ireland',
#        'South Africa', 'United Kingdom', 'Hong Kong', 'China',
#        'United States', 'Brazil', 'United States', 'Japan', 'China',
#        'United States', 'India', 'Germany', 'United States',
#        'United States', 'Norway', 'United States', 'United Kingdom',
#        'Taiwan', 'Norway', 'Hong Kong', 'Switzerland', 'France', 'China',
#        'South Africa', 'Canada', 'Czechia', 'Japan', 'China',
#        'United States', 'United States', 'United States', 'Japan',
#        'Hong Kong', 'Japan', 'United States', 'China', 'United States',
#        'South Africa', 'United States', 'China', 'United States', 'Macao',
#        'China', 'Australia', 'China', 'China', 'China', 'Switzerland',
#        'United States', 'Japan', 'United States', 'United States',
#        'Canada', 'United Kingdom', 'United States', 'China',
#        'United States', 'Indonesia', 'South Korea', 'Japan', 'Israel',
#        'United States', 'Luxembourg', 'Japan', 'United States', 'Israel',
#        'Denmark', 'United States', 'China', 'United States', 'Germany',
#        'Japan', 'United States', 'India', 'China', 'United Kingdom',
#        'United States', 'United Kingdom', 'United States',
#        'United States', 'United States', 'United States', 'France',
#        'Norway', 'China', 'United States', 'United States',
#        'United States', 'Australia', 'United States', 'United States',
#        'United States', 'United States', 'Ireland', 'France',
#        'United States', 'United States', 'United States', 'United States',
#        'United States', 'China', 'Denmark', 'United States',
#        'United States', 'United States', 'United States', 'Netherlands',
#        'China', 'United States', 'United States', 'United States',
#        'United States', 'China', 'United States', 'Switzerland',
#        'United States', 'United States', 'France', 'South Korea',
#        'United States', 'United States', 'United States', 'China',
#        'United States', 'United States', 'United States', 'Taiwan',
#        'United States', 'United States', 'United States', 'United States',
#        'United States', 'United States', 'Saudi Arabia', 'United States',
#        'United States', 'United States', 'United States', 'United States',
#        'France', 'Germany', 'China', 'United States', 'United States',
#        'United States', 'France', 'Hong Kong', 'United Kingdom', 'China',
#        'United States', 'United States', 'Australia', 'China', 'Canada',
#        'France', 'United States', 'United States', 'Ireland',
#        'United States', 'United States', 'Canada', 'United States',
#        'United States', 'United States', 'China', 'United States',
#        'United Kingdom', 'Netherlands', 'United States', 'United States',
#        'United States', 'United States', 'United States', 'China',
#        'China', 'United States', 'China', 'United States',
#        'United States', 'United States', 'United States', 'United States',
#        'United Kingdom', 'Switzerland', 'United Kingdom', 'Netherlands',
#        'Brazil', 'Germany', 'Switzerland', 'Germany', 'United States',
#        'United States', 'United States', 'United States',
#        'United Kingdom', 'United States', 'Japan', 'Saudi Arabia',
#        'China', 'United States', 'United States', 'Saudi Arabia', 'India',
#        'United States', 'United States', 'Brazil', 'United States',
#        'Germany', 'United States', 'United Kingdom', 'United States',
#        'Spain', 'Australia', 'United States', 'Belgium', 'United States',
#        'United States', 'Hong Kong', 'United Kingdom', 'Japan'],
#       dtype=object)

# %%
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2

def get_continent(col):
    try:
        cn_a2_code =  country_name_to_country_alpha2(col)
    except:
        cn_a2_code = 'Unknown' 
    try:
        cn_continent = country_alpha2_to_continent_code(cn_a2_code)
    except:
        cn_continent = 'Unknown' 
    print((cn_a2_code, cn_continent))

# %%
for s in df.country.values:
    get_continent(s)
# Out:
# ('US', 'NA')
# ('GB', 'EU')
# ('BR', 'SA')
# ('TW', 'AS')
# ('CA', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('KR', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('AU', 'OC')
# ('US', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('CH', 'EU')
# ('AU', 'OC')
# ('US', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('FR', 'EU')
# ('CN', 'AS')
# ('CA', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('FR', 'EU')
# ('US', 'NA')
# ('AU', 'OC')
# ('US', 'NA')
# ('FR', 'EU')
# ('CA', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CH', 'EU')
# ('CA', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('AU', 'OC')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('DE', 'EU')
# ('DE', 'EU')
# ('CA', 'NA')
# ('FR', 'EU')
# ('CA', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('GB', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('DK', 'EU')
# ('KR', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('IN', 'AS')
# ('SG', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('CH', 'EU')
# ('AU', 'OC')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('DE', 'EU')
# ('JP', 'AS')
# ('ES', 'EU')
# ('US', 'NA')
# ('RU', 'EU')
# ('CH', 'EU')
# ('US', 'NA')
# ('MX', 'NA')
# ('FR', 'EU')
# ('US', 'NA')
# ('IT', 'EU')
# ('FR', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('DE', 'EU')
# ('US', 'NA')
# ('ID', 'AS')
# ('MX', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('GB', 'EU')
# ('DE', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('SA', 'AS')
# ('CN', 'AS')
# ('GB', 'EU')
# ('US', 'NA')
# ('CA', 'NA')
# ('JP', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('BR', 'SA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('BM', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('FR', 'EU')
# ('CN', 'AS')
# ('SA', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('GB', 'EU')
# ('AU', 'OC')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('HK', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('DE', 'EU')
# ('CA', 'NA')
# ('HK', 'AS')
# ('NL', 'EU')
# ('SE', 'EU')
# ('DE', 'EU')
# ('ES', 'EU')
# ('US', 'NA')
# ('IE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('SG', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('AR', 'SA')
# ('US', 'NA')
# ('FR', 'EU')
# ('US', 'NA')
# ('RU', 'EU')
# ('US', 'NA')
# ('CN', 'AS')
# ('AU', 'OC')
# ('TW', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('JP', 'AS')
# ('CA', 'NA')
# ('NL', 'EU')
# ('IT', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('NL', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('DE', 'EU')
# ('CA', 'NA')
# ('GB', 'EU')
# ('CH', 'EU')
# ('US', 'NA')
# ('IT', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('BR', 'SA')
# ('NL', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('JP', 'AS')
# ('GB', 'EU')
# ('CN', 'AS')
# ('IN', 'AS')
# ('KR', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CH', 'EU')
# ('IT', 'EU')
# ('RU', 'EU')
# ('SA', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('DE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('CN', 'AS')
# ('CH', 'EU')
# ('DE', 'EU')
# ('JP', 'AS')
# ('BR', 'SA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('RU', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('ZA', 'AF')
# ('US', 'NA')
# ('MX', 'NA')
# ('US', 'NA')
# ('IE', 'EU')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('RU', 'EU')
# ('US', 'NA')
# ('CA', 'NA')
# ('TW', 'AS')
# ('AU', 'OC')
# ('JP', 'AS')
# ('CN', 'AS')
# ('SG', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('HK', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('SG', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('NL', 'EU')
# ('RU', 'EU')
# ('HK', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CH', 'EU')
# ('DE', 'EU')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('DK', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('AU', 'OC')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('AU', 'OC')
# ('US', 'NA')
# ('IE', 'EU')
# ('US', 'NA')
# ('FI', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('FR', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('CN', 'AS')
# ('CA', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('DE', 'EU')
# ('CN', 'AS')
# ('CN', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('JP', 'AS')
# ('IE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('ID', 'AS')
# ('FR', 'EU')
# ('GB', 'EU')
# ('JP', 'AS')
# ('FR', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('SE', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('ES', 'EU')
# ('US', 'NA')
# ('CO', 'SA')
# ('CH', 'EU')
# ('GB', 'EU')
# ('DK', 'EU')
# ('CH', 'EU')
# ('US', 'NA')
# ('CA', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('FR', 'EU')
# ('DE', 'EU')
# ('CA', 'NA')
# ('IE', 'EU')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('HK', 'AS')
# ('SE', 'EU')
# ('US', 'NA')
# ('CN', 'AS')
# ('NL', 'EU')
# ('TH', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('HK', 'AS')
# ('JP', 'AS')
# ('CH', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('TW', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('AU', 'OC')
# ('AT', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('LU', 'EU')
# ('HK', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('HK', 'AS')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('IT', 'EU')
# ('SE', 'EU')
# ('AU', 'OC')
# ('DE', 'EU')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('FI', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('FR', 'EU')
# ('CA', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('DE', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('TW', 'AS')
# ('NL', 'EU')
# ('CH', 'EU')
# ('US', 'NA')
# ('JP', 'AS')
# ('IE', 'EU')
# ('HK', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('AU', 'OC')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('ID', 'AS')
# ('JP', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('BR', 'SA')
# ('US', 'NA')
# ('CN', 'AS')
# ('GB', 'EU')
# ('SG', 'AS')
# ('CN', 'AS')
# ('ES', 'EU')
# ('HK', 'AS')
# ('CN', 'AS')
# ('HK', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('CH', 'EU')
# ('CA', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('DE', 'EU')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('SE', 'EU')
# ('CN', 'AS')
# ('DE', 'EU')
# ('SE', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('CH', 'EU')
# ('US', 'NA')
# ('TW', 'AS')
# ('RU', 'EU')
# ('US', 'NA')
# ('CN', 'AS')
# ('CN', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('FI', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('DE', 'EU')
# ('US', 'NA')
# ('FI', 'EU')
# ('ES', 'EU')
# ('US', 'NA')
# ('NL', 'EU')
# ('US', 'NA')
# ('CH', 'EU')
# ('TH', 'AS')
# ('CA', 'NA')
# ('NL', 'EU')
# ('US', 'NA')
# ('NL', 'EU')
# ('SA', 'AS')
# ('DK', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('JP', 'AS')
# ('FR', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('CH', 'EU')
# ('TW', 'AS')
# ('US', 'NA')
# ('TW', 'AS')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('ZA', 'AF')
# ('JP', 'AS')
# ('CA', 'NA')
# ('ID', 'AS')
# ('DE', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('IE', 'EU')
# ('FR', 'EU')
# ('GB', 'EU')
# ('ES', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('IE', 'EU')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('JP', 'AS')
# ('CH', 'EU')
# ('RU', 'EU')
# ('CN', 'AS')
# ('HK', 'AS')
# ('TH', 'AS')
# ('US', 'NA')
# ('GB', 'EU')
# ('DE', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('AU', 'OC')
# ('ES', 'EU')
# ('HK', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('DE', 'EU')
# ('US', 'NA')
# ('CN', 'AS')
# ('JP', 'AS')
# ('FR', 'EU')
# ('CA', 'NA')
# ('ES', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('SA', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('LU', 'EU')
# ('US', 'NA')
# ('TW', 'AS')
# ('BE', 'EU')
# ('IT', 'EU')
# ('US', 'NA')
# ('GB', 'EU')
# ('SA', 'AS')
# ('DK', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('SE', 'EU')
# ('FR', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('GB', 'EU')
# ('US', 'NA')
# ('JP', 'AS')
# ('BR', 'SA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('SE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('CH', 'EU')
# ('JP', 'AS')
# ('CN', 'AS')
# ('JP', 'AS')
# ('BR', 'SA')
# ('US', 'NA')
# ('CN', 'AS')
# ('MX', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('US', 'NA')
# ('SE', 'EU')
# ('BR', 'SA')
# ('US', 'NA')
# ('IN', 'AS')
# ('CN', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('HK', 'AS')
# ('US', 'NA')
# ('CH', 'EU')
# ('GB', 'EU')
# ('JP', 'AS')
# ('MX', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('BE', 'EU')
# ('JP', 'AS')
# ('LU', 'EU')
# ('SE', 'EU')
# ('CL', 'SA')
# ('US', 'NA')
# ('GB', 'EU')
# ('JP', 'AS')
# ('DE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('TW', 'AS')
# ('US', 'NA')
# ('ES', 'EU')
# ('AU', 'OC')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('ES', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('HK', 'AS')
# ('US', 'NA')
# ('SE', 'EU')
# ('FR', 'EU')
# ('US', 'NA')
# ('HK', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('HK', 'AS')
# ('CH', 'EU')
# ('US', 'NA')
# ('TW', 'AS')
# ('US', 'NA')
# ('IN', 'AS')
# ('BR', 'SA')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('DE', 'EU')
# ('CN', 'AS')
# ('JP', 'AS')
# ('ES', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('TW', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('CN', 'AS')
# ('SA', 'AS')
# ('SE', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('IE', 'EU')
# ('CA', 'NA')
# ('JP', 'AS')
# ('TH', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('GB', 'EU')
# ('JP', 'AS')
# ('ES', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('NL', 'EU')
# ('GB', 'EU')
# ('US', 'NA')
# ('HK', 'AS')
# ('IE', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('JP', 'AS')
# ('BR', 'SA')
# ('CA', 'NA')
# ('CH', 'EU')
# ('SA', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('CA', 'NA')
# ('CN', 'AS')
# ('IT', 'EU')
# ('KR', 'AS')
# ('SE', 'EU')
# ('DE', 'EU')
# ('PT', 'EU')
# ('ES', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('HK', 'AS')
# ('BR', 'SA')
# ('US', 'NA')
# ('BM', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('CN', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('HK', 'AS')
# ('CA', 'NA')
# ('JP', 'AS')
# ('BM', 'NA')
# ('JP', 'AS')
# ('IE', 'EU')
# ('US', 'NA')
# ('IE', 'EU')
# ('ZA', 'AF')
# ('GB', 'EU')
# ('HK', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('BR', 'SA')
# ('US', 'NA')
# ('JP', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('IN', 'AS')
# ('DE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('NO', 'EU')
# ('US', 'NA')
# ('GB', 'EU')
# ('TW', 'AS')
# ('NO', 'EU')
# ('HK', 'AS')
# ('CH', 'EU')
# ('FR', 'EU')
# ('CN', 'AS')
# ('ZA', 'AF')
# ('CA', 'NA')
# ('CZ', 'EU')
# ('JP', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('JP', 'AS')
# ('HK', 'AS')
# ('JP', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('ZA', 'AF')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('MO', 'AS')
# ('CN', 'AS')
# ('AU', 'OC')
# ('CN', 'AS')
# ('CN', 'AS')
# ('CN', 'AS')
# ('CH', 'EU')
# ('US', 'NA')
# ('JP', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('ID', 'AS')
# ('KR', 'AS')
# ('JP', 'AS')
# ('IL', 'AS')
# ('US', 'NA')
# ('LU', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('IL', 'AS')
# ('DK', 'EU')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('DE', 'EU')
# ('JP', 'AS')
# ('US', 'NA')
# ('IN', 'AS')
# ('CN', 'AS')
# ('GB', 'EU')
# ('US', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('NO', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('AU', 'OC')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('IE', 'EU')
# ('FR', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('DK', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('NL', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('CH', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('KR', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('TW', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('SA', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('DE', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('FR', 'EU')
# ('HK', 'AS')
# ('GB', 'EU')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('AU', 'OC')
# ('CN', 'AS')
# ('CA', 'NA')
# ('FR', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('IE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('CA', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('GB', 'EU')
# ('NL', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('CN', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('CH', 'EU')
# ('GB', 'EU')
# ('NL', 'EU')
# ('BR', 'SA')
# ('DE', 'EU')
# ('CH', 'EU')
# ('DE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('US', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('JP', 'AS')
# ('SA', 'AS')
# ('CN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('SA', 'AS')
# ('IN', 'AS')
# ('US', 'NA')
# ('US', 'NA')
# ('BR', 'SA')
# ('US', 'NA')
# ('DE', 'EU')
# ('US', 'NA')
# ('GB', 'EU')
# ('US', 'NA')
# ('ES', 'EU')
# ('AU', 'OC')
# ('US', 'NA')
# ('BE', 'EU')
# ('US', 'NA')
# ('US', 'NA')
# ('HK', 'AS')
# ('GB', 'EU')
# ('JP', 'AS')

# %%
df
# Out:
#                             name market_cap stock         country  \
# 0        Avis Budget Group, Inc.   $18.12 B   CAR   United States
# 1        Croda International plc   $19.22 B  CRDA  United Kingdom
# 2           Telefônica Brasil SA   $20.19 B   VIV          Brazil
# 3        Delta Electronics, Inc.   $24.05 B  2308          Taiwan
# 4    Power Corporation of Canada   $21.48 B   POW          Canada
# ..                           ...        ...   ...             ...
# 995             Caterpillar Inc.  $124.13 B   CAT   United States
# 996  Lockheed Martin Corporation  $124.98 B   LMT   United States
# 997                AIA Group Ltd  $125.16 B  1299       Hong Kong
# 998              Rio Tinto Group  $125.84 B   RIO  United Kingdom
# 999       Sony Group Corporation  $126.64 B  6758           Japan
#
#                       sector                              industry  \
# 0                Industrials             Rental & Leasing Services
# 1            Basic Materials                   Specialty Chemicals
# 2     Communication Services                      Telecom Services
# 3                 Technology                 Electronic Components
# 4                 Financials                        Insurance—Life
# ..                       ...                                   ...
# 995              Industrials   Farm & Heavy Construction Machinery
# 996              Industrials                   Aerospace & Defense
# 997               Financials                        Insurance—Life
# 998          Basic Materials      Other Industrial Metals & Mining
# 999               Technology                  Consumer Electronics
#
#              headquarters         founded employees  \
# 0                    None            2006    16,000
# 1                    None            1925     4,000
# 2                    None            1998    34,000
# 3                    None            None      None
# 4                    None            1925    30,000
# ..                    ...             ...       ...
# 995                  None  April 15, 1925   107,700
# 996                  None  March 15, 1995   114,000
# 997      Central,HongKong            None    23,000
# 998  London,UnitedKingdom            1873    49,000
# 999           Tokyo,Japan      7 May 1946   109,700
#
#                                 ceo
# 0             Mr. Joseph A. Ferraro
# 1                              None
# 2       Mr. Christian  Mauad Gebara
# 3                   Mr. Ping  Cheng
# 4            Mr. Robert Jeffrey Orr
# ..                              ...
# 995        Mr. D. James Umpleby III
# 996        Mr. James D. Taiclet Jr.
# 997                            None
# 998   Mr. Jakob  Stausholm M.S., MS
# 999          Mr. Kenichiro  Yoshida
#
# [1000 rows x 10 columns]

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Filippo")
def geolocate(country):
    try:
        # Geolocate the center of the country
        loc = geolocator.geocode(country)
        # And return latitude and longitude
        return (loc.latitude, loc.longitude)
    except:
        # Return missing value
        return np.nan

# %%
for s in df.country.values:
    geolocate(s)

# %%
import folium
from folium.plugins import MarkerCluster
#empty map
world_map= folium.Map(tiles="cartodbpositron")
marker_cluster = MarkerCluster().add_to(world_map)
#for each coordinate, create circlemarker of user percent
for i in range(len(df)):
        lat = df.iloc[i]['Latitude']
        long = df.iloc[i]['Longitude']
        radius=5
        popup_text = """Country : {}<br>
                    # %of Users : {}<br>"""
        popup_text = popup_text.format(df.iloc[i]['Country'],
                                   df.iloc[i]['User_Percent']
                                   )
        folium.CircleMarker(location = [lat, long], radius=radius, popup= popup_text, fill =True).add_to(marker_cluster)
#show the map
world_map
