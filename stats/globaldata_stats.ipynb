# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy

# Apply the default theme at seaborn
sns.set_theme()

# %%
# Opening JSON file
file_name = '../../../os1000.json'

df = pd.read_json(file_name)
df
# Out:
#                           name              headquarters number_of_employees  \
# 0                  Walmart Inc  United States of America           2,300,000
# 1     China Petrochemical Corp                     China                None
# 2               Amazon.com Inc  United States of America           1,608,000
# 3         Saudi Arabian Oil Co              Saudi Arabia              68,493
# 4             Exxon Mobil Corp  United States of America              63,000
# ...                        ...                       ...                 ...
# 1165              Alphabet Inc  United States of America             186,779
# 1166                Google LLC  United States of America              85,000
# 1167                 Shell plc            United Kingdom              82,000
# 1168             McKesson Corp  United States of America              58,000
# 1169    Berkshire Hathaway Inc  United States of America             372,000
#
#                                                 address  \
# 0      702 Sw 8th St, Bentonville, Arkansas, 72716-6209
# 1      No.22, Chaoyangmen North Street, Beijing, 100728
# 2     410 Terry Avenue North, Seattle, Washington, 9...
# 3     Corporate Communications Department, Saudi Ara...
# 4      5959 Las Colinas Blvd, Irving, Texas, 75039-2298
# ...                                                 ...
# 1165  1600 Amphitheatre Pkwy, Mountain View, Califor...
# 1166  1600 Amphitheatre Parkway, Mountain View, Cali...
# 1167       Shell Centre, London, Greater London, SE17NA
# 1168       6555 State Highway 161, Irving, Texas, 75039
# 1169        3555 Farnam St, Omaha, Nebraska, 68131-3311
#
#                            industry                    website market_cap  \
# 0                         Retailing      corporate.walmart.com    $415.9B
# 1              Energy and Utilities            www.sinopec.com       None
# 2                         Retailing             www.amazon.com    $960.3B
# 3              Energy and Utilities             www.aramco.com  $1,937.2B
# 4              Energy and Utilities   corporate.exxonmobil.com    $452.4B
# ...                             ...                        ...        ...
# 1165  Technology and Communications                    abc.xyz  $1,302.4B
# 1166  Technology and Communications             www.google.com       None
# 1167           Energy and Utilities              www.shell.com    $204.6B
# 1168                      Wholesale           www.mckesson.com     $54.9B
# 1169             Financial Services  www.berkshirehathaway.com    $696.3B
#
#            telephone  revenue      time
# 0      1 479 2734000  $572.8B  0.020155
# 1     86 10 59960114  $432.5B  0.018965
# 2      1 206 2661000  $469.8B  0.035708
# 3     966 1 38720115  $400.9B  0.022427
# 4      1 972 4441000  $276.7B  0.018523
# ...              ...      ...       ...
# 1165   1 650 2530000  $257.6B  0.031608
# 1166   1 650 2530000  $256.7B  0.032318
# 1167  44 20 79343363  $261.5B  0.024169
# 1168   1 972 4464800  $264.0B  0.025701
# 1169   1 402 3461400  $276.1B  0.023418
#
# [1170 rows x 10 columns]

# %%
df
# Out:
#                                 name              headquarters  \
# 0                        Walmart Inc  United States of America
# 1      China National Petroleum Corp                     China
# 2           China Petrochemical Corp                     China
# 3                  PetroChina Co Ltd                     China
# 4    China Petroleum & Chemical Corp                     China
# ..                               ...                       ...
# 176                       Google LLC  United States of America
# 177                     Alphabet Inc  United States of America
# 178                    McKesson Corp  United States of America
# 179                        Shell plc            United Kingdom
# 180           Berkshire Hathaway Inc  United States of America
#
#     number_of_employees                                            address  \
# 0             2,300,000   702 Sw 8th St, Bentonville, Arkansas, 72716-6209
# 1             1,448,400  9 Dongzhimen North Street, Dongcheng District,...
# 2                  None   No.22, Chaoyangmen North Street, Beijing, 100728
# 3               409,191  No. 9, Dongzhimen North Street, Dongcheng Dist...
# 4               385,691  No. 22 Chaoyangmen North Avenue, Chaoyang Dist...
# ..                  ...                                                ...
# 176              85,000  1600 Amphitheatre Parkway, Mountain View, Cali...
# 177             186,779  1600 Amphitheatre Pkwy, Mountain View, Califor...
# 178              58,000       6555 State Highway 161, Irving, Texas, 75039
# 179              82,000       Shell Centre, London, Greater London, SE17NA
# 180             372,000        3555 Farnam St, Omaha, Nebraska, 68131-3311
#
#                           industry                    website market_cap  \
# 0                        Retailing      corporate.walmart.com    $415.9B
# 1             Energy and Utilities            www.cnpc.com.cn       None
# 2             Energy and Utilities            www.sinopec.com       None
# 3             Energy and Utilities      www.petrochina.com.cn    $129.2B
# 4             Energy and Utilities            www.sinopec.com     $72.8B
# ..                             ...                        ...        ...
# 176  Technology and Communications             www.google.com       None
# 177  Technology and Communications                    abc.xyz  $1,302.4B
# 178                      Wholesale           www.mckesson.com     $54.9B
# 179           Energy and Utilities              www.shell.com    $204.6B
# 180             Financial Services  www.berkshirehathaway.com    $696.3B
#
#           telephone  revenue      time
# 0     1 479 2734000  $572.8B  0.022959
# 1    86 10 62094114  $435.2B  0.023147
# 2    86 10 59960114  $432.5B  0.019256
# 3    86 10 59982622  $405.3B  0.019556
# 4    86 10 59960028  $424.9B  0.016339
# ..              ...      ...       ...
# 176   1 650 2530000  $256.7B  0.023352
# 177   1 650 2530000  $257.6B  0.023745
# 178   1 972 4464800  $264.0B  0.023627
# 179  44 20 79343363  $261.5B  0.023129
# 180   1 402 3461400  $276.1B  0.025587
#
# [181 rows x 10 columns]

# %%
df.head(100).isnull().sum()
# Out:
# name                    0
# headquarters            0
# number_of_employees     2
# address                 0
# industry                0
# website                 0
# market_cap             10
# telephone               2
# revenue                 0
# time                    0
# dtype: int64

# %%
#number of cells
print("Number of cells: ",df.head(100).size)

#number of rows (dataframe's instances)
print("Number of rows: ", df.head(100).shape[0])
# Out:
# Number of cells:  1000
# Number of rows:  100

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df.head(100).index, df.head(100)['time'], color='blue')

# %%
times = [[100, df.head(100)['time'].min(), df.head(100)['time'].max(), df.head(100)['time'].mean(), df.head(100)['time'].median()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table
# Out:
#    Estrazioni   Minimo     Media   Mediana  Massimo
# 0         100  0.01554  0.039255  0.022366  0.02254

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df.head(9).index, pd.to_numeric(df.head(10)[~df['number_of_employees'].isnull()]['number_of_employees']), color='blue')
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_16024\1210164732.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax1.plot(df.head(9).index, (df.head(10)[~df['number_of_employees'].isnull()]['number_of_employees']), color='blue')

# %%
#status
print(df['company_status'].value_counts())
status = df['company_status'].value_counts()
type(status)
keys = status.index
values = status.values

#graph with mathplotlib
# plt.figure(figsize=(10, 4))
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 10, i - 0.1 , str(v),
            color = 'green', fontweight = 'bold')
plt.xlabel("number of companies")
plt.ylabel("status companies")
plt.show()

#graph with seaborn with scale semilog on axis of x
plt.figure(figsize=(20,4))
plt.semilogx()
status.plot(kind='barh')
# Out:
# Active               980
# Dissolved            146
# Liquidation           28
# In Administration      2
# Name: company_status, dtype: int64
# <AxesSubplot:>

# %%
#type
print(df['company_type'].value_counts())
type_companies = df['company_type'].value_counts()
keys = type_companies.index
values = type_companies.values

#creation of graph for type_companies
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 3, i - 0.1 , str(v),
            color = 'green', fontweight = 'bold')
plt.xlabel("number of companies")
plt.ylabel("type of companies")
plt.show()
# Out:
# Private limited Company                                                                  1115
# Private company limited by guarantee without share capital                                 33
# Private Limited Company by guarantee without share capital use of 'Limited' exemption       6
# Public limited Company                                                                      2
# Name: company_type, dtype: int64

# %%
# print(df['company_creation_date'].value_counts())
creation_date = df['company_creation_date'].value_counts()

#dati necessari per stabilire quanti sono i giorni in cui sono nate contemporaneamente lo stesso numero di aziende
#NUMERO DI GIORNI IN CUI UN CERTO NUMERO DI AZIENDE è NATO LO STESSO GIORNO
num_date, num_companies = numpy.unique(creation_date.values, return_counts=True)
print(dict(zip(num_date, num_companies)))

fig, ax = plt.subplots()
width = 0.5
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(num_date, num_companies, width, color = "green")

for i, v in enumerate(num_companies):
    ax.text(v + 10, i + 0.9 , str(v),
            color = 'green', fontweight = 'bold')
plt.xlabel("number of day")
plt.ylabel("number of companies born the same day")
plt.show()

keys = creation_date.index
values = creation_date.values

creation_date
# Out:
# {1: 857, 2: 109, 3: 19, 4: 6}
# 1 July 2020        4
# 20 April 2022      4
# 25 January 2021    4
# 26 April 2021      4
# 25 October 2021    4
#                   ..
# 14 April 2016      1
# 14 July 2022       1
# 18 April 2013      1
# 9 April 1990       1
# 17 August 2021     1
# Name: company_creation_date, Length: 991, dtype: int64

# %%
#take only the most important natures of the business
nature_of_business = df['nature_of_business'].value_counts().head(10)
print(nature_of_business)

keys = nature_of_business.index
values = nature_of_business.values

#creation of graph for type_companies
fig, ax = plt.subplots()
width = 0.5
fig.set_size_inches(12, 7)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.1 , str(v),
            color = 'green', fontweight = 'bold')
plt.xlabel("nature of business")
plt.ylabel("number of companies")
plt.show()
# Out:
# 62012 - Business and domestic software development                            117
# 62020 - Information technology consultancy activities                         105
# 56290 - Other food services                                                    58
# 56103 - Take-away food shops and mobile food stands                            51
# 82990 - Other business support service activities not elsewhere classified     47
# 70229 - Management consultancy activities other than financial management      45
# 99999 - Dormant Company                                                        35
# 62090 - Other information technology service activities                        30
# 47910 - Retail sale via mail order houses or via Internet                      27
# 96090 - Other service activities not elsewhere classified                      25
# Name: nature_of_business, dtype: int64

# %%
#here the idea is to perform a comparison between "companies_status" and "nature_of_business" in a graphs
nature_of_business = df[['company_status','nature_of_business']].value_counts()
nature_of_business
# Out:
# company_status  nature_of_business
# Active          62012 - Business and domestic software development                                         102
#                 62020 - Information technology consultancy activities                                       91
#                 56290 - Other food services                                                                 46
#                 82990 - Other business support service activities not elsewhere classified                  44
#                 70229 - Management consultancy activities other than financial management                   42
#                                                                                                           ...
#                 70221 - Financial management                                                                 1
#                 71112 - Urban planning and landscape architectural activities                                1
#                 71200 - Technical testing and analysis                                                       1
#                 72190 - Other research and experimental development on natural sciences and engineering      1
# Liquidation     82990 - Other business support service activities not elsewhere classified                   1
# Length: 277, dtype: int64
