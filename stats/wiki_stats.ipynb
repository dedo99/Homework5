# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy

# Apply the default theme at seaborn
sns.set_theme()

# %%
# Opening JSON file
file_name = './../output/output_wiki.json'

df = pd.read_json(file_name)

# %%
df
# Out:
#                            name                       type  \
# 0                       Binance                         []
# 1        Gourmet Master Co. Ltd                         []
# 2     Tata Consultancy Services                   [Public]
# 3                   APMEX, Inc.                  [Private]
# 4     Bitmain Technologies Ltd.                  [Private]
# ...                         ...                        ...
# 997                 Blockstream              [Corporation]
# 998                        Nuri                         []
# 999                    Bitstamp  [Cryptocurrency exchange]
# 1000                     BitPay                         []
# 1001                     BitMEX                         []
#
#                                                industry      founded  \
# 0                            [cryptocurrency industry ]  [July 2017]
# 1                                   [Food and Beverage]       [2004]
# 2     [Information technology, Consulting, Outsourcing]       [1968]
# 3                                     [precious metals]       [2000]
# 4                                      [Cryptocurrency]       [2013]
# ...                                                 ...          ...
# 997                          [Cryptocurrency, software]       [2014]
# 998                                [Financial Services]       [2015]
# 999                                                  []           []
# 1000                                [Payment Processor]           []
# 1001                                                 []       [2014]
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                    []
# 2                                       [J. R. D. Tata]
# 3                                                    []
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                           []         []       []
# 1                             [Taipei, Taiwan]         []       []
# 2                        [Mumbai, Maharashtra]         []       []
# 3     [Oklahoma City, Oklahoma, United States]         []       []
# 4                             [Beijing, China]         []       []
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]         []       []
# 998                          [Berlin, Germany]         []       []
# 999                                         []         []       []
# 1000                   [Atlanta, Georgia, USA]         []       []
# 1001                              [Seychelles]         []       []
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                                 []
# 4                                 []
# ...                              ...
# 997                               []
# 998                               []
# 999                               []
# 1000                              []
# 1001                              []
#
#                                        operating_income  \
# 0                                                    []
# 1                                                    []
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                                 []
#
#                                            total_assets  \
# 0                                                    []
# 1                                                    []
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998                                                  []
# 999                                                  []
# 1000                                                 []
# 1001                                                 []
#
#                            number_of_employees  \
# 0                                           []
# 1                                           []
# 2              [616,171, [3],  (October 2022)]
# 3                                           []
# 4                                           []
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                         []
# 999                                         []
# 1000                                        []
# 1001                                        []
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                             []
# 999                         [www, .bitstamp, .net]
# 1000                                            []
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]

# %%
df = df.applymap(lambda x: None if len(x)==0 else x)

# %%
df
# Out:
#                            name                       type  \
# 0                       Binance                       None
# 1        Gourmet Master Co. Ltd                       None
# 2     Tata Consultancy Services                   [Public]
# 3                   APMEX, Inc.                  [Private]
# 4     Bitmain Technologies Ltd.                  [Private]
# ...                         ...                        ...
# 997                 Blockstream              [Corporation]
# 998                        Nuri                       None
# 999                    Bitstamp  [Cryptocurrency exchange]
# 1000                     BitPay                       None
# 1001                     BitMEX                       None
#
#                                                industry      founded  \
# 0                            [cryptocurrency industry ]  [July 2017]
# 1                                   [Food and Beverage]       [2004]
# 2     [Information technology, Consulting, Outsourcing]       [1968]
# 3                                     [precious metals]       [2000]
# 4                                      [Cryptocurrency]       [2013]
# ...                                                 ...          ...
# 997                          [Cryptocurrency, software]       [2014]
# 998                                [Financial Services]       [2015]
# 999                                                None         None
# 1000                                [Payment Processor]         None
# 1001                                               None       [2014]
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                  None
# 2                                       [J. R. D. Tata]
# 3                                                  None
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                         None       None     None
# 1                             [Taipei, Taiwan]       None     None
# 2                        [Mumbai, Maharashtra]       None     None
# 3     [Oklahoma City, Oklahoma, United States]       None     None
# 4                             [Beijing, China]       None     None
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]       None     None
# 998                          [Berlin, Germany]       None     None
# 999                                       None       None     None
# 1000                   [Atlanta, Georgia, USA]       None     None
# 1001                              [Seychelles]       None     None
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                               None
# 4                               None
# ...                              ...
# 997                             None
# 998                             None
# 999                             None
# 1000                            None
# 1001                            None
#
#                                        operating_income  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                                            total_assets  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                            number_of_employees  \
# 0                                         None
# 1                                         None
# 2              [616,171, [3],  (October 2022)]
# 3                                         None
# 4                                         None
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                       None
# 999                                       None
# 1000                                      None
# 1001                                      None
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                           None
# 999                         [www, .bitstamp, .net]
# 1000                                          None
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# name                      0
# type                    142
# industry                 78
# founded                  46
# founders                498
# headquarters             37
# key_people             1001
# services                837
# revenue                 475
# operating_income        687
# total_assets            638
# number_of_employees     462
# website                 163
# dtype: int64

# %%
print("Number of cells:", df.size)
print("Number of value None:", df.isnull().sum().sum())
print("Number of row:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of cells: 13026
# Number of value None: 5064
# Number of row: 1002
# Number of columns: 13

# %%
# to extract the first elements from list
df.type = df.type.apply(lambda x: x[0] if x is not None else x)

# %%
#type
print(df['type'].value_counts())
type_companies = df['type'].value_counts()
type(type_companies)
#the top 10 types of companies are taken here because there are many types
type_companies_top10 = type_companies.head(10)
keys = type_companies_top10.index
values = type_companies_top10.values

print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("top 10 type of companies")
plt.xlabel("number of companies")
plt.show()
# Out:
# Public                     250
# Private                    132
# Public company              78
# Subsidiary                  78
# State-owned enterprise      21
#                           ...
# Sun Network                  1
# ASA                          1
# Private Limited company      1
# JSC                          1
# State owned company          1
# Name: type, Length: 135, dtype: int64
# Index(['Public', 'Private', 'Public company', 'Subsidiary',
#        'State-owned enterprise', 'Division', 'Public limited company',
#        'Production company', 'Corporation', 'Privately held company'],
#       dtype='object')
# [250 132  78  78  21  21  19  12  11  11]

# %%
# to extract the first elements from list
df.industry = df.industry.apply(lambda x: x[0] if x is not None else x)

# %%
#industry
plt.rcParams.update({'font.size': 22})
print(df['industry'].value_counts())
industry_companies = df['industry'].value_counts()
type(industry_companies)
#the top 10 industry
industry_companies_top10 = industry_companies.head(10)
keys = industry_companies_top10.index
values = industry_companies_top10.values

print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")
plt.tick_params(axis='both', which='major', labelsize=20)

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("top 10 industry of companies")
plt.xlabel("number of companies")
plt.show()
# Out:
# Film                       71
# Entertainment              64
# Retail                     58
# Oil and gas                56
# Motion pictures            47
#                            ..
# Motion Picture              1
# oil and gas exploration     1
# Supermarket                 1
# Gas utility                 1
# Payment Processor           1
# Name: industry, Length: 235, dtype: int64
# Index(['Film', 'Entertainment', 'Retail', 'Oil and gas', 'Motion pictures',
#        'Petroleum industry', 'Information technology', 'Petroleum',
#        'Financial services', 'Energy'],
#       dtype='object')
# [71 64 58 56 47 31 26 25 24 18]

# %%
# to extract the first elements from list
df.founded = df.founded.apply(lambda x: x[0] if x is not None else x)

# df.founded.apply(lambda txt: int(s) for s in txt for w in s.split() if w.isdigit() and len(s)==4)

# %%
companies_to_date = {'<1950': 0, '1950-2000': 0, '>2000': 0}
#generate dictionary with key an interval time and with value number of companies in that time interval
for s in df.founded.values:
    if s is not None:
        for w in s.split():
            if s.isdigit() and len(s)==4:
                s = int(s)
                type(s)
                if s<1950:
                    companies_to_date['<1950'] += 1
                elif 1950 < s < 2000:
                    companies_to_date['1950-2000'] += 1
                else:
                    companies_to_date['>2000'] += 1

print(companies_to_date)
companies_to_date = pd.Series(companies_to_date)
keys = companies_to_date.index
values = companies_to_date.values
print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.05, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("fondation date")
plt.xlabel("number of companies")
plt.show()
# Out:
# {'<1950': 105, '1950-2000': 237, '>2000': 125}
# Index(['<1950', '1950-2000', '>2000'], dtype='object')
# [105 237 125]

# %%
df
# Out:
#                            name                     type  \
# 0                       Binance                     None
# 1        Gourmet Master Co. Ltd                     None
# 2     Tata Consultancy Services                   Public
# 3                   APMEX, Inc.                  Private
# 4     Bitmain Technologies Ltd.                  Private
# ...                         ...                      ...
# 997                 Blockstream              Corporation
# 998                        Nuri                     None
# 999                    Bitstamp  Cryptocurrency exchange
# 1000                     BitPay                     None
# 1001                     BitMEX                     None
#
#                       industry    founded  \
# 0     cryptocurrency industry   July 2017
# 1            Food and Beverage       2004
# 2       Information technology       1968
# 3              precious metals       2000
# 4               Cryptocurrency       2013
# ...                        ...        ...
# 997             Cryptocurrency       2014
# 998         Financial Services       2015
# 999                       None       None
# 1000         Payment Processor       None
# 1001                      None       2014
#
#                                                founders  \
# 0                                      [ ("CZ"), Yi He]
# 1                                                  None
# 2                                       [J. R. D. Tata]
# 3                                                  None
# 4                               [Micree Zhan, Jihan Wu]
# ...                                                 ...
# 997   [Gregory Maxwell, Pieter Wuille, Matt Corallo,...
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                         [Ben Delo]
#
#                                   headquarters key_people services  \
# 0                                         None       None     None
# 1                             [Taipei, Taiwan]       None     None
# 2                        [Mumbai, Maharashtra]       None     None
# 3     [Oklahoma City, Oklahoma, United States]       None     None
# 4                             [Beijing, China]       None     None
# ...                                        ...        ...      ...
# 997               [Victoria, British Columbia]       None     None
# 998                          [Berlin, Germany]       None     None
# 999                                       None       None     None
# 1000                   [Atlanta, Georgia, USA]       None     None
# 1001                              [Seychelles]       None     None
#
#                              revenue  \
# 0                              [US$]
# 1                              [NT$]
# 2     [ ,  (US$25 billion),  (2022)]
# 3                               None
# 4                               None
# ...                              ...
# 997                             None
# 998                             None
# 999                             None
# 1000                            None
# 1001                            None
#
#                                        operating_income  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 51,687 crore,  (US$6.5 billion), [1],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                                            total_assets  \
# 0                                                  None
# 1                                                  None
# 2     [ , ₹, 141,514 crore,  (US$18 billion), [2],  ...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 997                                                None
# 998                                                None
# 999                                                None
# 1000                                               None
# 1001                                               None
#
#                            number_of_employees  \
# 0                                         None
# 1                                         None
# 2              [616,171, [3],  (October 2022)]
# 3                                         None
# 4                                         None
# ...                                        ...
# 997   [50–100, [, citation needed, ],  (2014)]
# 998                                       None
# 999                                       None
# 1000                                      None
# 1001                                      None
#
#                                            website
# 0                            [www, .binance, .com]
# 1     [www.85cafe.com, [1], www.85cbakerycafe.com]
# 2                                [www, .tcs, .com]
# 3                                  [www.apmex.com]
# 4                                  [bitmain, .com]
# ...                                            ...
# 997                            [blockstream, .com]
# 998                                           None
# 999                         [www, .bitstamp, .net]
# 1000                                          None
# 1001                          [www, .bitmex, .com]
#
# [1002 rows x 13 columns]

# %%
df.headquarters = df.headquarters.apply(lambda x: x[0] if x is not None else x)

# %%
list_without_none = list()
for i in df.headquarters:
    if i is not None:
        list_without_none.append(i)

print(list_without_none)
# Out:
# ['Taipei', 'Mumbai', 'Oklahoma City, Oklahoma', 'Beijing, China', 'Palo Alto, CA', 'New Brunswick, New Jersey', 'One Microsoft Way', 'Bentonville, Arkansas', 'Saint Kitts and Nevis', 'Northern Cross, Malahide Road, Dublin, Ireland', 'Ottawa', 'Oakland', 'Neckarsulm', 'Beijing', 'Essen', 'Deerfield, Illinois', 'Atlanta, Georgia', 'Brampton', '1000 ', 'Paris', 'Bella Vista, New South Wales', 'Goodlettsville, Tennessee', 'Issaquah, Washington', 'Delft', 'Saint-Étienne', 'Croix', 'Nanjing', 'Bangkok', 'Düsseldorf', 'Arteixo', 'Bologna', 'San Francisco, California', 'Hamburg', 'Beaverton, Oregon', 'New York City', 'Memphis, Tennessee', 'Monterrey', 'Karlsruhe', 'Solna', 'Madrid', 'Brackenfell', '40 rue de Sèvres, Paris 7e, France', 'West Des Moines, Iowa', 'Jamsil-dong', "Villeneuve d'Ascq", 'Kochi', 'Mumbai', 'Malad', 'Mumbai', 'Mumbai', 'Reykjavík', 'Hyderabad, Telangana', 'Chennai', 'Mumbai, Maharashtra', 'Mumbai', 'Chennai', 'Mumbai', 'Mumbai', 'Chennai', 'Mumbai, Maharashtra', 'India', 'Chembur', 'Oslo', 'Koganei, Tokyo', 'Pasig', 'Victoria Island', 'Ekaterinburg', 'Saint Petersburg', 'Manila', 'St. Petersburg, Russia', 'Moscow', 'Moscow', 'Saint-Petersburg', 'Cape Town', 'Akademika Korolyova str.', 'Nonhyeon-dong', 'Belgrade', 'Moscow', 'Saint Petersburg', 'Nambusunhwan', 'Istanbul', 'London, England', 'Broadcasting House', 'London, United Kingdom', 'Shepperton', 'Brooklyn, New York', 'Bridgend', 'Bangkok', 'London', 'Sheffield', 'London', 'New York City', 'Greenwich, Connecticut', 'St Margarets, London', 'United States', 'United States', 'Hollywood, California', 'Hollywood, California', 'Century City, California', '4000 Warner Blvd', 'Toronto', 'Glendale, California', '723 Seventh Avenue, New York, NY', 'Fort Lee, New Jersey', 'United States', 'The Bronx', 'Hollywood, California', 'Century City, Los Angeles, California', 'United States', 'New York City', 'Santa Monica, California', 'Santa Monica', 'Philadelphia, Pennsylvania', 'Studio City', '500 South Buena Vista Street', 'Letterman Digital Arts Center', 'Medford, Oregon', 'Beverly Hills, California', 'Melbourne', 'Los Angeles, California', 'Los Angeles, California', '4000 Warner Blvd', 'Los Angeles, California', 'Bayonne, New Jersey', 'London', 'Edendale, California', 'Culver City, California', 'Los Angeles, California', 'Albany, Georgia', '10202 West Washington Boulevard', 'Chicago', 'Century City', '10202 West Washington Boulevard', 'New York City', 'Los Angeles', 'Santa Monica, California', 'New York, New York', '10202 West Washington Boulevard', 'Santa Monica', 'Los Angeles, California', 'Universal City, California', 'Beverly Hills, California', 'Pico Boulevard', 'Minneapolis', 'Atlanta, Georgia', 'Hudson Street', 'Los Angeles', 'Century City', '1384 Broadway', 'Burbank, California', '500 South Buena Vista Street', 'United States', 'Los Angeles', '4000 Warner Blvd.', '500 South Buena Vista Street', 'Walt Disney Studios', 'Culver City, California', 'New York City', '10 Universal City Plaza', 'Santa Monica, California', 'Utah', 'New York City', 'Universal City, California', 'Studio City, Los Angeles', 'Hollywood, California', 'Avenue of the Americas', 'Austin Studios', 'Poverty Row', 'Scottsdale, Arizona', 'Los Angeles, California', 'Los Angeles', 'New York City, New York', 'Los Angeles', 'New York City', 'California', 'Beverly Hills, California', 'Edendale, Los Angeles', 'Albany, Georgia', 'Irving, Texas', 'Santa Monica Boulevard', 'Burbank', 'United States', 'New York', '500 South Buena Vista Street', 'Charlottesville', ', ', 'Springdale, Arkansas', 'Chatsworth, Los Angeles', 'Sonoma County, California', 'Universal City, California', 'Miami', 'Beverly Hills, California', 'United States', 'Los Angeles, California', 'Beverly Hills, California', 'Nashville, Tennessee', 'United States', 'New York City', 'Universal City, California', '10202 West Washington Boulevard', 'Santa Monica, California', 'Los Angeles', 'Brentwood, Los Angeles', 'Beverly Hills, California', 'Los Ange ...

# %%
#extract country
import pycountry

headquarters_list = list()
for i in df.headquarters:
    if i is not None:
        headquarters_list.append(i)

print(len(headquarters_list))


country_list = list()
for text in headquarters_list:
    for country in pycountry.countries:
        if country.name in text:
            # print(country.name)
            country_list.append(country.name)

# print(country_list)
print(len(country_list))

country_to_count = dict()
for i in country_list:
    if i not in country_to_count.keys():
        country_to_count[i] = 1
    else:
        country_to_count[i] += 1

print(country_to_count)
d = {'CountryName': country_to_count.keys(), 'User_Percent': country_to_count.values()}
df_country = pd.DataFrame(data=d)
# df_country.User_Percent = df_country.User_Percent.apply(lambda x: int(x)/len(country_list))

df_country
# Out:
# 965
# 90
# {'China': 2, 'Jersey': 8, 'Saint Kitts and Nevis': 1, 'Ireland': 1, 'Georgia': 6, 'France': 2, 'India': 8, 'United Kingdom': 3, 'United States': 9, 'South Africa': 2, 'Australia': 2, 'Norway': 1, 'Malaysia': 1, 'Japan': 3, 'Italy': 2, 'Mexico': 2, 'Canada': 1, 'Sweden': 1, 'Greece': 1, 'Germany': 4, 'Austria': 1, 'Denmark': 1, 'Hong Kong': 7, 'Singapore': 5, 'Belgium': 1, 'Luxembourg': 2, 'Gibraltar': 1, 'Switzerland': 3, 'Seychelles': 3, 'Bangladesh': 1, 'Netherlands': 1, 'Cayman Islands': 1, 'Libya': 1, 'Ghana': 1, 'Congo': 1}
#               CountryName  User_Percent
# 0                   China             2
# 1                  Jersey             8
# 2   Saint Kitts and Nevis             1
# 3                 Ireland             1
# 4                 Georgia             6
# 5                  France             2
# 6                   India             8
# 7          United Kingdom             3
# 8           United States             9
# 9            South Africa             2
# 10              Australia             2
# 11                 Norway             1
# 12               Malaysia             1
# 13                  Japan             3
# 14                  Italy             2
# 15                 Mexico             2
# 16                 Canada             1
# 17                 Sweden             1
# 18                 Greece             1
# 19                Germany             4
# 20                Austria             1
# 21                Denmark             1
# 22              Hong Kong             7
# 23              Singapore             5
# 24                Belgium             1
# 25             Luxembourg             2
# 26              Gibraltar             1
# 27            Switzerland             3
# 28             Seychelles             3
# 29             Bangladesh             1
# 30            Netherlands             1
# 31         Cayman Islands             1
# 32                  Libya             1
# 33                  Ghana             1
# 34                  Congo             1

# %%
#function to convert to alpah2 country codes and continents
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2

def get_continent(col):
    try:
        cn_a2_code =  country_name_to_country_alpha2(col)
    except:
        cn_a2_code = 'Unknown'
    try:
        cn_continent = country_alpha2_to_continent_code(cn_a2_code)
    except:
        cn_continent = 'Unknown'
    return (cn_a2_code, cn_continent)

list_tuple = list()
for i in df_country.CountryName:
    list_tuple.append(get_continent(i))

print(len(list_tuple))
df_country = df_country.assign(codes = list_tuple)
print(list_tuple[0][0])
df_country = df_country.assign(Country = list(zip(*list_tuple))[0])
df_country = df_country.assign(Continent = list(zip(*list_tuple))[1])
df_country
# Out:
# 35
# CN
#               CountryName  User_Percent     codes Country Continent
# 0                   China             2  (CN, AS)      CN        AS
# 1                  Jersey             8  (JE, EU)      JE        EU
# 2   Saint Kitts and Nevis             1  (KN, NA)      KN        NA
# 3                 Ireland             1  (IE, EU)      IE        EU
# 4                 Georgia             6  (GE, AS)      GE        AS
# 5                  France             2  (FR, EU)      FR        EU
# 6                   India             8  (IN, AS)      IN        AS
# 7          United Kingdom             3  (GB, EU)      GB        EU
# 8           United States             9  (US, NA)      US        NA
# 9            South Africa             2  (ZA, AF)      ZA        AF
# 10              Australia             2  (AU, OC)      AU        OC
# 11                 Norway             1  (NO, EU)      NO        EU
# 12               Malaysia             1  (MY, AS)      MY        AS
# 13                  Japan             3  (JP, AS)      JP        AS
# 14                  Italy             2  (IT, EU)      IT        EU
# 15                 Mexico             2  (MX, NA)      MX        NA
# 16                 Canada             1  (CA, NA)      CA        NA
# 17                 Sweden             1  (SE, EU)      SE        EU
# 18                 Greece             1  (GR, EU)      GR        EU
# 19                Germany             4  (DE, EU)      DE        EU
# 20                Austria             1  (AT, EU)      AT        EU
# 21                Denmark             1  (DK, EU)      DK        EU
# 22              Hong Kong             7  (HK, AS)      HK        AS
# 23              Singapore             5  (SG, AS)      SG        AS
# 24                Belgium             1  (BE, EU)      BE        EU
# 25             Luxembourg             2  (LU, EU)      LU        EU
# 26              Gibraltar             1  (GI, EU)      GI        EU
# 27            Switzerland             3  (CH, EU)      CH        EU
# 28             Seychelles             3  (SC, AF)      SC        AF
# 29             Bangladesh             1  (BD, AS)      BD        AS
# 30            Netherlands             1  (NL, EU)      NL        EU
# 31         Cayman Islands             1  (KY, NA)      KY        NA
# 32                  Libya             1  (LY, AF)      LY        AF
# 33                  Ghana             1  (GH, AF)      GH        AF
# 34                  Congo             1  (CG, AF)      CG        AF

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="http")
def geolocate(country):
    try:
        # Geolocate the center of the country
        loc = geolocator.geocode(country)
        # And return latitude and longitude
        return (loc.latitude, loc.longitude)
    except:
        # Return missing value
        return np.nan

list_tuple = list()
for i in df_country.CountryName:
    list_tuple.append(geolocate(i))

print(len(list_tuple))
df_country = df_country.assign(Geolocate = list_tuple)
print(list_tuple[0][0])
df_country = df_country.assign(Latitude = list(zip(*list_tuple))[0])
df_country = df_country.assign(Longitude = list(zip(*list_tuple))[1])
df_country
# Out:
# 35
# 35.000074
#               CountryName  User_Percent     codes Country Continent  \
# 0                   China             2  (CN, AS)      CN        AS
# 1                  Jersey             8  (JE, EU)      JE        EU
# 2   Saint Kitts and Nevis             1  (KN, NA)      KN        NA
# 3                 Ireland             1  (IE, EU)      IE        EU
# 4                 Georgia             6  (GE, AS)      GE        AS
# 5                  France             2  (FR, EU)      FR        EU
# 6                   India             8  (IN, AS)      IN        AS
# 7          United Kingdom             3  (GB, EU)      GB        EU
# 8           United States             9  (US, NA)      US        NA
# 9            South Africa             2  (ZA, AF)      ZA        AF
# 10              Australia             2  (AU, OC)      AU        OC
# 11                 Norway             1  (NO, EU)      NO        EU
# 12               Malaysia             1  (MY, AS)      MY        AS
# 13                  Japan             3  (JP, AS)      JP        AS
# 14                  Italy             2  (IT, EU)      IT        EU
# 15                 Mexico             2  (MX, NA)      MX        NA
# 16                 Canada             1  (CA, NA)      CA        NA
# 17                 Sweden             1  (SE, EU)      SE        EU
# 18                 Greece             1  (GR, EU)      GR        EU
# 19                Germany             4  (DE, EU)      DE        EU
# 20                Austria             1  (AT, EU)      AT        EU
# 21                Denmark             1  (DK, EU)      DK        EU
# 22              Hong Kong             7  (HK, AS)      HK        AS
# 23              Singapore             5  (SG, AS)      SG        AS
# 24                Belgium             1  (BE, EU)      BE        EU
# 25             Luxembourg             2  (LU, EU)      LU        EU
# 26              Gibraltar             1  (GI, EU)      GI        EU
# 27            Switzerland             3  (CH, EU)      CH        EU
# 28             Seychelles             3  (SC, AF)      SC        AF
# 29             Bangladesh             1  (BD, AS)      BD        AS
# 30            Netherlands             1  (NL, EU)      NL        EU
# 31         Cayman Islands             1  (KY, NA)      KY        NA
# 32                  Libya             1  (LY, AF)      LY        AF
# 33                  Ghana             1  (GH, AF)      GH        AF
# 34                  Congo             1  (CG, AF)      CG        AF
#
#                                   Geolocate   Latitude   Longitude
# 0                   (35.000074, 104.999927)  35.000074  104.999927
# 1                  (49.2214561, -2.1358386)  49.221456   -2.135839
# 2                  (17.250512, -62.6725973)  17.250512  -62.672597
# 3                   (52.865196, -7.9794599)  52.865196   -7.979460
# 4                 (32.3293809, -83.1137366)  32.329381  -83.113737
# 5                    (46.603354, 1.8883335)  46.603354    1.888334
# 6                  (22.3511148, 78.6677428)  22.351115   78.667743
# 7                  (54.7023545, -3.2765753)  54.702354   -3.276575
# 8                 (39.7837304, -100.445882)  39.783730 -100.445882
# 9                  (-28.8166236, 24.991639) -28.816624   24.991639
# 10                   (-24.7761086, 134.755) -24.776109  134.755000
# 11                  (60.5000209, 9.0999715)  60.500021    9.099972
# 12                 (4.5693754, 102.2656823)   4.569375  102.265682
# 13                (36.5748441, 139.2394179)  36.574844  139.239418
# 14                  (42.6384261, 12.674297)  42.638426   12.674297
# 15               (23.6585116, -102.0077097)  23.658512 -102.007710
# 16                (61.0666922, -107.991707)  61.066692 -107.991707
# 17                 (59.6749712, 14.5208584)  59.674971   14.520858
# 18                 (38.9953683, 21.9877132)  38.995368   21.987713
# 19                 (51.1638175, 10.4478313)  51.163818   10.447831
# 20                     (47.59397, 14.12456)  47.593970   14.124560
# 21                  (55.670249, 10.3333283)  55.670249   10.333328
# 22                (22.2793278, 114.1628131)  22.279328  114.162813
# 23                  (1.357107, 103.8194992)   1.357107  103.819499
# 24                  (50.6402809, 4.6667145)  50.640281    4.666715
# 25                  (49.8158683, 6.1296751)  49.815868    6.129675
# 26                 (36.1285933, -5.3474761)  36.128593   -5.347476
# 27                  (46.7985624, 8.2319736)  46.798562    8.231974
# 28                 (-4.6574977, 55.4540146)  -4.657498   55.454015
# 29                 (24.4769288, 90.2934413)  24.476929   90.293441
# 30                  (52.2434979, 5.6343227)  52.243498    5.634323
# 31  (19.703182249999998, -79.9174627243246)  19.703182  -79.917463
# 32                 (26.8234472, 18.1236723)  26.823447   18.123672
# 33                  (8.0300284, -1.0800271)   8.030028   -1.080027
# 34                 (-2.9814344, 23.8222636)  -2.981434   23.822264

# %%
# Create a world map to show distributions of users
import folium
from folium.plugins import MarkerCluster
#empty map
world_map= folium.Map(tiles="cartodbpositron")
marker_cluster = MarkerCluster().add_to(world_map)
#for each coordinate, create circlemarker of user percent
for i in range(len(df_country)):
        lat = df_country.iloc[i]['Latitude']
        long = df_country.iloc[i]['Longitude']
        radius=5
        popup_text = """Country : {}<br>
                    # %of #Companies : {}<br>"""
        popup_text = popup_text.format(df_country.iloc[i]['Country'],
                                   df_country.iloc[i]['User_Percent']
                                   )
        folium.CircleMarker(location = [lat, long], radius=radius, popup= popup_text, fill =True, weight = 5).add_to(marker_cluster)
#show the map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2634b1b995cc4a35e7ee99e6abb9ff38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2634b1b995cc4a35e7ee99e6abb9ff38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2634b1b995cc4a35e7ee99e6abb9ff38 = L.map(
#                 &quot;map_2634b1b995cc4a35e7ee99e6abb9ff38&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f86d338555be09c87245b1fbfa55440a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2634b1b995cc4a35e7ee99e6abb9ff38);
#
#
#             var marker_cluster_57b45d00239e0301948fc7d9115a646f = L.markerClusterGroup(
#                 {}
#             );
#             map_2634b1b995cc4a35e7ee99e6abb9ff38.addLayer(marker_cluster_57b45d00239e0301948fc7d9115a646f);
#
#
#             var circle_marker_44df8d09202728fbb3855eb011823cdd = L.circleMarker(
#                 [35.000074, 104.999927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_57b45d00239e0301948fc7d9115a646f);
#
#
#         var popup_92ea0820f2c1d8233e4c9dbc66b5fe55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aca7994acee18f87fb1579c850a6ae6d = $(`&lt;div id=&quot;html_aca7994acee18f87fb1579c850a6ae6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Country : CN&lt;br&gt;                     %of #Companies : 2&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_92ea0820f2c1d8233e4c9dbc66b5fe55.setContent(html_aca7994acee18f87fb1579c850a6ae6d);
#
#
#
#         circle_marker_44df8d09202728fbb3855eb011823cdd.bindPopup(popup_92ea0820f2c1d8233e4c9dbc66b5fe55)
#         ;
#
#
#
#
#             var circle_marker_49e4989abfc9ded9ff90af17a445b1a7 = L.circleMarker(
#                 [49.2214561, -2.1358386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_57b45d00239e0301948fc7d9115a646f);
#
#
#         var popup_47223b705f81c3df592e405fb8f9790f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4429f897638babebbefbad19573b0671 = $(`&lt;div id=&quot;html_4429f897638babebbefbad19573b0671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Country : JE&lt;br&gt;                     %of #Companies : 8&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_47223b705f81c3df592e405fb8f9790f.setContent(html_4429f897638babebbefbad19573b0671);
#
#
#
#         circle_marker_49e4989abfc9ded9ff90af17a445b1a7.bindPopup(popup_47223b705f81c3df592e405fb8f9790f)
#         ;
#
#
#
#
#             var circle_marker_1209860bed2b605369a6509152da3b1b = L.circleMarker(
#                 [17.250512, -62.6725973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(marker_cluster_57b45d00239e0301948fc7d9115a646f);
#
#
#         var popup_830fd9ce4cf0

# %% [markdown]
# # TEMPI ESTRAZIONI

# %%
# Opening JSON file
file_name_time = './../output/output_wiki_time.json'

df_time = pd.read_json(file_name_time)

# %%
df_time

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(100).index, df_time.head(100)['time'], color='blue')

# %%
times = [[100, df_time.head(100)['time'].min(), df_time.head(100)['time'].mean(), df_time.head(500)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(500).index, df_time.head(500)['time'], color='blue')

# %%
times = [[500, df_time.head(500)['time'].min(), df_time.head(500)['time'].mean(), df_time.head(500)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(1000).index, df_time.head(1000)['time'], color='blue')

# %%
times = [[1000, df_time.head(1000)['time'].min(), df_time.head(1000)['time'].mean(), df_time.head(1000)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table

# %%
# print(df_table.Massimo)
time = df_time.head(1)['time'].astype('float').values[0]
value = df_table.Massimo.values[0]
mask = df_time['time'].astype('float') == value
filtered_df = df_time[df_time['time']== value]
filtered_df
