# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy

# Apply the default theme at seaborn
sns.set_theme()

# %%
# Opening JSON file
file_name = './../output/output_wiki.json'

df = pd.read_json(file_name)

# %%
df
# Out:
#                  name                     type               industry  \
# 0            AXA S.A.                 [Public]   [Financial services]
# 1      ING Groep N.V.  [Naamloze vennootschap]   [Financial services]
# 2                 Eni     [Società per azioni]          [Oil and gas]
# 3             E.ON SE      [Societas Europaea]     [Electric utility]
# 4       Goldline, LLC        [Private company]                     []
# ..                ...                      ...                    ...
# 889          Engie SA        [Société Anonyme]     [Electric utility]
# 890  BNP Paribas S.A.        [Société Anonyme]   [Financial services]
# 891           Allianz                 [Public]   [Financial services]
# 892         Exor N.V.           [Public, N.V.]      [Holding company]
# 893         Carrefour        [Société anonyme]  [Retail, Wholesaling]
#
#                                                founded  \
# 0                                               [1816]
# 1                                [1991 through merger]
# 2                                   [10 February 1953]
# 3                                               [2000]
# 4                                              [1960 ]
# ..                                                 ...
# 889                                     [22 July 2008]
# 890  [1848,  (Comptoir National d'Escompte de Paris...
# 891                                  [5 February 1890]
# 892                                     [27 July 1927]
# 893                                   [1 January 1958]
#
#                                 founders  \
# 0                                     []
# 1                                     []
# 2                                     []
# 3                                     []
# 4                                     []
# ..                                   ...
# 889                                   []
# 890                                   []
# 891                    [Carl von Thieme]
# 892                   [Giovanni Agnelli]
# 893  [Marcel Fournier, Jacques Defforey]
#
#                                 headquarters key_people  \
# 0                                    [Paris]         []
# 1                                [Amsterdam]         []
# 2                       [Rome, Lazio, Italy]         []
# 3                                    [Essen]         []
# 4            [Los Angeles, California, U.S.]         []
# ..                                       ...        ...
# 889                     [La Défense, France]         []
# 890  [Boulevard des Italiens, Paris, France]         []
# 891                                 [Munich]         []
# 892                 [Amsterdam, Netherlands]         []
# 893                         [Massy, Essonne]         []
#
#                                               services  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [Electricity generation, distribution, explora...
# 4                                                   []
# ..                                                 ...
# 889                                                 []
# 890                                                 []
# 891                                                 []
# 892                                                 []
# 893  [Cash and carry, warehouse club, discount stor...
#
#                                                revenue  \
# 0                                                  [€]
# 1                                                  [€]
# 2                            [ €76.575 billion (2021)]
# 3                                                  [€]
# 4                                                   []
# ..                                                 ...
# 889                                                [€]
# 890                                                [€]
# 891                                                [€]
# 892                          [ €33.617 billion (2021)]
# 893  [ 35.28 billion (France)\n,  21.28 billion (Eu...
#
#                                       operating_income  \
# 0                        [ €5.91 billion  (2021), [2]]
# 1                        [€3.81 billion , (2020), [2]]
# 2                       [ €12.341 billion (2021), [1]]
# 3                        [ €5.305 billion (2021), [1]]
# 4                                                   []
# ..                                                 ...
# 889                        [ €5.7 billion (2019), [1]]
# 890                       [ €12.2 billion (2021), [2]]
# 891                      [ €13.40 billion (2021), [1]]
# 892                                                 []
# 893  [\n,  €2.27 billion (2021), [2], [1], \n,  768...
#
#                         total_assets  \
# 0      [ €775.5 billion (2021), [2]]
# 1    [€937.28 billion , (2020), [2]]
# 2     [ €137.76 billion (2021), [1]]
# 3    [ €119.759 billion (2021), [1]]
# 4                                 []
# ..                               ...
# 889    [ €159.8 billion (2019), [1]]
# 890     [ €2.6 trillion (2021), [2]]
# 891    [ €1.14 trillion (2021), [1]]
# 892   [ €91.111 billion (2021), [1]]
# 893    [ €47.67 billion (2021), [2]]
#
#                                    number_of_employees              website
# 0                                [149,000 (2021), [2]]    [www, .axa, .com]
# 1                               [55,901 , (2020), [2]]          [ing, .com]
# 2                                [ 32,689 (2021), [1]]    [www, .eni, .com]
# 3                                 [72,169 (2021), [1]]    [www, .eon, .com]
# 4                                                   []       [Goldline.com]
# ..                                                 ...                  ...
# 889                                   [171,100 (2019)]   [engie, .com, /en]
# 890                              [190,000 (2022), [2]]   [group.bnpparibas]
# 891                              [155,411 (2021), [1]]      [allianz, .com]
# 892                      [74,353 (approx) (2021), [1]]           [exor.com]
# 893  [\n,  319,565 , (2021), [1], \n,  115,310 (, L...  [www.carrefour.com]
#
# [894 rows x 13 columns]

# %%
df = df.applymap(lambda x: None if len(x)==0 else x)

# %%
df
# Out:
#                  name                     type               industry  \
# 0            AXA S.A.                 [Public]   [Financial services]
# 1      ING Groep N.V.  [Naamloze vennootschap]   [Financial services]
# 2                 Eni     [Società per azioni]          [Oil and gas]
# 3             E.ON SE      [Societas Europaea]     [Electric utility]
# 4       Goldline, LLC        [Private company]                   None
# ..                ...                      ...                    ...
# 889          Engie SA        [Société Anonyme]     [Electric utility]
# 890  BNP Paribas S.A.        [Société Anonyme]   [Financial services]
# 891           Allianz                 [Public]   [Financial services]
# 892         Exor N.V.           [Public, N.V.]      [Holding company]
# 893         Carrefour        [Société anonyme]  [Retail, Wholesaling]
#
#                                                founded  \
# 0                                               [1816]
# 1                                [1991 through merger]
# 2                                   [10 February 1953]
# 3                                               [2000]
# 4                                              [1960 ]
# ..                                                 ...
# 889                                     [22 July 2008]
# 890  [1848,  (Comptoir National d'Escompte de Paris...
# 891                                  [5 February 1890]
# 892                                     [27 July 1927]
# 893                                   [1 January 1958]
#
#                                 founders  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ..                                   ...
# 889                                 None
# 890                                 None
# 891                    [Carl von Thieme]
# 892                   [Giovanni Agnelli]
# 893  [Marcel Fournier, Jacques Defforey]
#
#                                 headquarters key_people  \
# 0                                    [Paris]       None
# 1                                [Amsterdam]       None
# 2                       [Rome, Lazio, Italy]       None
# 3                                    [Essen]       None
# 4            [Los Angeles, California, U.S.]       None
# ..                                       ...        ...
# 889                     [La Défense, France]       None
# 890  [Boulevard des Italiens, Paris, France]       None
# 891                                 [Munich]       None
# 892                 [Amsterdam, Netherlands]       None
# 893                         [Massy, Essonne]       None
#
#                                               services  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    [Electricity generation, distribution, explora...
# 4                                                 None
# ..                                                 ...
# 889                                               None
# 890                                               None
# 891                                               None
# 892                                               None
# 893  [Cash and carry, warehouse club, discount stor...
#
#                                                revenue  \
# 0                                                  [€]
# 1                                                  [€]
# 2                            [ €76.575 billion (2021)]
# 3                                                  [€]
# 4                                                 None
# ..                                                 ...
# 889                                                [€]
# 890                                                [€]
# 891                                                [€]
# 892                          [ €33.617 billion (2021)]
# 893  [ 35.28 billion (France)\n,  21.28 billion (Eu...
#
#                                       operating_income  \
# 0                        [ €5.91 billion  (2021), [2]]
# 1                        [€3.81 billion , (2020), [2]]
# 2                       [ €12.341 billion (2021), [1]]
# 3                        [ €5.305 billion (2021), [1]]
# 4                                                 None
# ..                                                 ...
# 889                        [ €5.7 billion (2019), [1]]
# 890                       [ €12.2 billion (2021), [2]]
# 891                      [ €13.40 billion (2021), [1]]
# 892                                               None
# 893  [\n,  €2.27 billion (2021), [2], [1], \n,  768...
#
#                         total_assets  \
# 0      [ €775.5 billion (2021), [2]]
# 1    [€937.28 billion , (2020), [2]]
# 2     [ €137.76 billion (2021), [1]]
# 3    [ €119.759 billion (2021), [1]]
# 4                               None
# ..                               ...
# 889    [ €159.8 billion (2019), [1]]
# 890     [ €2.6 trillion (2021), [2]]
# 891    [ €1.14 trillion (2021), [1]]
# 892   [ €91.111 billion (2021), [1]]
# 893    [ €47.67 billion (2021), [2]]
#
#                                    number_of_employees              website
# 0                                [149,000 (2021), [2]]    [www, .axa, .com]
# 1                               [55,901 , (2020), [2]]          [ing, .com]
# 2                                [ 32,689 (2021), [1]]    [www, .eni, .com]
# 3                                 [72,169 (2021), [1]]    [www, .eon, .com]
# 4                                                 None       [Goldline.com]
# ..                                                 ...                  ...
# 889                                   [171,100 (2019)]   [engie, .com, /en]
# 890                              [190,000 (2022), [2]]   [group.bnpparibas]
# 891                              [155,411 (2021), [1]]      [allianz, .com]
# 892                      [74,353 (approx) (2021), [1]]           [exor.com]
# 893  [\n,  319,565 , (2021), [1], \n,  115,310 (, L...  [www.carrefour.com]
#
# [894 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# name                     0
# type                   138
# industry                76
# founded                 43
# founders               456
# headquarters            36
# key_people             894
# services               748
# revenue                463
# operating_income       637
# total_assets           589
# number_of_employees    451
# website                160
# dtype: int64

# %%
print("Number of cells:", df.size)
print("Number of value None:", df.isnull().sum().sum())
print("Number of row:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of cells: 11622
# Number of value None: 4691
# Number of row: 894
# Number of columns: 13

# %%
# to extract the first elements from list
df.type = df.type.apply(lambda x: x[0] if x is not None else x)

# %%
#type
print(df['type'].value_counts())
type_companies = df['type'].value_counts()
type(type_companies)
#the top 10 types of companies are taken here because there are many types
type_companies_top10 = type_companies.head(10)
keys = type_companies_top10.index
values = type_companies_top10.values

print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("top 10 type of companies")
plt.xlabel("number of companies")
plt.show()
# Out:
# Public                        202
# Private                       116
# Subsidiary                     74
# Public company                 73
# Division                       21
#                              ...
# Film distribution               1
# JSC                             1
# Dual-listed public company      1
# d.o.o.                          1
# Société anonyme                 1
# Name: type, Length: 123, dtype: int64
# Index(['Public', 'Private', 'Subsidiary', 'Public company', 'Division',
#        'State-owned enterprise', 'Production company',
#        'Public limited company', 'Corporation', 'Privately held company'],
#       dtype='object')
# [202 116  74  73  21  20  12  12  11  10]

# %%
# to extract the first elements from list
df.industry = df.industry.apply(lambda x: x[0] if x is not None else x)

# %%
#industry
print(df['industry'].value_counts())
industry_companies = df['industry'].value_counts()
type(industry_companies)
#the top 10 industry
industry_companies_top10 = industry_companies.head(10)
keys = industry_companies_top10.index
values = industry_companies_top10.values

print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.2, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("top 10 industry of companies")
plt.xlabel("number of companies")
plt.show()
# Out:
# Film                       69
# Entertainment              64
# Oil and gas                55
# Motion pictures            47
# Petroleum industry         31
#                            ..
# oil and gas exploration     1
# Filmmaking                  1
# Motion Picture              1
# Manufacturing               1
# Chemicals                   1
# Name: industry, Length: 215, dtype: int64
# Index(['Film', 'Entertainment', 'Oil and gas', 'Motion pictures',
#        'Petroleum industry', 'Information technology', 'Petroleum',
#        'Film production', 'Energy', 'Oil and gas industry'],
#       dtype='object')
# [69 64 55 47 31 26 25 17 17 17]

# %%
# to extract the first elements from list
df.founded = df.founded.apply(lambda x: x[0] if x is not None else x)

# df.founded.apply(lambda txt: int(s) for s in txt for w in s.split() if w.isdigit() and len(s)==4)

# %%
companies_to_date = {'<1950': 0, '1950-2000': 0, '>2000': 0}
#generate dictionary with key an interval time and with value number of companies in that time interval
for s in df.founded.values:
    if s is not None:
        for w in s.split():
            if s.isdigit() and len(s)==4:
                s = int(s)
                type(s)
                if s<1950:
                    companies_to_date['<1950'] += 1
                elif 1950 < s < 2000:
                    companies_to_date['1950-2000'] += 1
                else:
                    companies_to_date['>2000'] += 1

print(companies_to_date)
companies_to_date = pd.Series(companies_to_date)
keys = companies_to_date.index
values = companies_to_date.values
print(keys)
print(values)

#graph with mathplotlib
fig, ax = plt.subplots()
width = 0.75
fig.set_size_inches(10, 5)
ind = np.arange(len(values))
ax.barh(keys, values, width, color = "green")

for i, v in enumerate(values):
    ax.text(v + 1, i - 0.05, str(v),
            color = 'green', fontweight = 'bold')
plt.ylabel("fondation date")
plt.xlabel("number of companies")
plt.show()
# Out:
# {'<1950': 91, '1950-2000': 217, '>2000': 120}
# Index(['<1950', '1950-2000', '>2000'], dtype='object')
# [ 91 217 120]

# %%
df
# Out:
#                  name                   type            industry  \
# 0            AXA S.A.                 Public  Financial services
# 1      ING Groep N.V.  Naamloze vennootschap  Financial services
# 2                 Eni     Società per azioni         Oil and gas
# 3             E.ON SE      Societas Europaea    Electric utility
# 4       Goldline, LLC        Private company                None
# ..                ...                    ...                 ...
# 889          Engie SA        Société Anonyme    Electric utility
# 890  BNP Paribas S.A.        Société Anonyme  Financial services
# 891           Allianz                 Public  Financial services
# 892         Exor N.V.                 Public     Holding company
# 893         Carrefour        Société anonyme              Retail
#
#                  founded                             founders  \
# 0                   1816                                 None
# 1    1991 through merger                                 None
# 2       10 February 1953                                 None
# 3                   2000                                 None
# 4                  1960                                  None
# ..                   ...                                  ...
# 889         22 July 2008                                 None
# 890                 1848                                 None
# 891      5 February 1890                    [Carl von Thieme]
# 892         27 July 1927                   [Giovanni Agnelli]
# 893       1 January 1958  [Marcel Fournier, Jacques Defforey]
#
#                                 headquarters key_people  \
# 0                                    [Paris]       None
# 1                                [Amsterdam]       None
# 2                       [Rome, Lazio, Italy]       None
# 3                                    [Essen]       None
# 4            [Los Angeles, California, U.S.]       None
# ..                                       ...        ...
# 889                     [La Défense, France]       None
# 890  [Boulevard des Italiens, Paris, France]       None
# 891                                 [Munich]       None
# 892                 [Amsterdam, Netherlands]       None
# 893                         [Massy, Essonne]       None
#
#                                               services  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    [Electricity generation, distribution, explora...
# 4                                                 None
# ..                                                 ...
# 889                                               None
# 890                                               None
# 891                                               None
# 892                                               None
# 893  [Cash and carry, warehouse club, discount stor...
#
#                                                revenue  \
# 0                                                  [€]
# 1                                                  [€]
# 2                            [ €76.575 billion (2021)]
# 3                                                  [€]
# 4                                                 None
# ..                                                 ...
# 889                                                [€]
# 890                                                [€]
# 891                                                [€]
# 892                          [ €33.617 billion (2021)]
# 893  [ 35.28 billion (France)\n,  21.28 billion (Eu...
#
#                                       operating_income  \
# 0                        [ €5.91 billion  (2021), [2]]
# 1                        [€3.81 billion , (2020), [2]]
# 2                       [ €12.341 billion (2021), [1]]
# 3                        [ €5.305 billion (2021), [1]]
# 4                                                 None
# ..                                                 ...
# 889                        [ €5.7 billion (2019), [1]]
# 890                       [ €12.2 billion (2021), [2]]
# 891                      [ €13.40 billion (2021), [1]]
# 892                                               None
# 893  [\n,  €2.27 billion (2021), [2], [1], \n,  768...
#
#                         total_assets  \
# 0      [ €775.5 billion (2021), [2]]
# 1    [€937.28 billion , (2020), [2]]
# 2     [ €137.76 billion (2021), [1]]
# 3    [ €119.759 billion (2021), [1]]
# 4                               None
# ..                               ...
# 889    [ €159.8 billion (2019), [1]]
# 890     [ €2.6 trillion (2021), [2]]
# 891    [ €1.14 trillion (2021), [1]]
# 892   [ €91.111 billion (2021), [1]]
# 893    [ €47.67 billion (2021), [2]]
#
#                                    number_of_employees              website
# 0                                [149,000 (2021), [2]]    [www, .axa, .com]
# 1                               [55,901 , (2020), [2]]          [ing, .com]
# 2                                [ 32,689 (2021), [1]]    [www, .eni, .com]
# 3                                 [72,169 (2021), [1]]    [www, .eon, .com]
# 4                                                 None       [Goldline.com]
# ..                                                 ...                  ...
# 889                                   [171,100 (2019)]   [engie, .com, /en]
# 890                              [190,000 (2022), [2]]   [group.bnpparibas]
# 891                              [155,411 (2021), [1]]      [allianz, .com]
# 892                      [74,353 (approx) (2021), [1]]           [exor.com]
# 893  [\n,  319,565 , (2021), [1], \n,  115,310 (, L...  [www.carrefour.com]
#
# [894 rows x 13 columns]

# %% [markdown]
# # TEMPI ESTRAZIONI

# %%
# Opening JSON file
file_name_time = './../output/output_wiki_time.json'

df_time = pd.read_json(file_name_time)

# %%
df_time
# Out:
#                             name               type  \
# 0               Salesforce, Inc.   [Public company]
# 1                         SAP SE           [Public]
# 2          Microsoft Corporation           [Public]
# 3               TotalEnergies SE           [Public]
# 4          PayPal Holdings, Inc.           [Public]
# ...                          ...                ...
# 997                     Engie SA  [Société Anonyme]
# 998   Siemens Aktiengesellschaft           [Public]
# 999             BNP Paribas S.A.  [Société Anonyme]
# 1000                     Allianz           [Public]
# 1001                   Carrefour  [Société anonyme]
#
#                                                industry  \
# 0     [Cloud computing, Enterprise software, Consult...
# 1     [Enterprise software, Business software, Cloud...
# 2                              [Information technology]
# 3                                   [Petroleum, Energy]
# 4                                [Financial technology]
# ...                                                 ...
# 997                                  [Electric utility]
# 998                                      [Conglomerate]
# 999                                [Financial services]
# 1000                               [Financial services]
# 1001                              [Retail, Wholesaling]
#
#                                                 founded  \
# 0                                    [February 3, 1999]
# 1                                            [Weinheim]
# 2                                 [April 4, 1975,  in ]
# 3                                       [28 March 1924]
# 4                                    [Confinity, X.com]
# ...                                                 ...
# 997                                      [22 July 2008]
# 998                        [Berlin, Kingdom of Prussia]
# 999   [1848,  (Comptoir National d'Escompte de Paris...
# 1000                                  [5 February 1890]
# 1001                                   [1 January 1958]
#
#                                                founders  \
# 0     [Parker Harris, Dave Moellenhoff, Frank Doming...
# 1     [Dietmar Hopp, Hasso Plattner, Klaus Tschira, ...
# 2                              [Bill Gates, Paul Allen]
# 3                                                    []
# 4     [Max Levchin, Peter Thiel, Luke Nosek, Ken How...
# ...                                                 ...
# 997                                                  []
# 998                                [Werner von Siemens]
# 999                                                  []
# 1000                                  [Carl von Thieme]
# 1001                [Marcel Fournier, Jacques Defforey]
#
#                                            headquarters key_people  \
# 0     [Salesforce Tower, San Francisco, California, ...         []
# 1                         [Walldorf, Baden-Württemberg]         []
# 2              [One Microsoft Way, Redmond, Washington]         []
# 3                      [Tour Total, Courbevoie, France]         []
# 4            [San Jose, California, La Vista, Nebraska]         []
# ...                                                 ...        ...
# 997                                [La Défense, France]         []
# 998                                    [Munich, Berlin]         []
# 999             [Boulevard des Italiens, Paris, France]         []
# 1000                                           [Munich]         []
# 1001                                   [Massy, Essonne]         []
#
#                                                services  \
# 0                                     [Cloud computing]
# 1                                 [Applications, Cloud]
# 2     [Azure, Bing, LinkedIn, Yammer, Microsoft 365,...
# 3                                       [Fuel stations]
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998   [Business services, financing, project enginee...
# 999                                                  []
# 1000                                                 []
# 1001  [Cash and carry, warehouse club, discount stor...
#
#                                                 revenue  \
# 0                                          [ ,  (2022)]
# 1                                                   [€]
# 2                                          [ ,  (2022)]
# 3                                          [ ,  (2021)]
# 4                                                 [US$]
# ...                                                 ...
# 997                                                 [€]
# 998                           [ €62.265 billion (2021)]
# 999                                                 [€]
# 1000                                                [€]
# 1001  [ 35.28 billion (France)\n,  21.28 billion (Eu...
#
#                                        operating_income  \
# 0                          [ , US$548 million,  (2022)]
# 1                         [ €4.659 billion (2021), [1]]
# 2                         [ , US$83.4 billion,  (2022)]
# 3                         [ , US$30.5 billion,  (2021)]
# 4                        [ US$4.26 billion (2021), [3]]
# ...                                                 ...
# 997                         [ €5.7 billion (2019), [1]]
# 998                       [ €7.496 billion (2021), [2]]
# 999                        [ €12.2 billion (2021), [2]]
# 1000                      [ €13.40 billion (2021), [1]]
# 1001  [\n,  €2.27 billion (2021), [2], [1], \n,  768...
#
#                          total_assets  \
# 0      [ , US$95.21 billion,  (2022)]
# 1      [ €71.173 billion (2021), [1]]
# 2      [ , US$364.8 billion,  (2022)]
# 3      [ , US$320.5 billion,  (2021)]
# 4     [ US$75.80 billion (2021), [3]]
# ...                               ...
# 997     [ €159.8 billion (2019), [1]]
# 998   [ €139.608 billion (2021), [2]]
# 999      [ €2.6 trillion (2021), [2]]
# 1000    [ €1.14 trillion (2021), [1]]
# 1001    [ €47.67 billion (2021), [2]]
#
#                                     number_of_employees  \
# 0                                [73,542 (August 2022)]
# 1                                 [107,415 (2021), [1]]
# 2                                      [221,000 (2022)]
# 3                                 [105,476 (2020), [2]]
# 4                           [c.,  30,900,  (2021), [3]]
# ...                                                 ...
# 997                                    [171,100 (2019)]
# 998                               [303,000 (2021), [2]]
# 999                               [190,000 (2022), [2]]
# 1000                              [155,411 (2021), [1]]
# 1001  [\n,  319,565 , (2021), [1], \n,  115,310 (, L...
#
#                     website      time
# 0        [salesforce, .com]  0.055215
# 1         [www, .sap, .com]  0.087919
# 2           [microsoft.com]  0.161741
# 3     [totalenergies, .com]  0.120914
# 4      [www, .paypal, .com]  0.093921
# ...                     ...       ...
# 997      [engie, .com, /en]  0.080023
# 998   [www, .siemens, .com]  0.121239
# 999      [group.bnpparibas]  0.068112
# 1000        [allianz, .com]  0.089607
# 1001    [www.carrefour.com]  0.088403
#
# [1002 rows x 14 columns]

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(100).index, df_time.head(100)['time'], color='blue')

# %%
times = [[100, df_time.head(100)['time'].min(), df_time.head(100)['time'].mean(), df_time.head(500)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table
# Out:
#    Estrazioni    Minimo    Media   Mediana   Massimo
# 0         100  0.016642  0.39319  0.068308  0.049632

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(500).index, df_time.head(500)['time'], color='blue')

# %%
times = [[500, df_time.head(500)['time'].min(), df_time.head(500)['time'].mean(), df_time.head(500)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table
# Out:
#    Estrazioni    Minimo    Media   Mediana   Massimo
# 0         500  0.011323  0.39319  0.058232  0.044878

# %%
fig=plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(df_time.head(1000).index, df_time.head(1000)['time'], color='blue')

# %%
times = [[1000, df_time.head(1000)['time'].min(), df_time.head(1000)['time'].mean(), df_time.head(1000)['time'].median(),
          df_time.head(1000)['time'].max()]]
df_table = pd.DataFrame(times, columns=['Estrazioni', 'Minimo', 'Media', 'Mediana', 'Massimo'])
df_table
# Out:
#    Estrazioni    Minimo     Media   Mediana   Massimo
# 0        1000  0.011323  0.059584  0.059584  0.465123

# %%
# print(df_table.Massimo)
time = df_time.head(1)['time'].astype('float').values[0]
value = df_table.Massimo.values[0]
mask = df_time['time'].astype('float') == value
filtered_df = df_time[df_time['time']== value]
filtered_df
# Out:
#            name      type                                           industry  \
# 971  Apple Inc.  [Public]  [Consumer electronics, Software services, Onli...
#
#                      founded                                   founders  \
# 971  [Los Altos, California]  [Steve Jobs, Steve Wozniak, Ronald Wayne]
#
#            headquarters key_people  \
# 971  [1 Apple Park Way]         []
#
#                                               services       revenue  \
# 971  [App Store, Apple Card, Apple Music, Apple TV+...  [ ,  (2022)]
#
#                     operating_income                     total_assets  \
# 971  [ , US$119.44 billion,  (2022)]  [ , US$352.76 billion,  (2022)]
#
#     number_of_employees website      time
# 971    [164,000 (2022)]     [ ]  0.465123
